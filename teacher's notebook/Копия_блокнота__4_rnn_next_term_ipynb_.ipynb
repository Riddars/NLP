# %% [markdown]
# Да, данный файл также относится к вашему заданию. Он содержит реализацию модели на основе рекуррентных нейронных сетей (RNN) для задачи **генерации следующего токена**. Давайте разберем концептуально, что происходит в этом коде, чтобы вы могли понять, как он решает задачу.
#
# ---
#
# ### **1. Что такое RNN?**
# Рекуррентные нейронные сети (RNN) — это тип нейронных сетей, которые хорошо подходят для работы с последовательными данными, такими как текст, аудио или временные ряды. В отличие от обычных нейронных сетей, RNN имеют **память**, которая позволяет учитывать предыдущие элементы последовательности при обработке текущего элемента.
#
# ---
#
# ### **2. Основные этапы решения задачи**
#
# #### **2.1. Подготовка данных**
# Перед обучением модели текст нужно обработать:
# 1. **Токенизация**: Разбиваем текст на предложения и слова. Убираем стоп-слова (например, "a", "the") и пунктуацию.
# 2. **Построение словаря**: Создаем словарь, который сопоставляет каждому слову уникальный индекс.
# 3. **Создание последовательностей**: Для обучения модели создаются последовательности фиксированной длины. Например, если длина последовательности равна 5, то из предложения "I love machine learning models" будут созданы такие пары:
#    - Вход: `["I", "love", "machine", "learning", "models"]`
#    - Цель: следующее слово после последовательности.
#
# В коде это реализовано функциями:
# - `make_sequences`: создает обучающие пары (последовательность, следующее слово).
#
# #### **2.2. Построение модели**
# Модель состоит из трех основных компонентов:
# 1. **Слой эмбеддингов**: Преобразует индексы слов в векторные представления фиксированной размерности. Это позволяет модели работать с плотными векторами вместо разреженных one-hot векторов.
# 2. **RNN-слой (GRU)**: Обрабатывает последовательность векторов, учитывая контекст предыдущих слов. В данном случае используется GRU (Gated Recurrent Unit) — это разновидность RNN, которая решает проблему затухающих градиентов.
# 3. **Линейный слой**: Преобразует выход RNN в вероятности для каждого слова в словаре.
#
# Модель реализована в классе:
# - `RNNPredictor`: включает слой эмбеддингов, GRU и линейный слой.
#
# #### **2.3. Обучение модели**
# Модель обучается предсказывать следующее слово для каждой последовательности. Для этого используется:
# - **Функция потерь**: `CrossEntropyLoss`, которая измеряет разницу между предсказанными вероятностями и истинным словом.
# - **Оптимизатор**: `Adam`, который обновляет веса модели для минимизации функции потерь.
#
# Обучение происходит в цикле:
# 1. Для каждой последовательности вычисляется предсказание модели.
# 2. Вычисляется ошибка (потеря) между предсказанием и истинным словом.
# 3. Градиенты ошибки распространяются назад по сети (backpropagation).
# 4. Веса модели обновляются с учетом градиентов.
#
# #### **2.4. Генерация текста**
# После обучения модель может использоваться для генерации текста. Процесс генерации:
# 1. Начинаем с заданной последовательности слов.
# 2. Модель предсказывает следующее слово.
# 3. Предсказанное слово добавляется к последовательности, и процесс повторяется.
#
# В коде это реализовано функцией:
# - `predict_next_word`: предсказывает следующее слово для заданной последовательности.
#
# ---
#
# ### **3. Концептуальное объяснение кода**
#
# #### **3.1. Импорт библиотек**
# - `nltk`: используется для токенизации текста.
# - `torch`: используется для построения и обучения нейронной сети.
# - `random`: используется для перемешивания данных перед каждой эпохой обучения.
#
# #### **3.2. Обработка текста**
# 1. Текст загружается из файла `ml_text.txt`.
# 2. Текст разбивается на предложения и слова с помощью `nltk`.
# 3. Убираются стоп-слова и пунктуация.
# 4. Создается словарь, который сопоставляет каждому слову уникальный индекс.
#
# #### **3.3. Создание последовательностей**
# Для каждой последовательности фиксированной длины создается пара (входная последовательность, следующее слово). Например:
# - Вход: `["I", "love", "machine", "learning"]`
# - Цель: `"models"`
#
# #### **3.4. Построение модели**
# Модель `RNNPredictor` включает:
# 1. **Слой эмбеддингов**: Преобразует индексы слов в векторные представления.
# 2. **GRU**: Обрабатывает последовательность векторов, учитывая контекст предыдущих слов.
# 3. **Линейный слой**: Преобразует выход GRU в вероятности для каждого слова в словаре.
#
# #### **3.5. Обучение модели**
# Модель обучается предсказывать следующее слово для каждой последовательности. На каждой эпохе:
# 1. Данные перемешиваются.
# 2. Для каждой последовательности вычисляется предсказание модели.
# 3. Вычисляется ошибка между предсказанием и истинным словом.
# 4. Градиенты распространяются назад, и веса модели обновляются.
#
# #### **3.6. Генерация текста**
# После обучения модель может предсказывать следующее слово для заданной последовательности. Например:
# - Вход: `["I", "love", "machine", "learning"]`
# - Выход: `"models"`
#
# ---
#
# ### **4. Важные аспекты**
#
# 1. **RNN (GRU)**: Рекуррентные нейронные сети обрабатывают последовательности, учитывая контекст предыдущих элементов.
# 2. **Слой эмбеддингов**: Преобразует индексы слов в плотные векторные представления.
# 3. **Функция потерь**: `CrossEntropyLoss` измеряет разницу между предсказанными вероятностями и истинным словом.
# 4. **Генерация текста**: Используется обученная модель для предсказания следующего слова.
#
# ---
#
# ### **5. Как это связано с вашим заданием?**
# Ваше задание состоит из четырех частей:
# 1. **Выбрать задачу**: В данном случае выбрана задача генерации следующего токена.
# 2. **Построить и обучить модель RNN**: Это реализовано в классе `RNNPredictor` и обучающем цикле.
# 3. **Включить слой эмбеддингов, RNN-слой и линейное преобразование**: Все эти компоненты включены в модель.
# 4. **Продемонстрировать работу модели**: Модель используется для генерации текста.
#
# ---
#
# Если у вас есть дополнительные вопросы или что-то осталось непонятным, дайте знать! Я могу объяснить подробнее или помочь с конкретными частями кода.

# %%
#%env MKL_ENABLE_INSTRUCTIONS=SSE4_2

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('punkt')
from pprint import pprint
import math
import string

#stopwords = nltk.corpus.stopwords.words('english')
stopwords = set(["a" ,"the", "'s"])
punctuation_list = set(string.punctuation)
# Out:
# [nltk_data] Downloading package punkt to /Users/olga/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
text = open("./data/ml_text.txt").read()
print(text[0:150], "...")
# Out:
# Machine learning is a field of study in artificial intelligence concerned with the development and study of statistical algorithms that can learn from ...

# %%
# Sentence Tokenization
sentences = sent_tokenize(text)
print("Sentence Tokenization:")
for idx, sentence in enumerate(sentences[0:3]):
    print(f"{idx+1}: {sentence}")

print("\nWord Tokenization:")
tokenized_text = []
for idx, sentence in enumerate(sentences):
    words = word_tokenize(sentence)
    tokenized_text.append([t.lower() for t in words if t.lower() not in stopwords and t.lower() not in punctuation_list])
    print(f"Sentence {idx+1} Words: {words}")
# Out:
# Sentence Tokenization:
# 1: Machine learning is a field of study in artificial intelligence concerned with the development and study of statistical algorithms that can learn from data and generalize to unseen data, and thus perform tasks without explicit instructions.
# 2: Within a subdiscipline in machine learning, advances in the field of deep learning have allowed neural networks, a class of statistical algorithms, to surpass many previous machine learning approaches in performance.ML finds application in many fields, including natural language processing, computer vision, speech recognition, email filtering, agriculture, and medicine.
# 3: The application of ML to business problems is known as predictive analytics.Statistics and mathematical optimization methods comprise the foundations of machine learning.
#
# Word Tokenization:
# Sentence 1 Words: ['Machine', 'learning', 'is', 'a', 'field', 'of', 'study', 'in', 'artificial', 'intelligence', 'concerned', 'with', 'the', 'development', 'and', 'study', 'of', 'statistical', 'algorithms', 'that', 'can', 'learn', 'from', 'data', 'and', 'generalize', 'to', 'unseen', 'data', ',', 'and', 'thus', 'perform', 'tasks', 'without', 'explicit', 'instructions', '.']
# Sentence 2 Words: ['Within', 'a', 'subdiscipline', 'in', 'machine', 'learning', ',', 'advances', 'in', 'the', 'field', 'of', 'deep', 'learning', 'have', 'allowed', 'neural', 'networks', ',', 'a', 'class', 'of', 'statistical', 'algorithms', ',', 'to', 'surpass', 'many', 'previous', 'machine', 'learning', 'approaches', 'in', 'performance.ML', 'finds', 'application', 'in', 'many', 'fields', ',', 'including', 'natural', 'language', 'processing', ',', 'computer', 'vision', ',', 'speech', 'recognition', ',', 'email', 'filtering', ',', 'agriculture', ',', 'and', 'medicine', '.']
# Sentence 3 Words: ['The', 'application', 'of', 'ML', 'to', 'business', 'problems', 'is', 'known', 'as', 'predictive', 'analytics.Statistics', 'and', 'mathematical', 'optimization', 'methods', 'comprise', 'the', 'foundations', 'of', 'machine', 'learning', '.']
# Sentence 4 Words: ['Data', 'mining', 'is', 'a', 'related', 'field', 'of', 'study', ',', 'focusing', 'on', 'exploratory', 'data', 'analysis', 'via', 'unsupervised', 'learning', '.']
# Sentence 5 Words: ['From', 'a', 'theoretical', 'viewpoint', ',', 'probably', 'approximately', 'correct', 'learning', 'provides', 'a', 'framework', 'for', 'describing', 'machine', 'learning.The', 'term', 'machine', 'learning', 'was', 'coined', 'in', '1959', 'by', 'Arthur', 'Samuel', ',', 'an', 'IBM', 'employee', 'and', 'pioneer', 'in', 'the', 'field', 'of', 'computer', 'gaming', 'and', 'artificial', 'intelligence', '.']
# Sentence 6 Words: ['The', 'synonym', 'self-teaching', 'computers', 'was', 'also', 'used', 'in', 'this', 'time', 'period.Although', 'the', 'earliest', 'machine', 'learning', 'model', 'was', 'introduced', 'in', 'the', '1950s', 'when', 'Arthur', 'Samuel', 'invented', 'a', 'program', 'that', 'calculated', 'the', 'winning', 'chance', 'in', 'checkers', 'for', 'each', 'side', ',', 'the', 'history', 'of', 'machine', 'learning', 'roots', 'back', 'to', 'decades', 'of', 'human', 'desire', 'and', 'effort', 'to', 'study', 'human', 'cognitive', 'processes', '.']
# Sentence 7 Words: ['In', '1949', ',', 'Canadian', 'psychologist', 'Donald', 'Hebb', 'published', 'the', 'book', 'The', 'Organization', 'of', 'Behavior', ',', 'in', 'which', 'he', 'introduced', 'a', 'theoretical', 'neural', 'structure', 'formed', 'by', 'certain', 'interactions', 'among', 'nerve', 'cells', '.']
# Sentence 8 Words: ['Hebb', "'s", 'model', 'of', 'neurons', 'interacting', 'with', 'one', 'another', 'set', 'a', 'groundwork', 'for', 'how', 'AIs', 'and', 'machine', 'learning', 'algorithms', 'work', 'under', 'nodes', ',', 'or', 'artificial', 'neurons', 'used', 'by', 'computers', 'to', 'communicate', 'data', '.']
# Sentence 9 Words: ['Other', 'researchers', 'who', 'have', 'studied', 'human', 'cognitive', 'systems', 'contributed', 'to', 'the', 'modern', 'machine', 'learning', 'technologies', 'as', 'well', ',', 'including', 'logician', 'Walter', 'Pitts', 'and', 'Warren', 'McCulloch', ',', 'who', 'proposed', 'the', 'early', 'mathematical', 'models', 'of', 'neural', 'networks', 'to', 'come', 'up', 'with', 'algorithms', 'that', 'mirror', 'human', 'thought', 'processes.By', 'the', 'early', '1960s', ',', 'an', 'experimental', '``', 'learning', 'machine', "''", 'with', 'punched', 'tape', 'memory', ',', 'called', 'Cybertron', ',', 'had', 'been', 'developed', 'by', 'Raytheon', 'Company', 'to', 'analyse', 'sonar', 'signals', ',', 'electrocardiograms', ',', 'and', 'speech', 'patterns', 'using', 'rudimentary', 'reinforcement', 'learning', '.']
# Sentence 10 Words: ['It', 'was', 'repetitively', '``', 'trained', "''", 'by', 'a', 'human', 'operator/teacher', 'to', 'recognize', 'patterns', 'and', 'equipped', 'with', 'a', '``', 'goof', "''", 'button', 'to', 'cause', 'it', 'to', 'reevaluate', 'incorrect', 'decisions', '.']
# Sentence 11 Words: ['A', 'representative', 'book', 'on', 'research', 'into', 'machine', 'learning', 'during', 'the', '1960s', 'was', 'Nilsson', "'s", 'book', 'on', 'Learning', 'Machines', ',', 'dealing', 'mostly', 'with', 'machine', 'learning', 'for', 'pattern', 'classification', '.']
# Sentence 12 Words: ['Interest', 'related', 'to', 'pattern', 'recognition', 'continued', 'into', 'the', '1970s', ',', 'as', 'described', 'by', 'Duda', 'and', 'Hart', 'in', '1973', '.']
# Sentence 13 Words: ['In', '1981', 'a', 'report', 'was', 'given', 'on', 'using', 'teaching', 'strategies', 'so', 'that', 'an', 'artificial', 'neural', 'network', 'learns', 'to', 'recognize', '40', 'characters', 'from', 'a', 'computer', 'terminal.Tom', 'M.', 'Mitchell', 'provided', 'a', 'widely', 'quoted', ',', 'more', 'formal', 'definition', 'of', 'the', 'algorithms', 'studied', 'in', 'the', 'machine', 'learning', 'field', ':', '``', 'A', 'computer', 'program', 'is', 'said', 'to', 'learn', 'from', 'experience', 'E', 'with', 'respect', 'to', 'some', 'class', 'of', 'tasks', 'T', 'and', 'performance', 'measure', 'P', 'if', 'its', 'performance', 'at', 'tasks', 'in', 'T', ',', 'as', 'measured', 'by', 'P', ',', 'improves', 'with', 'experience', 'E.', "''", 'This', 'definition', 'of', 'the', 'tasks', 'in', 'which', 'machine', 'learning', 'is', 'concerned', 'offers', 'a', 'fundamentally', 'operational', 'definition', 'rather', 'than', 'defining', 'the', 'field', 'in', 'cognitive', 'terms', '.']
# Sentence 14 Words: ['This', 'follows', 'Alan', 'Turing', "'s", 'proposal', 'in', 'his', 'paper', '``', 'Computing', 'Machinery', 'and', 'Intelligence', "''", ',', 'in', 'which', 'the', 'question', '``', 'Can', 'machines', 'think', '?', "''"]
# Sentence 15 Words: ['is', 'replaced', 'with', 'the', 'question', '``', 'Can', 'machines', 'do', 'what', 'we', 'can', 'do', '?']
# Sentence 16 Words: ['``', '.Modern-day', 'machine', 'learning', 'has', 'two', 'objectives', '.']
# Sentence 17 Words: ['One', 'is', 'to', 'classify', 'data', 'based', 'on', 'models', 'which', 'have', 'been', 'developed', ';', 'the', 'other', 'purpose', 'is', 'to', 'make', 'predictions', 'for', 'future', 'outcomes', 'based', 'on', 'these', 'models', '.']
# Sentence 18 Words: ['A', 'hypothetical', 'algorithm', 'specific', 'to', 'classifying', 'data', 'may', 'use', 'computer', 'vision', 'of', 'moles', 'coupled', 'with', 'supervised', 'learning', 'in', 'order', 'to', 'train', 'it', 'to', 'classify', 'the', 'cancerous', 'moles', '.']
# Sentence 19 Words: ['A', 'machine', 'learning', 'algorithm', 'for', 'stock', 'trading', 'may', 'inform', 'the', 'trader', 'of', 'future', 'potential', 'predictions.As', 'a', 'scientific', 'endeavor', ',', 'machine', 'learning', 'grew', 'out', 'of', 'the', 'quest', 'for', 'artificial', 'intelligence', '.']
# Sentence 20 Words: ['In', 'the', 'early', 'days', 'of', 'AI', 'as', 'an', 'academic', 'discipline', ',', 'some', 'researchers', 'were', 'interested', 'in', 'having', 'machines', 'learn', 'from', 'data', '.']
# Sentence 21 Words: ['They', 'attempted', 'to', 'approach', 'the', 'problem', 'with', 'various', 'symbolic', 'methods', ',', 'as', 'well', 'as', 'what', 'were', 'then', 'termed', '``', 'neural', 'networks', "''", ';', 'these', 'were', 'mostly', 'perceptrons', 'and', 'other', 'models', 'that', 'were', 'later', 'found', 'to', 'be', 'reinventions', 'of', 'the', 'generalized', 'linear', 'models', 'of', 'statistics', '.']
# Sentence 22 Words: ['Probabilistic', 'reasoning', 'was', 'also', 'employed', ',', 'especially', 'in', 'automated', 'medical', 'diagnosis.However', ',', 'an', 'increasing', 'emphasis', 'on', 'the', 'logical', ',', 'knowledge-based', 'approach', 'caused', 'a', 'rift', 'between', 'AI', 'and', 'machine', 'learning', '.']
# Sentence 23 Words: ['Probabilistic', 'systems', 'were', 'plagued', 'by', 'theoretical', 'and', 'practical', 'problems', 'of', 'data', 'acquisition', 'and', 'representation', '.']
# Sentence 24 Words: ['By', '1980', ',', 'expert', 'systems', 'had', 'come', 'to', 'dominate', 'AI', ',', 'and', 'statistics', 'was', 'out', 'of', 'favor', '.']
# Sentence 25 Words: ['Work', 'on', 'symbolic/knowledge-based', 'learning', 'did', 'continue', 'within', 'AI', ',', 'leading', 'to', 'inductive', 'logic', 'programming', ',', 'but', 'the', 'more', 'statistical', 'line', 'of', 'research', 'was', 'now', 'outside', 'the', 'field', 'of', 'AI', 'proper', ',', 'in', 'pattern', 'recognition', 'and', 'information', 'retrieval', '.']
# Sentence 26 Words: ['Neural', 'networks', 'research', 'had', 'been', 'abandoned', 'by', 'AI', 'and', 'computer', 'science', 'around', 'the', 'same', 'time', '.']
# Sentence 27 Words: ['This', 'line', ',', 'too', ',', 'was', 'continued', 'outside', 'the', 'AI/CS', 'field', ',', 'as', '``', 'connectionism', "''", ',', 'by', 'researchers', 'from', 'other', 'disciplines', 'including', 'John', 'Hopfield', ',', 'David', 'Rumelhart', ',', 'and', 'Geoffrey', 'Hinton', '.']
# Sentence 28 Words: ['Their', 'main', 'success', 'came', 'in', 'the', 'mid-1980s', 'with', 'the', 'reinvention', 'of', 'backpropagation.Machine', 'learning', ',', 'reorganized', 'and', 'recognized', 'as', 'its', 'own', 'field', ',', 'started', 'to', 'flourish', 'in', 'the', '1990s', '.']
# Sentence 29 Words: ['The', 'field', 'changed', 'its', 'goal', 'from', 'achieving', 'artificial', 'intelligence', 'to', 'tackling', 'solvable', 'problems', 'of', 'a', 'practical', 'nature', '.']
# Sentence 30 Words: ['It', 'shifted', 'focus', 'away', 'from', 'the', 'symbolic', 'approaches', 'it', 'had', 'inherited', 'from', 'AI', ',', 'and', 'toward', 'methods', 'and', 'models', 'borrowed', 'from', 'statistics', ',', 'fuzzy', 'logic', ',', 'and', 'probability', 'theory.There', 'is', 'a', 'close', 'connection', 'between', 'machine', 'learning', 'and', 'compression', '.']
# Sentence 31 Words: ['A', 'system', 'that', 'predicts', 'the', 'posterior', 'probabilities', 'of', 'a', 'sequence', 'given', 'its', 'entire', 'history', 'can', 'be', 'used', 'for', 'optimal', 'data', 'compression', '.']
# Sentence 32 Words: ['Conversely', ',', 'an', 'optimal', 'compressor', 'can', 'be', 'used', 'for', 'prediction', '.']
# Sentence 33 Words: ['This', 'equivalence', 'has', 'been', 'used', 'as', 'a', 'justification', 'for', 'using', 'data', 'compression', 'as', 'a', 'benchmark', 'for', '``', 'general', 'intelligence', "''", '.An', 'alternative', 'view', 'can', 'show', 'compression', 'algorithms', 'implicitly', 'map', 'strings', 'into', 'implicit', 'feature', 'space', 'vectors', ',', 'and', 'compression-based', 'similarity', 'measures', 'compute', 'similarity', 'within', 'these', 'feature', 'spaces', '.']
# Sentence 34 Words: ['For', 'each', 'compressor', 'C', 'we', 'define', 'an', 'associated', 'vector', 'space', 'ℵ', ',', 'such', 'that', 'C', 'maps', 'an', 'input', 'string', 'x', ',', 'corresponding', 'to', 'the', 'vector', 'norm', '||~x||', '.']
# Sentence 35 Words: ['An', 'exhaustive', 'examination', 'of', 'the', 'feature', 'spaces', 'underlying', 'all', 'compression', 'algorithms', 'is', 'precluded', 'by', 'space', ';', 'instead', ',', 'feature', 'vectors', 'chooses', 'to', 'examine', 'three', 'representative', 'lossless', 'compression', 'methods', ',', 'LZW', ',', 'LZ77', ',', 'and', 'PPM.According', 'to', 'AIXI', 'theory', ',', 'a', 'connection', 'more', 'directly', 'explained', 'in', 'Hutter', 'Prize', ',', 'the', 'best', 'possible', 'compression', 'of', 'x', 'is', 'the', 'smallest', 'possible', 'software', 'that', 'generates', 'x', '.']
# Sentence 36 Words: ['For', 'example', ',', 'in', 'that', 'model', ',', 'a', 'zip', 'file', "'s", 'compressed', 'size', 'includes', 'both', 'the', 'zip', 'file', 'and', 'the', 'unzipping', 'software', ',', 'since', 'you', 'can', 'not', 'unzip', 'it', 'without', 'both', ',', 'but', 'there', 'may', 'be', 'an', 'even', 'smaller', 'combined', 'form.Examples', 'of', 'AI-powered', 'audio/video', 'compression', 'software', 'include', 'NVIDIA', 'Maxine', ',', 'AIVC', '.']
# Sentence 37 Words: ['Examples', 'of', 'software', 'that', 'can', 'perform', 'AI-powered', 'image', 'compression', 'include', 'OpenCV', ',', 'TensorFlow', ',', 'MATLAB', "'s", 'Image', 'Processing', 'Toolbox', 'and', 'High-Fidelity', 'Generative', 'Image', 'Compression.In', 'unsupervised', 'machine', 'learning', ',', 'k-means', 'clustering', 'can', 'be', 'utilized', 'to', 'compress', 'data', 'by', 'grouping', 'similar', 'data', 'points', 'into', 'clusters', '.']
# Sentence 38 Words: ['This', 'technique', 'simplifies', 'handling', 'extensive', 'datasets', 'that', 'lack', 'predefined', 'labels', 'and', 'finds', 'widespread', 'use', 'in', 'fields', 'such', 'as', 'image', 'compression.Data', 'compression', 'aims', 'to', 'reduce', 'the', 'size', 'of', 'data', 'files', ',', 'enhancing', 'storage', 'efficiency', 'and', 'speeding', 'up', 'data', 'transmission', '.']
# Sentence 39 Words: ['K-means', 'clustering', ',', 'an', 'unsupervised', 'machine', 'learning', 'algorithm', ',', 'is', 'employed', 'to', 'partition', 'a', 'dataset', 'into', 'a', 'specified', 'number', 'of', 'clusters', ',', 'k', ',', 'each', 'represented', 'by', 'the', 'centroid', 'of', 'its', 'points', '.']
# Sentence 40 Words: ['This', 'process', 'condenses', 'extensive', 'datasets', 'into', 'a', 'more', 'compact', 'set', 'of', 'representative', 'points', '.']
# Sentence 41 Words: ['Particularly', 'beneficial', 'in', 'image', 'and', 'signal', 'processing', ',', 'k-means', 'clustering', 'aids', 'in', 'data', 'reduction', 'by', 'replacing', 'groups', 'of', 'data', 'points', 'with', 'their', 'centroids', ',', 'thereby', 'preserving', 'the', 'core', 'information', 'of', 'the', 'original', 'data', 'while', 'significantly', 'decreasing', 'the', 'required', 'storage', 'space.Machine', 'learning', 'and', 'data', 'mining', 'often', 'employ', 'the', 'same', 'methods', 'and', 'overlap', 'significantly', ',', 'but', 'while', 'machine', 'learning', 'focuses', 'on', 'prediction', ',', 'based', 'on', 'known', 'properties', 'learned', 'from', 'the', 'training', 'data', ',', 'data', 'mining', 'focuses', 'on', 'the', 'discovery', 'of', 'unknown', 'properties', 'in', 'the', 'data', '.']
# Sentence 42 Words: ['Data', 'mining', 'uses', 'many', 'machine', 'learning', 'methods', ',', 'but', 'with', 'different', 'goals', ';', 'on', 'the', 'other', 'hand', ',', 'machine', 'learning', 'also', 'employs', 'data', 'mining', 'methods', 'as', '``', 'unsupervised', 'learning', "''", 'or', 'as', 'a', 'preprocessing', 'step', 'to', 'improve', 'learner', 'accuracy', '.']
# Sentence 43 Words: ['Much', 'of', 'the', 'confusion', 'between', 'these', 'two', 'research', 'communities', 'comes', 'from', 'the', 'basic', 'assumptions', 'they', 'work', 'with', ':', 'in', 'machine', 'learning', ',', 'performance', 'is', 'usually', 'evaluated', 'with', 'respect', 'to', 'the', 'ability', 'to', 'reproduce', 'known', 'knowledge', ',', 'while', 'in', 'knowledge', 'discovery', 'and', 'data', 'mining', 'the', 'key', 'task', 'is', 'the', 'discovery', 'of', 'previously', 'unknown', 'knowledge', '.']
# Sentence 44 Words: ['Evaluated', 'with', 'respect', 'to', 'known', 'knowledge', ',', 'an', 'uninformed', 'method', 'will', 'easily', 'be', 'outperformed', 'by', 'other', 'supervised', 'methods', ',', 'while', 'in', 'a', 'typical', 'KDD', 'task', ',', 'supervised', 'methods', 'can', 'not', 'be', 'used', 'due', 'to', 'the', 'unavailability', 'of', 'training', 'data.Machine', 'learning', 'also', 'has', 'intimate', 'ties', 'to', 'optimization', ':', 'Many', 'learning', 'problems', 'are', 'formulated', 'as', 'minimization', 'of', 'some', 'loss', 'function', 'on', 'a', 'training', 'set', 'of', 'examples', '.']
# Sentence 45 Words: ['Loss', 'functions', 'express', 'the', 'discrepancy', 'between', 'the', 'predictions', 'of', 'the', 'model', 'being', 'trained', 'and', 'the', 'actual', 'problem', 'instances', '.Characterizing', 'the', 'generalization', 'of', 'various', 'learning', 'algorithms', 'is', 'an', 'active', 'topic', 'of', 'current', 'research', ',', 'especially', 'for', 'deep', 'learning', 'algorithms.Machine', 'learning', 'and', 'statistics', 'are', 'closely', 'related', 'fields', 'in', 'terms', 'of', 'methods', ',', 'but', 'distinct', 'in', 'their', 'principal', 'goal', ':', 'statistics', 'draws', 'population', 'inferences', 'from', 'a', 'sample', ',', 'while', 'machine', 'learning', 'finds', 'generalizable', 'predictive', 'patterns', '.']
# Sentence 46 Words: ['According', 'to', 'Michael', 'I.', 'Jordan', ',', 'the', 'ideas', 'of', 'machine', 'learning', ',', 'from', 'methodological', 'principles', 'to', 'theoretical', 'tools', ',', 'have', 'had', 'a', 'long', 'pre-history', 'in', 'statistics', '.']
# Sentence 47 Words: ['He', 'also', 'suggested', 'the', 'term', 'data', 'science', 'as', 'a', 'placeholder', 'to', 'call', 'the', 'overall', 'field.Conventional', 'statistical', 'analyses', 'require', 'the', 'a', 'priori', 'selection', 'of', 'a', 'model', 'most', 'suitable', 'for', 'the', 'study', 'data', 'set', '.']
# Sentence 48 Words: ['In', 'addition', ',', 'only', 'significant', 'or', 'theoretically', 'relevant', 'variables', 'based', 'on', 'previous', 'experience', 'are', 'included', 'for', 'analysis', '.']
# Sentence 49 Words: ['In', 'contrast', ',', 'machine', 'learning', 'is', 'not', 'built', 'on', 'a', 'pre-structured', 'model', ';', 'rather', ',', 'the', 'data', 'shape', 'the', 'model', 'by', 'detecting', 'underlying', 'patterns', '.']
# Sentence 50 Words: ['The', 'more', 'variables', 'used', 'to', 'train', 'the', 'model', ',', 'the', 'more', 'accurate', 'the', 'ultimate', 'model', 'will', 'be.Leo', 'Breiman', 'distinguished', 'two', 'statistical', 'modeling', 'paradigms', ':', 'data', 'model', 'and', 'algorithmic', 'wherein', '``', 'algorithmic', 'model', "''", 'means', 'more', 'or', 'less', 'the', 'machine', 'learning', 'algorithms', 'like', 'Random', 'Forest.Some', 'statisticians', 'have', 'adopted', 'methods', 'from', 'machine', 'learning', ',', 'leading', 'to', 'a', 'combined', 'field', 'that', 'they', 'call', 'statistical', 'learning.Analytical', 'and', 'computational', 'techniques', 'derived', 'from', 'deep-rooted', 'physics', 'of', 'disordered', 'systems', 'can', 'be', 'extended', 'to', 'large-scale', 'problems', ',', 'including', 'machine', 'learning', ',', 'e.g.', ',', 'to', 'analyse', 'the', 'weight', 'space', 'of', 'deep', 'neural', 'networks', '.']
# Sentence 51 Words: ['Statistical', 'physics', 'is', 'thus', 'finding', 'applications', 'in', 'the', 'area', 'of', 'medical', 'diagnostics.A', 'core', 'objective', 'of', 'a', 'learner', 'is', 'to', 'generalize', 'from', 'its', 'experience', '.']
# Sentence 52 Words: ['Generalization', 'in', 'this', 'context', 'is', 'the', 'ability', 'of', 'a', 'learning', 'machine', 'to', 'perform', 'accurately', 'on', 'new', ',', 'unseen', 'examples/tasks', 'after', 'having', 'experienced', 'a', 'learning', 'data', 'set', '.']
# Sentence 53 Words: ['The', 'training', 'examples', 'come', 'from', 'some', 'generally', 'unknown', 'probability', 'distribution', 'and', 'the', 'learner', 'has', 'to', 'build', 'a', 'general', 'model', 'about', 'this', 'space', 'that', 'enables', 'it', 'to', 'produce', 'sufficiently', 'accurate', 'predictions', 'in', 'new', 'cases.The', 'computational', 'analysis', 'of', 'machine', 'learning', 'algorithms', 'and', 'their', 'performance', 'is', 'a', 'branch', 'of', 'theoretical', 'computer', 'science', 'known', 'as', 'computational', 'learning', 'theory', 'via', 'the', 'probably', 'approximately', 'correct', 'learning', 'model', '.']
# Sentence 54 Words: ['Because', 'training', 'sets', 'are', 'finite', 'and', 'the', 'future', 'is', 'uncertain', ',', 'learning', 'theory', 'usually', 'does', 'not', 'yield', 'guarantees', 'of', 'the', 'performance', 'of', 'algorithms', '.']
# Sentence 55 Words: ['Instead', ',', 'probabilistic', 'bounds', 'on', 'the', 'performance', 'are', 'quite', 'common', '.']
# Sentence 56 Words: ['The', 'bias–variance', 'decomposition', 'is', 'one', 'way', 'to', 'quantify', 'generalization', 'error.For', 'the', 'best', 'performance', 'in', 'the', 'context', 'of', 'generalization', ',', 'the', 'complexity', 'of', 'the', 'hypothesis', 'should', 'match', 'the', 'complexity', 'of', 'the', 'function', 'underlying', 'the', 'data', '.']
# Sentence 57 Words: ['If', 'the', 'hypothesis', 'is', 'less', 'complex', 'than', 'the', 'function', ',', 'then', 'the', 'model', 'has', 'under', 'fitted', 'the', 'data', '.']
# Sentence 58 Words: ['If', 'the', 'complexity', 'of', 'the', 'model', 'is', 'increased', 'in', 'response', ',', 'then', 'the', 'training', 'error', 'decreases', '.']
# Sentence 59 Words: ['But', 'if', 'the', 'hypothesis', 'is', 'too', 'complex', ',', 'then', 'the', 'model', 'is', 'subject', 'to', 'overfitting', 'and', 'generalization', 'will', 'be', 'poorer.In', 'addition', 'to', 'performance', 'bounds', ',', 'learning', 'theorists', 'study', 'the', 'time', 'complexity', 'and', 'feasibility', 'of', 'learning', '.']
# Sentence 60 Words: ['In', 'computational', 'learning', 'theory', ',', 'a', 'computation', 'is', 'considered', 'feasible', 'if', 'it', 'can', 'be', 'done', 'in', 'polynomial', 'time', '.']
# Sentence 61 Words: ['There', 'are', 'two', 'kinds', 'of', 'time', 'complexity', 'results', ':', 'Positive', 'results', 'show', 'that', 'a', 'certain', 'class', 'of', 'functions', 'can', 'be', 'learned', 'in', 'polynomial', 'time', '.']
# Sentence 62 Words: ['Negative', 'results', 'show', 'that', 'certain', 'classes', 'can', 'not', 'be', 'learned', 'in', 'polynomial', 'time.Machine', 'learning', 'approaches', 'are', 'traditionally', 'divided', 'into', 'three', 'broad', 'categories', ',', 'which', 'correspond', 'to', 'learning', 'paradigms', ',', 'depending', 'on', 'the', 'nature', 'of', 'the', '``', 'signal', "''", 'or', '``', 'feedback', "''", 'available', 'to', 'the', 'learning', 'system', ':', 'Although', 'each', 'algorithm', 'has', 'advantages', 'and', 'limitations', ',', 'no', 'single', 'algorithm', 'works', 'for', 'all', 'problems.Supervised', 'learning', 'algorithms', 'build', 'a', 'mathematical', 'model', 'of', 'a', 'set', 'of', 'data', 'that', 'contains', 'both', 'the', 'inputs', 'and', 'the', 'desired', 'outputs', '.']
# Sentence 63 Words: ['The', 'data', ',', 'known', 'as', 'training', 'data', ',', 'consists', 'of', 'a', 'set', 'of', 'training', 'examples', '.']
# Sentence 64 Words: ['Each', 'training', 'example', 'has', 'one', 'or', 'more', 'inputs', 'and', 'the', 'desired', 'output', ',', 'also', 'known', 'as', 'a', 'supervisory', 'signal', '.']
# Sentence 65 Words: ['In', 'the', 'mathematical', 'model', ',', 'each', 'training', 'example', 'is', 'represented', 'by', 'an', 'array', 'or', 'vector', ',', 'sometimes', 'called', 'a', 'feature', 'vector', ',', 'and', 'the', 'training', 'data', 'is', 'represented', 'by', 'a', 'matrix', '.']
# Sentence 66 Words: ['Through', 'iterative', 'optimization', 'of', 'an', 'objective', 'function', ',', 'supervised', 'learning', 'algorithms', 'learn', 'a', 'function', 'that', 'can', 'be', 'used', 'to', 'predict', 'the', 'output', 'associated', 'with', 'new', 'inputs', '.']
# Sentence 67 Words: ['An', 'optimal', 'function', 'allows', 'the', 'algorithm', 'to', 'correctly', 'determine', 'the', 'output', 'for', 'inputs', 'that', 'were', 'not', 'a', 'part', 'of', 'the', 'training', 'data', '.']
# Sentence 68 Words: ['An', 'algorithm', 'that', 'improves', 'the', 'accuracy', 'of', 'its', 'outputs', 'or', 'predictions', 'over', 'time', 'is', 'said', 'to', 'have', 'learned', 'to', 'perform', 'that', 'task.Types', 'of', 'supervised-learning', 'algorithms', 'include', 'active', 'learning', ',', 'classification', 'and', 'regression', '.']
# Sentence 69 Words: ['Classification', 'algorithms', 'are', 'used', 'when', 'the', 'outputs', 'are', 'restricted', 'to', 'a', 'limited', 'set', 'of', 'values', ',', 'while', 'regression', 'algorithms', 'are', 'used', 'when', 'the', 'outputs', 'can', 'take', 'any', 'numerical', 'value', 'within', 'a', 'range', '.']
# Sentence 70 Words: ['For', 'example', ',', 'in', 'a', 'classification', 'algorithm', 'that', 'filters', 'emails', ',', 'the', 'input', 'is', 'an', 'incoming', 'email', ',', 'and', 'the', 'output', 'is', 'the', 'folder', 'in', 'which', 'to', 'file', 'the', 'email', '.']
# Sentence 71 Words: ['In', 'contrast', ',', 'regression', 'is', 'used', 'for', 'tasks', 'such', 'as', 'predicting', 'a', 'person', "'s", 'height', 'based', 'on', 'factors', 'like', 'age', 'and', 'genetics', 'or', 'forecasting', 'future', 'temperatures', 'based', 'on', 'historical', 'data.Similarity', 'learning', 'is', 'an', 'area', 'of', 'supervised', 'machine', 'learning', 'closely', 'related', 'to', 'regression', 'and', 'classification', ',', 'but', 'the', 'goal', 'is', 'to', 'learn', 'from', 'examples', 'using', 'a', 'similarity', 'function', 'that', 'measures', 'how', 'similar', 'or', 'related', 'two', 'objects', 'are', '.']
# Sentence 72 Words: ['It', 'has', 'applications', 'in', 'ranking', ',', 'recommendation', 'systems', ',', 'visual', 'identity', 'tracking', ',', 'face', 'verification', ',', 'and', 'speaker', 'verification.Unsupervised', 'learning', 'algorithms', 'find', 'structures', 'in', 'data', 'that', 'has', 'not', 'been', 'labeled', ',', 'classified', 'or', 'categorized', '.']
# Sentence 73 Words: ['Instead', 'of', 'responding', 'to', 'feedback', ',', 'unsupervised', 'learning', 'algorithms', 'identify', 'commonalities', 'in', 'the', 'data', 'and', 'react', 'based', 'on', 'the', 'presence', 'or', 'absence', 'of', 'such', 'commonalities', 'in', 'each', 'new', 'piece', 'of', 'data', '.']
# Sentence 74 Words: ['Central', 'applications', 'of', 'unsupervised', 'machine', 'learning', 'include', 'clustering', ',', 'dimensionality', 'and', 'density', 'estimation.Cluster', 'analysis', 'is', 'the', 'assignment', 'of', 'a', 'set', 'of', 'observations', 'into', 'subsets', 'so', 'that', 'observations', 'within', 'the', 'same', 'cluster', 'are', 'similar', 'according', 'to', 'one', 'or', 'more', 'predesignated', 'criteria', ',', 'while', 'observations', 'drawn', 'from', 'different', 'clusters', 'are', 'dissimilar', '.']
# Sentence 75 Words: ['Different', 'clustering', 'techniques', 'make', 'different', 'assumptions', 'on', 'the', 'structure', 'of', 'the', 'data', ',', 'often', 'defined', 'by', 'some', 'similarity', 'metric', 'and', 'evaluated', ',', 'for', 'example', ',', 'by', 'internal', 'compactness', ',', 'or', 'the', 'similarity', 'between', 'members', 'of', 'the', 'same', 'cluster', ',', 'and', 'separation', ',', 'the', 'difference', 'between', 'clusters', '.']
# Sentence 76 Words: ['Other', 'methods', 'are', 'based', 'on', 'estimated', 'density', 'and', 'graph', 'connectivity.A', 'special', 'type', 'of', 'unsupervised', 'learning', 'called', ',', 'self-supervised', 'learning', 'involves', 'training', 'a', 'model', 'by', 'generating', 'the', 'supervisory', 'signal', 'from', 'the', 'data', 'itself.Semi-supervised', 'learning', 'falls', 'between', 'unsupervised', 'learning', 'and', 'supervised', 'learning', '.']
# Sentence 77 Words: ['Some', 'of', 'the', 'training', 'examples', 'are', 'missing', 'training', 'labels', ',', 'yet', 'many', 'machine-learning', 'researchers', 'have', 'found', 'that', 'unlabeled', 'data', ',', 'when', 'used', 'in', 'conjunction', 'with', 'a', 'small', 'amount', 'of', 'labeled', 'data', ',', 'can', 'produce', 'a', 'considerable', 'improvement', 'in', 'learning', 'accuracy.In', 'weakly', 'supervised', 'learning', ',', 'the', 'training', 'labels', 'are', 'noisy', ',', 'limited', ',', 'or', 'imprecise', ';', 'however', ',', 'these', 'labels', 'are', 'often', 'cheaper', 'to', 'obtain', ',', 'resulting', 'in', 'larger', 'effective', 'training', 'sets.Reinforcement', 'learning', 'is', 'an', 'area', 'of', 'machine', 'learning', 'concerned', 'with', 'how', 'software', 'agents', 'ought', 'to', 'take', 'actions', 'in', 'an', 'environment', 'so', 'as', 'to', 'maximize', 'some', 'notion', 'of', 'cumulative', 'reward', '.']
# Sentence 78 Words: ['Due', 'to', 'its', 'generality', ',', 'the', 'field', 'is', 'studied', 'in', 'many', 'other', 'disciplines', ',', 'such', 'as', 'game', 'theory', ',', 'control', 'theory', ',', 'operations', 'research', ',', 'information', 'theory', ',', 'simulation-based', 'optimization', ',', 'multi-agent', 'systems', ',', 'swarm', 'intelligence', ',', 'statistics', 'and', 'genetic', 'algorithms', '.']
# Sentence 79 Words: ['In', 'reinforcement', 'learning', ',', 'the', 'environment', 'is', 'typically', 'represented', 'as', 'a', 'Markov', 'decision', 'process', '.']
# Sentence 80 Words: ['Many', 'reinforcement', 'learning', 'algorithms', 'use', 'dynamic', 'programming', 'techniques', '.']
# Sentence 81 Words: ['Reinforcement', 'learning', 'algorithms', 'do', 'not', 'assume', 'knowledge', 'of', 'an', 'exact', 'mathematical', 'model', 'of', 'the', 'MDP', 'and', 'are', 'used', 'when', 'exact', 'models', 'are', 'infeasible', '.']
# Sentence 82 Words: ['Reinforcement', 'learning', 'algorithms', 'are', 'used', 'in', 'autonomous', 'vehicles', 'or', 'in', 'learning', 'to', 'play', 'a', 'game', 'against', 'a', 'human', 'opponent.Dimensionality', 'reduction', 'is', 'a', 'process', 'of', 'reducing', 'the', 'number', 'of', 'random', 'variables', 'under', 'consideration', 'by', 'obtaining', 'a', 'set', 'of', 'principal', 'variables', '.']
# Sentence 83 Words: ['In', 'other', 'words', ',', 'it', 'is', 'a', 'process', 'of', 'reducing', 'the', 'dimension', 'of', 'the', 'feature', 'set', ',', 'also', 'called', 'the', '``', 'number', 'of', 'features', "''", '.']
# Sentence 84 Words: ['Most', 'of', 'the', 'dimensionality', 'reduction', 'techniques', 'can', 'be', 'considered', 'as', 'either', 'feature', 'elimination', 'or', 'extraction', '.']
# Sentence 85 Words: ['One', 'of', 'the', 'popular', 'methods', 'of', 'dimensionality', 'reduction', 'is', 'principal', 'component', 'analysis', '.']
# Sentence 86 Words: ['PCA', 'involves', 'changing', 'higher-dimensional', 'data', 'to', 'a', 'smaller', 'space', '.Other', 'approaches', 'have', 'been', 'developed', 'which', 'do', 'not', 'fit', 'neatly', 'into', 'this', 'three-fold', 'categorization', ',', 'and', 'sometimes', 'more', 'than', 'one', 'is', 'used', 'by', 'the', 'same', 'machine', 'learning', 'system', '.']
# Sentence 87 Words: ['For', 'example', ',', 'topic', 'modeling', ',', 'meta-learning.Self-learning', ',', 'as', 'a', 'machine', 'learning', 'paradigm', 'was', 'introduced', 'in', '1982', 'along', 'with', 'a', 'neural', 'network', 'capable', 'of', 'self-learning', ',', 'named', 'crossbar', 'adaptive', 'array', '.']
# Sentence 88 Words: ['It', 'gives', 'a', 'solution', 'to', 'the', 'problem', 'learning', 'without', 'any', 'external', 'reward', ',', 'by', 'introducing', 'emotion', 'as', 'an', 'internal', 'reward', '.']
# Sentence 89 Words: ['Emotion', 'is', 'used', 'as', 'state', 'evaluation', 'of', 'a', 'self-learning', 'agent', '.']
# Sentence 90 Words: ['The', 'CAA', 'self-learning', 'algorithm', 'computes', ',', 'in', 'a', 'crossbar', 'fashion', ',', 'both', 'decisions', 'about', 'actions', 'and', 'emotions', 'about', 'consequence', 'situations', '.']
# Sentence 91 Words: ['The', 'system', 'is', 'driven', 'by', 'the', 'interaction', 'between', 'cognition', 'and', 'emotion.It', 'is', 'a', 'system', 'with', 'only', 'one', 'input', ',', 'situation', ',', 'and', 'only', 'one', 'output', ',', 'action', 'a', '.']
# Sentence 92 Words: ['There', 'is', 'neither', 'a', 'separate', 'reinforcement', 'input', 'nor', 'an', 'advice', 'input', 'from', 'the', 'environment', '.']
# Sentence 93 Words: ['The', 'backpropagated', 'value', 'is', 'the', 'emotion', 'toward', 'the', 'consequence', 'situation', '.']
# Sentence 94 Words: ['The', 'CAA', 'exists', 'in', 'two', 'environments', ',', 'one', 'is', 'the', 'behavioral', 'environment', 'where', 'it', 'behaves', ',', 'and', 'the', 'other', 'is', 'the', 'genetic', 'environment', ',', 'wherefrom', 'it', 'initially', 'and', 'only', 'once', 'receives', 'initial', 'emotions', 'about', 'situations', 'to', 'be', 'encountered', 'in', 'the', 'behavioral', 'environment', '.']
# Sentence 95 Words: ['After', 'receiving', 'the', 'genome', 'vector', 'from', 'the', 'genetic', 'environment', ',', 'the', 'CAA', 'learns', 'a', 'goal-seeking', 'behavior', ',', 'in', 'an', 'environment', 'that', 'contains', 'both', 'desirable', 'and', 'undesirable', 'situations.Several', 'learning', 'algorithms', 'aim', 'at', 'discovering', 'better', 'representations', 'of', 'the', 'inputs', 'provided', 'during', 'training', '.']
# Sentence 96 Words: ['Classic', 'examples', 'include', 'principal', 'component', 'analysis', 'and', 'cluster', 'analysis', '.']
# Sentence 97 Words: ['Feature', 'learning', 'algorithms', ',', 'also', 'called', 'representation', 'learning', 'algorithms', ',', 'often', 'attempt', 'to', 'preserve', 'the', 'information', 'in', 'their', 'input', 'but', 'also', 'transform', 'it', 'in', 'a', 'way', 'that', 'makes', 'it', 'useful', ',', 'often', 'as', 'a', 'pre-processing', 'step', 'before', 'performing', 'classification', 'or', 'predictions', '.']
# Sentence 98 Words: ['This', 'technique', 'allows', 'reconstruction', 'of', 'the', 'inputs', 'coming', 'from', 'the', 'unknown', 'data-generating', 'distribution', ',', 'while', 'not', 'being', 'necessarily', 'faithful', 'to', 'configurations', 'that', 'are', 'implausible', 'under', 'that', 'distribution', '.']
# Sentence 99 Words: ['This', 'replaces', 'manual', 'feature', 'engineering', ',', 'and', 'allows', 'a', 'machine', 'to', 'both', 'learn', 'the', 'features', 'and', 'use', 'them', 'to', 'perform', 'a', 'specific', 'task.Feature', 'learning', 'can', 'be', 'either', 'supervised', 'or', 'unsupervised', '.']
# Sentence 100 Words: ['In', 'supervised', 'feature', 'learning', ',', 'features', 'are', 'learned', 'using', 'labeled', 'input', 'data', '.']
# Sentence 101 Words: ['Examples', 'include', 'artificial', 'neural', 'networks', ',', 'multilayer', 'perceptrons', ',', 'and', 'supervised', 'dictionary', 'learning', '.']
# Sentence 102 Words: ['In', 'unsupervised', 'feature', 'learning', ',', 'features', 'are', 'learned', 'with', 'unlabeled', 'input', 'data', '.']
# Sentence 103 Words: ['Examples', 'include', 'dictionary', 'learning', ',', 'independent', 'component', 'analysis', ',', 'autoencoders', ',', 'matrix', 'and', 'various', 'forms', 'of', 'clustering.Manifold', 'learning', 'algorithms', 'attempt', 'to', 'do', 'so', 'under', 'the', 'constraint', 'that', 'the', 'learned', 'representation', 'is', 'low-dimensional', '.']
# Sentence 104 Words: ['Sparse', 'coding', 'algorithms', 'attempt', 'to', 'do', 'so', 'under', 'the', 'constraint', 'that', 'the', 'learned', 'representation', 'is', 'sparse', ',', 'meaning', 'that', 'the', 'mathematical', 'model', 'has', 'many', 'zeros', '.']
# Sentence 105 Words: ['Multilinear', 'subspace', 'learning', 'algorithms', 'aim', 'to', 'learn', 'low-dimensional', 'representations', 'directly', 'from', 'tensor', 'representations', 'for', 'multidimensional', 'data', ',', 'without', 'reshaping', 'them', 'into', 'higher-dimensional', 'vectors', '.']
# Sentence 106 Words: ['Deep', 'learning', 'algorithms', 'discover', 'multiple', 'levels', 'of', 'representation', ',', 'or', 'a', 'hierarchy', 'of', 'features', ',', 'with', 'higher-level', ',', 'more', 'abstract', 'features', 'defined', 'in', 'terms', 'of', 'lower-level', 'features', '.']
# Sentence 107 Words: ['It', 'has', 'been', 'argued', 'that', 'an', 'intelligent', 'machine', 'is', 'one', 'that', 'learns', 'a', 'representation', 'that', 'disentangles', 'the', 'underlying', 'factors', 'of', 'variation', 'that', 'explain', 'the', 'observed', 'data.Feature', 'learning', 'is', 'motivated', 'by', 'the', 'fact', 'that', 'machine', 'learning', 'tasks', 'such', 'as', 'classification', 'often', 'require', 'input', 'that', 'is', 'mathematically', 'and', 'computationally', 'convenient', 'to', 'process', '.']
# Sentence 108 Words: ['However', ',', 'real-world', 'data', 'such', 'as', 'images', ',', 'video', ',', 'and', 'sensory', 'data', 'has', 'not', 'yielded', 'attempts', 'to', 'algorithmically', 'define', 'specific', 'features', '.']
# Sentence 109 Words: ['An', 'alternative', 'is', 'to', 'discover', 'such', 'features', 'or', 'representations', 'through', 'examination', ',', 'without', 'relying', 'on', 'explicit', 'algorithms.Sparse', 'dictionary', 'learning', 'is', 'a', 'feature', 'learning', 'method', 'where', 'a', 'training', 'example', 'is', 'represented', 'as', 'a', 'linear', 'combination', 'of', 'basis', 'functions', 'and', 'assumed', 'to', 'be', 'a', 'sparse', 'matrix', '.']
# Sentence 110 Words: ['The', 'method', 'is', 'strongly', 'NP-hard', 'and', 'difficult', 'to', 'solve', 'approximately', '.']
# Sentence 111 Words: ['A', 'popular', 'heuristic', 'method', 'for', 'sparse', 'dictionary', 'learning', 'is', 'the', 'k-SVD', 'algorithm', '.']
# Sentence 112 Words: ['Sparse', 'dictionary', 'learning', 'has', 'been', 'applied', 'in', 'several', 'contexts', '.']
# Sentence 113 Words: ['In', 'classification', ',', 'the', 'problem', 'is', 'to', 'determine', 'the', 'class', 'to', 'which', 'a', 'previously', 'unseen', 'training', 'example', 'belongs', '.']
# Sentence 114 Words: ['For', 'a', 'dictionary', 'where', 'each', 'class', 'has', 'already', 'been', 'built', ',', 'a', 'new', 'training', 'example', 'is', 'associated', 'with', 'the', 'class', 'that', 'is', 'best', 'sparsely', 'represented', 'by', 'the', 'corresponding', 'dictionary', '.']
# Sentence 115 Words: ['Sparse', 'dictionary', 'learning', 'has', 'also', 'been', 'applied', 'in', 'image', 'de-noising', '.']
# Sentence 116 Words: ['The', 'key', 'idea', 'is', 'that', 'a', 'clean', 'image', 'patch', 'can', 'be', 'sparsely', 'represented', 'by', 'an', 'image', 'dictionary', ',', 'but', 'the', 'noise', 'can', 'not', '.In', 'data', 'mining', ',', 'anomaly', 'detection', ',', 'also', 'known', 'as', 'outlier', 'detection', ',', 'is', 'the', 'identification', 'of', 'rare', 'items', ',', 'events', 'or', 'observations', 'which', 'raise', 'suspicions', 'by', 'differing', 'significantly', 'from', 'the', 'majority', 'of', 'the', 'data', '.']
# Sentence 117 Words: ['Typically', ',', 'the', 'anomalous', 'items', 'represent', 'an', 'issue', 'such', 'as', 'bank', 'fraud', ',', 'a', 'structural', 'defect', ',', 'medical', 'problems', 'or', 'errors', 'in', 'a', 'text', '.']
# Sentence 118 Words: ['Anomalies', 'are', 'referred', 'to', 'as', 'outliers', ',', 'novelties', ',', 'noise', ',', 'deviations', 'and', 'exceptions.In', 'particular', ',', 'in', 'the', 'context', 'of', 'abuse', 'and', 'network', 'intrusion', 'detection', ',', 'the', 'interesting', 'objects', 'are', 'often', 'not', 'rare', 'objects', ',', 'but', 'unexpected', 'bursts', 'of', 'inactivity', '.']
# Sentence 119 Words: ['This', 'pattern', 'does', 'not', 'adhere', 'to', 'the', 'common', 'statistical', 'definition', 'of', 'an', 'outlier', 'as', 'a', 'rare', 'object', '.']
# Sentence 120 Words: ['Many', 'outlier', 'detection', 'methods', 'will', 'fail', 'on', 'such', 'data', 'unless', 'aggregated', 'appropriately', '.']
# Sentence 121 Words: ['Instead', ',', 'a', 'cluster', 'analysis', 'algorithm', 'may', 'be', 'able', 'to', 'detect', 'the', 'micro-clusters', 'formed', 'by', 'these', 'patterns.Three', 'broad', 'categories', 'of', 'anomaly', 'detection', 'techniques', 'exist', '.']
# Sentence 122 Words: ['Unsupervised', 'anomaly', 'detection', 'techniques', 'detect', 'anomalies', 'in', 'an', 'unlabeled', 'test', 'data', 'set', 'under', 'the', 'assumption', 'that', 'the', 'majority', 'of', 'the', 'instances', 'in', 'the', 'data', 'set', 'are', 'normal', ',', 'by', 'looking', 'for', 'instances', 'that', 'seem', 'to', 'fit', 'the', 'least', 'to', 'the', 'remainder', 'of', 'the', 'data', 'set', '.']
# Sentence 123 Words: ['Supervised', 'anomaly', 'detection', 'techniques', 'require', 'a', 'data', 'set', 'that', 'has', 'been', 'labeled', 'as', '``', 'normal', "''", 'and', '``', 'abnormal', "''", 'and', 'involves', 'training', 'a', 'classifier', '.']
# Sentence 124 Words: ['Semi-supervised', 'anomaly', 'detection', 'techniques', 'construct', 'a', 'model', 'representing', 'normal', 'behavior', 'from', 'a', 'given', 'normal', 'training', 'data', 'set', 'and', 'then', 'test', 'the', 'likelihood', 'of', 'a', 'test', 'instance', 'to', 'be', 'generated', 'by', 'the', 'model.Robot', 'learning', 'is', 'inspired', 'by', 'a', 'multitude', 'of', 'machine', 'learning', 'methods', ',', 'starting', 'from', 'supervised', 'learning', ',', 'reinforcement', 'and', 'finally', 'meta-learning', '.Association', 'rule', 'learning', 'is', 'a', 'rule-based', 'machine', 'learning', 'method', 'for', 'discovering', 'relationships', 'between', 'variables', 'in', 'large', 'databases', '.']
# Sentence 125 Words: ['It', 'is', 'intended', 'to', 'identify', 'strong', 'rules', 'discovered', 'in', 'databases', 'using', 'some', 'measure', 'of', '``', 'interestingness', "''", '.Rule-based', 'machine', 'learning', 'is', 'a', 'general', 'term', 'for', 'any', 'machine', 'learning', 'method', 'that', 'identifies', ',', 'learns', ',', 'or', 'evolves', '``', 'rules', "''", 'to', 'store', ',', 'manipulate', 'or', 'apply', 'knowledge', '.']
# Sentence 126 Words: ['The', 'defining', 'characteristic', 'of', 'a', 'rule-based', 'machine', 'learning', 'algorithm', 'is', 'the', 'identification', 'and', 'utilization', 'of', 'a', 'set', 'of', 'relational', 'rules', 'that', 'collectively', 'represent', 'the', 'knowledge', 'captured', 'by', 'the', 'system', '.']
# Sentence 127 Words: ['This', 'is', 'in', 'contrast', 'to', 'other', 'machine', 'learning', 'algorithms', 'that', 'commonly', 'identify', 'a', 'singular', 'model', 'that', 'can', 'be', 'universally', 'applied', 'to', 'any', 'instance', 'in', 'order', 'to', 'make', 'a', 'prediction', '.']
# Sentence 128 Words: ['Rule-based', 'machine', 'learning', 'approaches', 'include', 'learning', 'classifier', 'systems', ',', 'association', 'rule', 'learning', ',', 'and', 'artificial', 'immune', 'systems.Based', 'on', 'the', 'concept', 'of', 'strong', 'rules', ',', 'Rakesh', 'Agrawal', ',', 'Tomasz', 'Imieliński', 'and', 'Arun', 'Swami', 'introduced', 'association', 'rules', 'for', 'discovering', 'regularities', 'between', 'products', 'in', 'large-scale', 'transaction', 'data', 'recorded', 'by', 'point-of-sale', 'systems', 'in', 'supermarkets', '.']
# Sentence 129 Words: ['Learning', 'classifier', 'systems', 'are', 'a', 'family', 'of', 'rule-based', 'machine', 'learning', 'algorithms', 'that', 'combine', 'a', 'discovery', 'component', ',', 'typically', 'a', 'genetic', 'algorithm', ',', 'with', 'a', 'learning', 'component', ',', 'performing', 'either', 'supervised', 'learning', ',', 'reinforcement', 'learning', ',', 'or', 'unsupervised', 'learning', '.']
# Sentence 130 Words: ['They', 'seek', 'to', 'identify', 'a', 'set', 'of', 'context-dependent', 'rules', 'that', 'collectively', 'store', 'and', 'apply', 'knowledge', 'in', 'a', 'piecewise', 'manner', 'in', 'order', 'to', 'make', 'predictions.Inductive', 'logic', 'programming', 'is', 'an', 'approach', 'to', 'rule', 'learning', 'using', 'logic', 'programming', 'as', 'a', 'uniform', 'representation', 'for', 'input', 'examples', ',', 'background', 'knowledge', ',', 'and', 'hypotheses', '.']
# Sentence 131 Words: ['Given', 'an', 'encoding', 'of', 'the', 'known', 'background', 'knowledge', 'and', 'a', 'set', 'of', 'examples', 'represented', 'as', 'a', 'logical', 'database', 'of', 'facts', ',', 'an', 'ILP', 'system', 'will', 'derive', 'a', 'hypothesized', 'logic', 'program', 'that', 'entails', 'all', 'positive', 'and', 'no', 'negative', 'examples', '.']
# Sentence 132 Words: ['Inductive', 'programming', 'is', 'a', 'related', 'field', 'that', 'considers', 'any', 'kind', 'of', 'programming', 'language', 'for', 'representing', 'hypotheses', ',', 'such', 'as', 'functional', 'programs.Inductive', 'logic', 'programming', 'is', 'particularly', 'useful', 'in', 'bioinformatics', 'and', 'natural', 'language', 'processing', '.']
# Sentence 133 Words: ['Gordon', 'Plotkin', 'and', 'Ehud', 'Shapiro', 'laid', 'the', 'initial', 'theoretical', 'foundation', 'for', 'inductive', 'machine', 'learning', 'in', 'a', 'logical', 'setting', '.']
# Sentence 134 Words: ['Shapiro', 'built', 'their', 'first', 'implementation', 'in', '1981', ':', 'a', 'Prolog', 'program', 'that', 'inductively', 'inferred', 'logic', 'programs', 'from', 'positive', 'and', 'negative', 'examples', '.']
# Sentence 135 Words: ['The', 'term', 'inductive', 'here', 'refers', 'to', 'philosophical', 'induction', ',', 'suggesting', 'a', 'theory', 'to', 'explain', 'observed', 'facts', ',', 'rather', 'than', 'mathematical', 'induction', ',', 'proving', 'a', 'property', 'for', 'all', 'members', 'of', 'a', 'well-ordered', 'set', '.']
# Sentence 136 Words: ['A', 'machine', 'learning', 'model', 'is', 'a', 'type', 'of', 'mathematical', 'model', 'that', ',', 'once', '``', 'trained', "''", 'on', 'a', 'given', 'dataset', ',', 'can', 'be', 'used', 'to', 'make', 'predictions', 'or', 'classifications', 'on', 'new', 'data', '.']
# Sentence 137 Words: ['During', 'training', ',', 'a', 'learning', 'algorithm', 'iteratively', 'adjusts', 'the', 'model', "'s", 'internal', 'parameters', 'to', 'minimize', 'errors', 'in', 'its', 'predictions', '.']
# Sentence 138 Words: ['By', 'extension', ',', 'the', 'term', '``', 'model', "''", 'can', 'refer', 'to', 'several', 'levels', 'of', 'specificity', ',', 'from', 'a', 'general', 'class', 'of', 'models', 'and', 'their', 'associated', 'learning', 'algorithms', 'to', 'a', 'fully', 'trained', 'model', 'with', 'all', 'its', 'internal', 'parameters', 'tuned.Various', 'types', 'of', 'models', 'have', 'been', 'used', 'and', 'researched', 'for', 'machine', 'learning', 'systems', ',', 'picking', 'the', 'best', 'model', 'for', 'a', 'task', 'is', 'called', 'model', 'selection.Artificial', 'neural', 'networks', ',', 'or', 'connectionist', 'systems', ',', 'are', 'computing', 'systems', 'vaguely', 'inspired', 'by', 'the', 'biological', 'neural', 'networks', 'that', 'constitute', 'animal', 'brains', '.']
# Sentence 139 Words: ['Such', 'systems', '``', 'learn', "''", 'to', 'perform', 'tasks', 'by', 'considering', 'examples', ',', 'generally', 'without', 'being', 'programmed', 'with', 'any', 'task-specific', 'rules.An', 'ANN', 'is', 'a', 'model', 'based', 'on', 'a', 'collection', 'of', 'connected', 'units', 'or', 'nodes', 'called', '``', 'artificial', 'neurons', "''", ',', 'which', 'loosely', 'model', 'the', 'neurons', 'in', 'a', 'biological', 'brain', '.']
# Sentence 140 Words: ['Each', 'connection', ',', 'like', 'the', 'synapses', 'in', 'a', 'biological', 'brain', ',', 'can', 'transmit', 'information', ',', 'a', '``', 'signal', "''", ',', 'from', 'one', 'artificial', 'neuron', 'to', 'another', '.']
# Sentence 141 Words: ['An', 'artificial', 'neuron', 'that', 'receives', 'a', 'signal', 'can', 'process', 'it', 'and', 'then', 'signal', 'additional', 'artificial', 'neurons', 'connected', 'to', 'it', '.']
# ...
# Sentence 218 Words: ['A', 'toy', 'example', 'is', 'that', 'an', 'image', 'classifier', 'trained', 'only', 'on', 'pictures', 'of', 'brown', 'horses', 'and', 'black', 'cats', 'might', 'conclude', 'that', 'all', 'brown', 'patches', 'are', 'likely', 'to', 'be', 'horses', '.']
# Sentence 219 Words: ['A', 'real-world', 'example', 'is', 'that', ',', 'unlike', 'humans', ',', 'current', 'image', 'classifiers', 'often', 'do', 'not', 'primarily', 'make', 'judgments', 'from', 'the', 'spatial', 'relationship', 'between', 'components', 'of', 'the', 'picture', ',', 'and', 'they', 'learn', 'relationships', 'between', 'pixels', 'that', 'humans', 'are', 'oblivious', 'to', ',', 'but', 'that', 'still', 'correlate', 'with', 'images', 'of', 'certain', 'types', 'of', 'real', 'objects', '.']
# Sentence 220 Words: ['Modifying', 'these', 'patterns', 'on', 'a', 'legitimate', 'image', 'can', 'result', 'in', '``', 'adversarial', "''", 'images', 'that', 'the', 'system', 'misclassifies.Adversarial', 'vulnerabilities', 'can', 'also', 'result', 'in', 'nonlinear', 'systems', ',', 'or', 'from', 'non-pattern', 'perturbations', '.']
# Sentence 221 Words: ['For', 'some', 'systems', ',', 'it', 'is', 'possible', 'to', 'change', 'the', 'output', 'by', 'only', 'changing', 'a', 'single', 'adversarially', 'chosen', 'pixel', '.']
# Sentence 222 Words: ['Machine', 'learning', 'models', 'are', 'often', 'vulnerable', 'to', 'manipulation', 'or', 'evasion', 'via', 'adversarial', 'machine', 'learning.Researchers', 'have', 'demonstrated', 'how', 'backdoors', 'can', 'be', 'placed', 'undetectably', 'into', 'classifying', 'machine', 'learning', 'models', 'that', 'are', 'often', 'developed', 'or', 'trained', 'by', 'third', 'parties', '.']
# Sentence 223 Words: ['Parties', 'can', 'change', 'the', 'classification', 'of', 'any', 'input', ',', 'including', 'in', 'cases', 'for', 'which', 'a', 'type', 'of', 'data/software', 'transparency', 'is', 'provided', ',', 'possibly', 'including', 'white-box', 'access.Classification', 'of', 'machine', 'learning', 'models', 'can', 'be', 'validated', 'by', 'accuracy', 'estimation', 'techniques', 'like', 'the', 'holdout', 'method', ',', 'which', 'splits', 'the', 'data', 'in', 'a', 'training', 'and', 'test', 'set', 'and', 'evaluates', 'the', 'performance', 'of', 'the', 'training', 'model', 'on', 'the', 'test', 'set', '.']
# Sentence 224 Words: ['In', 'comparison', ',', 'the', 'K-fold-cross-validation', 'method', 'randomly', 'partitions', 'the', 'data', 'into', 'K', 'subsets', 'and', 'then', 'K', 'experiments', 'are', 'performed', 'each', 'respectively', 'considering', '1', 'subset', 'for', 'evaluation', 'and', 'the', 'remaining', 'K-1', 'subsets', 'for', 'training', 'the', 'model', '.']
# Sentence 225 Words: ['In', 'addition', 'to', 'the', 'holdout', 'and', 'cross-validation', 'methods', ',', 'bootstrap', ',', 'which', 'samples', 'n', 'instances', 'with', 'replacement', 'from', 'the', 'dataset', ',', 'can', 'be', 'used', 'to', 'assess', 'model', 'accuracy.In', 'addition', 'to', 'overall', 'accuracy', ',', 'investigators', 'frequently', 'report', 'sensitivity', 'and', 'specificity', 'meaning', 'true', 'positive', 'rate', 'and', 'true', 'negative', 'rate', 'respectively', '.']
# Sentence 226 Words: ['Similarly', ',', 'investigators', 'sometimes', 'report', 'the', 'false', 'positive', 'rate', 'as', 'well', 'as', 'the', 'false', 'negative', 'rate', '.']
# Sentence 227 Words: ['However', ',', 'these', 'rates', 'are', 'ratios', 'that', 'fail', 'to', 'reveal', 'their', 'numerators', 'and', 'denominators', '.']
# Sentence 228 Words: ['Receiver', 'operating', 'characteristic', 'along', 'with', 'the', 'accompanying', 'Area', 'Under', 'the', 'ROC', 'Curve', 'offer', 'additional', 'tools', 'for', 'classification', 'model', 'assessment', '.']
# Sentence 229 Words: ['Higher', 'AUC', 'is', 'associated', 'with', 'a', 'better', 'performing', 'model.The', 'ethics', 'of', 'artificial', 'intelligence', 'covers', 'a', 'broad', 'range', 'of', 'topics', 'within', 'the', 'field', 'that', 'are', 'considered', 'to', 'have', 'particular', 'ethical', 'stakes', '.']
# Sentence 230 Words: ['This', 'includes', 'algorithmic', 'biases', ',', 'automated', 'decision-making', ',', 'accountability', ',', 'privacy', ',', 'and', 'regulation', '.']
# Sentence 231 Words: ['It', 'also', 'covers', 'various', 'emerging', 'or', 'potential', 'future', 'challenges', 'such', 'as', 'machine', 'ethics', ',', 'lethal', 'autonomous', 'weapon', 'systems', ',', 'arms', 'race', 'dynamics', ',', 'AI', 'safety', 'and', 'alignment', ',', 'technological', 'unemployment', ',', 'AI-enabled', 'misinformation', ',', 'how', 'to', 'treat', 'certain', 'AI', 'systems', 'if', 'they', 'have', 'a', 'moral', 'status', ',', 'artificial', 'superintelligence', 'and', 'existential', 'risks', '.']
# Sentence 232 Words: ['Different', 'machine', 'learning', 'approaches', 'can', 'suffer', 'from', 'different', 'data', 'biases', '.']
# Sentence 233 Words: ['A', 'machine', 'learning', 'system', 'trained', 'specifically', 'on', 'current', 'customers', 'may', 'not', 'be', 'able', 'to', 'predict', 'the', 'needs', 'of', 'new', 'customer', 'groups', 'that', 'are', 'not', 'represented', 'in', 'the', 'training', 'data', '.']
# Sentence 234 Words: ['When', 'trained', 'on', 'human-made', 'data', ',', 'machine', 'learning', 'is', 'likely', 'to', 'pick', 'up', 'the', 'constitutional', 'and', 'unconscious', 'biases', 'already', 'present', 'in', 'society.Systems', 'that', 'are', 'trained', 'on', 'datasets', 'collected', 'with', 'biases', 'may', 'exhibit', 'these', 'biases', 'upon', 'use', ',', 'thus', 'digitizing', 'cultural', 'prejudices', '.']
# Sentence 235 Words: ['For', 'example', ',', 'in', '1988', ',', 'the', 'UK', "'s", 'Commission', 'for', 'Racial', 'Equality', 'found', 'that', 'St.', 'George', "'s", 'Medical', 'School', 'had', 'been', 'using', 'a', 'computer', 'program', 'trained', 'from', 'data', 'of', 'previous', 'admissions', 'staff', 'and', 'that', 'this', 'program', 'had', 'denied', 'nearly', '60', 'candidates', 'who', 'were', 'found', 'to', 'either', 'be', 'women', 'or', 'have', 'non-European', 'sounding', 'names', '.']
# Sentence 236 Words: ['Using', 'job', 'hiring', 'data', 'from', 'a', 'firm', 'with', 'racist', 'hiring', 'policies', 'may', 'lead', 'to', 'a', 'machine', 'learning', 'system', 'duplicating', 'the', 'bias', 'by', 'scoring', 'job', 'applicants', 'by', 'similarity', 'to', 'previous', 'successful', 'applicants', '.']
# Sentence 237 Words: ['Another', 'example', 'includes', 'predictive', 'policing', 'company', 'Geolitica', "'s", 'predictive', 'algorithm', 'that', 'resulted', 'in', '``', 'disproportionately', 'high', 'levels', 'of', 'over-policing', 'in', 'low-income', 'and', 'minority', 'communities', "''", 'after', 'being', 'trained', 'with', 'historical', 'crime', 'data.While', 'responsible', 'collection', 'of', 'data', 'and', 'documentation', 'of', 'algorithmic', 'rules', 'used', 'by', 'a', 'system', 'is', 'considered', 'a', 'critical', 'part', 'of', 'machine', 'learning', ',', 'some', 'researchers', 'blame', 'lack', 'of', 'participation', 'and', 'representation', 'of', 'minority', 'population', 'in', 'the', 'field', 'of', 'AI', 'for', 'machine', 'learning', "'s", 'vulnerability', 'to', 'biases', '.']
# Sentence 238 Words: ['In', 'fact', ',', 'according', 'to', 'research', 'carried', 'out', 'by', 'the', 'Computing', 'Research', 'Association', 'in', '2021', ',', '``', 'female', 'faculty', 'merely', 'make', 'up', '16.1', '%', "''", 'of', 'all', 'faculty', 'members', 'who', 'focus', 'on', 'AI', 'among', 'several', 'universities', 'around', 'the', 'world', '.']
# Sentence 239 Words: ['Furthermore', ',', 'among', 'the', 'group', 'of', '``', 'new', 'U.S.', 'resident', 'AI', 'PhD', 'graduates', ',', "''", '45', '%', 'identified', 'as', 'white', ',', '22.4', '%', 'as', 'Asian', ',', '3.2', '%', 'as', 'Hispanic', ',', 'and', '2.4', '%', 'as', 'African', 'American', ',', 'which', 'further', 'demonstrates', 'a', 'lack', 'of', 'diversity', 'in', 'the', 'field', 'of', 'AI.Language', 'models', 'learned', 'from', 'data', 'have', 'been', 'shown', 'to', 'contain', 'human-like', 'biases', '.']
# Sentence 240 Words: ['Because', 'human', 'languages', 'contain', 'biases', ',', 'machines', 'trained', 'on', 'language', 'corpora', 'will', 'necessarily', 'also', 'learn', 'these', 'biases', '.']
# Sentence 241 Words: ['In', '2016', ',', 'Microsoft', 'tested', 'Tay', ',', 'a', 'chatbot', 'that', 'learned', 'from', 'Twitter', ',', 'and', 'it', 'quickly', 'picked', 'up', 'racist', 'and', 'sexist', 'language.In', 'an', 'experiment', 'carried', 'out', 'by', 'ProPublica', ',', 'an', 'investigative', 'journalism', 'organization', ',', 'a', 'machine', 'learning', 'algorithm', "'s", 'insight', 'into', 'the', 'recidivism', 'rates', 'among', 'prisoners', 'falsely', 'flagged', '``', 'black', 'defendants', 'high', 'risk', 'twice', 'as', 'often', 'as', 'white', 'defendants', "''", '.']
# Sentence 242 Words: ['In', '2015', ',', 'Google', 'Photos', 'once', 'tagged', 'a', 'couple', 'of', 'black', 'people', 'as', 'gorillas', ',', 'which', 'caused', 'controversy', '.']
# Sentence 243 Words: ['The', 'gorilla', 'label', 'was', 'subsequently', 'removed', ',', 'and', 'in', '2023', ',', 'it', 'still', 'can', 'not', 'recognize', 'gorillas', '.']
# Sentence 244 Words: ['Similar', 'issues', 'with', 'recognizing', 'non-white', 'people', 'have', 'been', 'found', 'in', 'many', 'other', 'systems.Because', 'of', 'such', 'challenges', ',', 'the', 'effective', 'use', 'of', 'machine', 'learning', 'may', 'take', 'longer', 'to', 'be', 'adopted', 'in', 'other', 'domains', '.']
# Sentence 245 Words: ['Concern', 'for', 'fairness', 'in', 'machine', 'learning', ',', 'that', 'is', ',', 'reducing', 'bias', 'in', 'machine', 'learning', 'and', 'propelling', 'its', 'use', 'for', 'human', 'good', ',', 'is', 'increasingly', 'expressed', 'by', 'artificial', 'intelligence', 'scientists', ',', 'including', 'Fei-Fei', 'Li', ',', 'who', 'said', 'that', '``', '[', 't', ']', 'here', "'s", 'nothing', 'artificial', 'about', 'AI', '.']
# Sentence 246 Words: ['It', "'s", 'inspired', 'by', 'people', ',', 'it', "'s", 'created', 'by', 'people', ',', 'and—most', 'importantly—it', 'impacts', 'people', '.']
# Sentence 247 Words: ['It', 'is', 'a', 'powerful', 'tool', 'we', 'are', 'only', 'just', 'beginning', 'to', 'understand', ',', 'and', 'that', 'is', 'a', 'profound', 'responsibility', '.']
# Sentence 248 Words: ['``', 'There', 'are', 'concerns', 'among', 'health', 'care', 'professionals', 'that', 'these', 'systems', 'might', 'not', 'be', 'designed', 'in', 'the', 'public', "'s", 'interest', 'but', 'as', 'income-generating', 'machines', '.']
# Sentence 249 Words: ['This', 'is', 'especially', 'true', 'in', 'the', 'United', 'States', 'where', 'there', 'is', 'a', 'long-standing', 'ethical', 'dilemma', 'of', 'improving', 'health', 'care', ',', 'but', 'also', 'increasing', 'profits', '.']
# Sentence 250 Words: ['For', 'example', ',', 'the', 'algorithms', 'could', 'be', 'designed', 'to', 'provide', 'patients', 'with', 'unnecessary', 'tests', 'or', 'medication', 'in', 'which', 'the', 'algorithm', "'s", 'proprietary', 'owners', 'hold', 'stakes', '.']
# Sentence 251 Words: ['There', 'is', 'potential', 'for', 'machine', 'learning', 'in', 'health', 'care', 'to', 'provide', 'professionals', 'an', 'additional', 'tool', 'to', 'diagnose', ',', 'medicate', ',', 'and', 'plan', 'recovery', 'paths', 'for', 'patients', ',', 'but', 'this', 'requires', 'these', 'biases', 'to', 'be', 'mitigated.Since', 'the', '2010s', ',', 'advances', 'in', 'both', 'machine', 'learning', 'algorithms', 'and', 'computer', 'hardware', 'have', 'led', 'to', 'more', 'efficient', 'methods', 'for', 'training', 'deep', 'neural', 'networks', 'that', 'contain', 'many', 'layers', 'of', 'nonlinear', 'hidden', 'units', '.']
# Sentence 252 Words: ['By', '2019', ',', 'graphics', 'processing', 'units', ',', 'often', 'with', 'AI-specific', 'enhancements', ',', 'had', 'displaced', 'CPUs', 'as', 'the', 'dominant', 'method', 'of', 'training', 'large-scale', 'commercial', 'cloud', 'AI', '.']
# Sentence 253 Words: ['OpenAI', 'estimated', 'the', 'hardware', 'compute', 'used', 'in', 'the', 'largest', 'deep', 'learning', 'projects', 'from', 'AlexNet', 'to', 'AlphaZero', ',', 'and', 'found', 'a', '300,000-fold', 'increase', 'in', 'the', 'amount', 'of', 'compute', 'required', ',', 'with', 'a', 'doubling-time', 'trendline', 'of', '3.4', 'months.Tensor', 'Processing', 'Units', 'are', 'specialized', 'hardware', 'accelerators', 'developed', 'by', 'Google', 'specifically', 'for', 'machine', 'learning', 'workloads', '.']
# Sentence 254 Words: ['Unlike', 'general-purpose', 'GPUs', 'and', 'FPGAs', ',', 'TPUs', 'are', 'optimized', 'for', 'tensor', 'computations', ',', 'making', 'them', 'particularly', 'efficient', 'for', 'deep', 'learning', 'tasks', 'such', 'as', 'training', 'and', 'inference', '.']
# Sentence 255 Words: ['They', 'are', 'widely', 'used', 'in', 'Google', 'Cloud', 'AI', 'services', 'and', 'large-scale', 'machine', 'learning', 'models', 'like', 'Google', "'s", 'DeepMind', 'AlphaFold', 'and', 'large', 'language', 'models', '.']
# Sentence 256 Words: ['TPUs', 'leverage', 'matrix', 'multiplication', 'units', 'and', 'high-bandwidth', 'memory', 'to', 'accelerate', 'computations', 'while', 'maintaining', 'energy', 'efficiency', '.']
# Sentence 257 Words: ['Since', 'their', 'introduction', 'in', '2016', ',', 'TPUs', 'have', 'become', 'a', 'key', 'component', 'of', 'AI', 'infrastructure', ',', 'especially', 'in', 'cloud-based', 'environments.Neuromorphic', 'computing', 'refers', 'to', 'a', 'class', 'of', 'computing', 'systems', 'designed', 'to', 'emulate', 'the', 'structure', 'and', 'functionality', 'of', 'biological', 'neural', 'networks', '.']
# Sentence 258 Words: ['These', 'systems', 'may', 'be', 'implemented', 'through', 'software-based', 'simulations', 'on', 'conventional', 'hardware', 'or', 'through', 'specialized', 'hardware', 'architectures.A', 'physical', 'neural', 'network', 'is', 'a', 'specific', 'type', 'of', 'neuromorphic', 'hardware', 'that', 'relies', 'on', 'electrically', 'adjustable', 'materials', ',', 'such', 'as', 'memristors', ',', 'to', 'emulate', 'the', 'function', 'of', 'neural', 'synapses', '.']
# Sentence 259 Words: ['The', 'term', '``', 'physical', 'neural', 'network', "''", 'highlights', 'the', 'use', 'of', 'physical', 'hardware', 'for', 'computation', ',', 'as', 'opposed', 'to', 'software-based', 'implementations', '.']
# Sentence 260 Words: ['It', 'broadly', 'refers', 'to', 'artificial', 'neural', 'networks', 'that', 'use', 'materials', 'with', 'adjustable', 'resistance', 'to', 'replicate', 'neural', 'synapses.Embedded', 'machine', 'learning', 'is', 'a', 'sub-field', 'of', 'machine', 'learning', 'where', 'models', 'are', 'deployed', 'on', 'embedded', 'systems', 'with', 'limited', 'computing', 'resources', ',', 'such', 'as', 'wearable', 'computers', ',', 'edge', 'devices', 'and', 'microcontrollers', '.']
# Sentence 261 Words: ['Running', 'models', 'directly', 'on', 'these', 'devices', 'eliminates', 'the', 'need', 'to', 'transfer', 'and', 'store', 'data', 'on', 'cloud', 'servers', 'for', 'further', 'processing', ',', 'thereby', 'reducing', 'the', 'risk', 'of', 'data', 'breaches', ',', 'privacy', 'leaks', 'and', 'theft', 'of', 'intellectual', 'property', ',', 'personal', 'data', 'and', 'business', 'secrets', '.']
# Sentence 262 Words: ['Embedded', 'machine', 'learning', 'can', 'be', 'achieved', 'through', 'various', 'techniques', ',', 'such', 'as', 'hardware', 'approximate', 'and', 'model', 'optimization', '.']
# Sentence 263 Words: ['Common', 'optimization', 'techniques', 'include', 'pruning', ',', 'quantization', ',', 'knowledge', 'distillation', ',', 'low-rank', 'factorization', ',', 'network', 'architecture', 'search', ',', 'and', 'parameter', 'sharing.Software', 'suites', 'containing', 'a', 'variety', 'of', 'machine', 'learning', 'algorithms', 'include', 'the', 'following', ':']

# %%
#tokenized_text
freq_dict  = nltk.FreqDist([t for s in tokenized_text for t in s])
print(len(freq_dict))
# for k, v in vocabulary.items():
#     print(k, v)
# Out:
# 2132

# %%
#tokenized_text = [[t if freq_dict[t] > 1 else "UNK" for t in sent] for sent in tokenized_text]
tokenized_text
# Out:
# [['machine',
#   'learning',
#   'is',
#   'field',
#   'of',
#   'study',
#   'in',
#   'artificial',
#   'intelligence',
#   'concerned',
#   'with',
#   'development',
#   'and',
#   'study',
#   'of',
#   'statistical',
#   'algorithms',
#   'that',
#   'can',
#   'learn',
#   'from',
#   'data',
#   'and',
#   'generalize',
#   'to',
#   'unseen',
#   'data',
#   'and',
#   'thus',
#   'perform',
#   'tasks',
#   'without',
#   'explicit',
#   'instructions'],
#  ['within',
#   'subdiscipline',
#   'in',
#   'machine',
#   'learning',
#   'advances',
#   'in',
#   'field',
#   'of',
#   'deep',
#   'learning',
#   'have',
#   'allowed',
#   'neural',
#   'networks',
#   'class',
#   'of',
#   'statistical',
#   'algorithms',
#   'to',
#   'surpass',
#   'many',
#   'previous',
#   'machine',
#   'learning',
#   'approaches',
#   'in',
#   'performance.ml',
#   'finds',
#   'application',
#   'in',
#   'many',
#   'fields',
#   'including',
#   'natural',
#   'language',
#   'processing',
#   'computer',
#   'vision',
#   'speech',
#   'recognition',
#   'email',
#   'filtering',
#   'agriculture',
#   'and',
#   'medicine'],
#  ['application',
#   'of',
#   'ml',
#   'to',
#   'business',
#   'problems',
#   'is',
#   'known',
#   'as',
#   'predictive',
#   'analytics.statistics',
#   'and',
#   'mathematical',
#   'optimization',
#   'methods',
#   'comprise',
#   'foundations',
#   'of',
#   'machine',
#   'learning'],
#  ['data',
#   'mining',
#   'is',
#   'related',
#   'field',
#   'of',
#   'study',
#   'focusing',
#   'on',
#   'exploratory',
#   'data',
#   'analysis',
#   'via',
#   'unsupervised',
#   'learning'],
#  ['from',
#   'theoretical',
#   'viewpoint',
#   'probably',
#   'approximately',
#   'correct',
#   'learning',
#   'provides',
#   'framework',
#   'for',
#   'describing',
#   'machine',
#   'learning.the',
#   'term',
#   'machine',
#   'learning',
#   'was',
#   'coined',
#   'in',
#   '1959',
#   'by',
#   'arthur',
#   'samuel',
#   'an',
#   'ibm',
#   'employee',
#   'and',
#   'pioneer',
#   'in',
#   'field',
#   'of',
#   'computer',
#   'gaming',
#   'and',
#   'artificial',
#   'intelligence'],
#  ['synonym',
#   'self-teaching',
#   'computers',
#   'was',
#   'also',
#   'used',
#   'in',
#   'this',
#   'time',
#   'period.although',
#   'earliest',
#   'machine',
#   'learning',
#   'model',
#   'was',
#   'introduced',
#   'in',
#   '1950s',
#   'when',
#   'arthur',
#   'samuel',
#   'invented',
#   'program',
#   'that',
#   'calculated',
#   'winning',
#   'chance',
#   'in',
#   'checkers',
#   'for',
#   'each',
#   'side',
#   'history',
#   'of',
#   'machine',
#   'learning',
#   'roots',
#   'back',
#   'to',
#   'decades',
#   'of',
#   'human',
#   'desire',
#   'and',
#   'effort',
#   'to',
#   'study',
#   'human',
#   'cognitive',
#   'processes'],
#  ['in',
#   '1949',
#   'canadian',
#   'psychologist',
#   'donald',
#   'hebb',
#   'published',
#   'book',
#   'organization',
#   'of',
#   'behavior',
#   'in',
#   'which',
#   'he',
#   'introduced',
#   'theoretical',
#   'neural',
#   'structure',
#   'formed',
#   'by',
#   'certain',
#   'interactions',
#   'among',
#   'nerve',
#   'cells'],
#  ['hebb',
#   'model',
#   'of',
#   'neurons',
#   'interacting',
#   'with',
#   'one',
#   'another',
#   'set',
#   'groundwork',
#   'for',
#   'how',
#   'ais',
#   'and',
#   'machine',
#   'learning',
#   'algorithms',
#   'work',
#   'under',
#   'nodes',
#   'or',
#   'artificial',
#   'neurons',
#   'used',
#   'by',
#   'computers',
#   'to',
#   'communicate',
#   'data'],
#  ['other',
#   'researchers',
#   'who',
#   'have',
#   'studied',
#   'human',
#   'cognitive',
#   'systems',
#   'contributed',
#   'to',
#   'modern',
#   'machine',
#   'learning',
#   'technologies',
#   'as',
#   'well',
#   'including',
#   'logician',
#   'walter',
#   'pitts',
#   'and',
#   'warren',
#   'mcculloch',
#   'who',
#   'proposed',
#   'early',
#   'mathematical',
#   'models',
#   'of',
#   'neural',
#   'networks',
#   'to',
#   'come',
#   'up',
#   'with',
#   'algorithms',
#   'that',
#   'mirror',
#   'human',
#   'thought',
#   'processes.by',
#   'early',
#   '1960s',
#   'an',
#   'experimental',
#   '``',
#   'learning',
#   'machine',
#   "''",
#   'with',
#   'punched',
#   'tape',
#   'memory',
#   'called',
#   'cybertron',
#   'had',
#   'been',
#   'developed',
#   'by',
#   'raytheon',
#   'company',
#   'to',
#   'analyse',
#   'sonar',
#   'signals',
#   'electrocardiograms',
#   'and',
#   'speech',
#   'patterns',
#   'using',
#   'rudimentary',
#   'reinforcement',
#   'learning'],
#  ['it',
#   'was',
#   'repetitively',
#   '``',
#   'trained',
#   "''",
#   'by',
#   'human',
#   'operator/teacher',
#   'to',
#   'recognize',
#   'patterns',
#   'and',
#   'equipped',
#   'with',
#   '``',
#   'goof',
#   "''",
#   'button',
#   'to',
#   'cause',
#   'it',
#   'to',
#   'reevaluate',
#   'incorrect',
#   'decisions'],
#  ['representative',
#   'book',
#   'on',
#   'research',
#   'into',
#   'machine',
#   'learning',
#   'during',
#   '1960s',
#   'was',
#   'nilsson',
#   'book',
#   'on',
#   'learning',
#   'machines',
#   'dealing',
#   'mostly',
#   'with',
#   'machine',
#   'learning',
#   'for',
#   'pattern',
#   'classification'],
#  ['interest',
#   'related',
#   'to',
#   'pattern',
#   'recognition',
#   'continued',
#   'into',
#   '1970s',
#   'as',
#   'described',
#   'by',
#   'duda',
#   'and',
#   'hart',
#   'in',
#   '1973'],
#  ['in',
#   '1981',
#   'report',
#   'was',
#   'given',
#   'on',
#   'using',
#   'teaching',
#   'strategies',
#   'so',
#   'that',
#   'an',
#   'artificial',
#   'neural',
#   'network',
#   'learns',
#   'to',
#   'recognize',
#   '40',
#   'characters',
#   'from',
#   'computer',
#   'terminal.tom',
#   'm.',
#   'mitchell',
#   'provided',
#   'widely',
#   'quoted',
#   'more',
#   'formal',
#   'definition',
#   'of',
#   'algorithms',
#   'studied',
#   'in',
#   'machine',
#   'learning',
#   'field',
#   '``',
#   'computer',
#   'program',
#   'is',
#   'said',
#   'to',
#   'learn',
#   'from',
#   'experience',
#   'e',
#   'with',
#   'respect',
#   'to',
#   'some',
#   'class',
#   'of',
#   'tasks',
#   't',
#   'and',
#   'performance',
#   'measure',
#   'p',
#   'if',
#   'its',
#   'performance',
#   'at',
#   'tasks',
#   'in',
#   't',
#   'as',
#   'measured',
#   'by',
#   'p',
#   'improves',
#   'with',
#   'experience',
#   'e.',
#   "''",
#   'this',
#   'definition',
#   'of',
#   'tasks',
#   'in',
#   'which',
#   'machine',
#   'learning',
#   'is',
#   'concerned',
#   'offers',
#   'fundamentally',
#   'operational',
#   'definition',
#   'rather',
#   'than',
#   'defining',
#   'field',
#   'in',
#   'cognitive',
#   'terms'],
#  ['this',
#   'follows',
#   'alan',
#   'turing',
#   'proposal',
#   'in',
#   'his',
#   'paper',
#   '``',
#   'computing',
#   'machinery',
#   'and',
#   'intelligence',
#   "''",
#   'in',
#   'which',
#   'question',
#   '``',
#   'can',
#   'machines',
#   'think',
#   "''"],
#  ['is',
#   'replaced',
#   'with',
#   'question',
#   '``',
#   'can',
#   'machines',
#   'do',
#   'what',
#   'we',
#   'can',
#   'do'],
#  ['``', '.modern-day', 'machine', 'learning', 'has', 'two', 'objectives'],
#  ['one',
#   'is',
#   'to',
#   'classify',
#   'data',
#   'based',
#   'on',
#   'models',
#   'which',
#   'have',
#   'been',
#   'developed',
#   'other',
#   'purpose',
#   'is',
#   'to',
#   'make',
#   'predictions',
#   'for',
#   'future',
#   'outcomes',
#   'based',
#   'on',
#   'these',
#   'models'],
#  ['hypothetical',
#   'algorithm',
#   'specific',
#   'to',
#   'classifying',
#   'data',
#   'may',
#   'use',
#   'computer',
#   'vision',
#   'of',
#   'moles',
#   'coupled',
#   'with',
#   'supervised',
#   'learning',
#   'in',
#   'order',
#   'to',
#   'train',
#   'it',
#   'to',
#   'classify',
#   'cancerous',
#   'moles'],
#  ['machine',
#   'learning',
#   'algorithm',
#   'for',
#   'stock',
#   'trading',
#   'may',
#   'inform',
#   'trader',
#   'of',
#   'future',
#   'potential',
#   'predictions.as',
#   'scientific',
#   'endeavor',
#   'machine',
#   'learning',
#   'grew',
#   'out',
#   'of',
#   'quest',
#   'for',
#   'artificial',
#   'intelligence'],
#  ['in',
#   'early',
#   'days',
#   'of',
#   'ai',
#   'as',
#   'an',
#   'academic',
#   'discipline',
#   'some',
#   'researchers',
#   'were',
#   'interested',
#   'in',
#   'having',
#   'machines',
#   'learn',
#   'from',
#   'data'],
#  ['they',
#   'attempted',
#   'to',
#   'approach',
#   'problem',
#   'with',
#   'various',
#   'symbolic',
#   'methods',
#   'as',
#   'well',
#   'as',
#   'what',
#   'were',
#   'then',
#   'termed',
#   '``',
#   'neural',
#   'networks',
#   "''",
#   'these',
#   'were',
#   'mostly',
#   'perceptrons',
#   'and',
#   'other',
#   'models',
#   'that',
#   'were',
#   'later',
#   'found',
#   'to',
#   'be',
#   'reinventions',
#   'of',
#   'generalized',
#   'linear',
#   'models',
#   'of',
#   'statistics'],
#  ['probabilistic',
#   'reasoning',
#   'was',
#   'also',
#   'employed',
#   'especially',
#   'in',
#   'automated',
#   'medical',
#   'diagnosis.however',
#   'an',
#   'increasing',
#   'emphasis',
#   'on',
#   'logical',
#   'knowledge-based',
#   'approach',
#   'caused',
#   'rift',
#   'between',
#   'ai',
#   'and',
#   'machine',
#   'learning'],
#  ['probabilistic',
#   'systems',
#   'were',
#   'plagued',
#   'by',
#   'theoretical',
#   'and',
#   'practical',
#   'problems',
#   'of',
#   'data',
#   'acquisition',
#   'and',
#   'representation'],
#  ['by',
#   '1980',
#   'expert',
#   'systems',
#   'had',
#   'come',
#   'to',
#   'dominate',
#   'ai',
#   'and',
#   'statistics',
#   'was',
#   'out',
#   'of',
#   'favor'],
#  ['work',
#   'on',
#   'symbolic/knowledge-based',
#   'learning',
#   'did',
#   'continue',
#   'within',
#   'ai',
#   'leading',
#   'to',
#   'inductive',
#   'logic',
#   'programming',
#   'but',
#   'more',
#   'statistical',
#   'line',
#   'of',
#   'research',
#   'was',
#   'now',
#   'outside',
#   'field',
#   'of',
#   'ai',
#   'proper',
#   'in',
#   'pattern',
#   'recognition',
#   'and',
#   'information',
#   'retrieval'],
#  ['neural',
#   'networks',
#   'research',
#   'had',
#   'been',
#   'abandoned',
#   'by',
#   'ai',
#   'and',
#   'computer',
#   'science',
#   'around',
#   'same',
#   'time'],
#  ['this',
#   'line',
#   'too',
#   'was',
#   'continued',
#   'outside',
#   'ai/cs',
#   'field',
#   'as',
#   '``',
#   'connectionism',
#   "''",
#   'by',
#   'researchers',
#   'from',
#   'other',
#   'disciplines',
#   'including',
#   'john',
#   'hopfield',
#   'david',
#   'rumelhart',
#   'and',
#   'geoffrey',
#   'hinton'],
#  ['their',
#   'main',
#   'success',
#   'came',
#   'in',
#   'mid-1980s',
#   'with',
#   'reinvention',
#   'of',
#   'backpropagation.machine',
#   'learning',
#   'reorganized',
#   'and',
#   'recognized',
#   'as',
#   'its',
#   'own',
#   'field',
#   'started',
#   'to',
#   'flourish',
#   'in',
#   '1990s'],
#  ['field',
#   'changed',
#   'its',
#   'goal',
#   'from',
#   'achieving',
#   'artificial',
#   'intelligence',
#   'to',
#   'tackling',
#   'solvable',
#   'problems',
#   'of',
#   'practical',
#   'nature'],
#  ['it',
#   'shifted',
#   'focus',
#   'away',
#   'from',
#   'symbolic',
#   'approaches',
#   'it',
#   'had',
#   'inherited',
#   'from',
#   'ai',
#   'and',
#   'toward',
#   'methods',
#   'and',
#   'models',
#   'borrowed',
#   'from',
#   'statistics',
#   'fuzzy',
#   'logic',
#   'and',
#   'probability',
#   'theory.there',
#   'is',
#   'close',
#   'connection',
#   'between',
#   'machine',
#   'learning',
#   'and',
#   'compression'],
#  ['system',
#   'that',
#   'predicts',
#   'posterior',
#   'probabilities',
#   'of',
#   'sequence',
#   'given',
#   'its',
#   'entire',
#   'history',
#   'can',
#   'be',
#   'used',
#   'for',
#   'optimal',
#   'data',
#   'compression'],
#  ['conversely',
#   'an',
#   'optimal',
#   'compressor',
#   'can',
#   'be',
#   'used',
#   'for',
#   'prediction'],
#  ['this',
#   'equivalence',
#   'has',
#   'been',
#   'used',
#   'as',
#   'justification',
#   'for',
#   'using',
#   'data',
#   'compression',
#   'as',
#   'benchmark',
#   'for',
#   '``',
#   'general',
#   'intelligence',
#   "''",
#   '.an',
#   'alternative',
#   'view',
#   'can',
#   'show',
#   'compression',
#   'algorithms',
#   'implicitly',
#   'map',
#   'strings',
#   'into',
#   'implicit',
#   'feature',
#   'space',
#   'vectors',
#   'and',
#   'compression-based',
#   'similarity',
#   'measures',
#   'compute',
#   'similarity',
#   'within',
#   'these',
#   'feature',
#   'spaces'],
#  ['for',
#   'each',
#   'compressor',
#   'c',
#   'we',
#   'define',
#   'an',
#   'associated',
#   'vector',
#   'space',
#   'ℵ',
#   'such',
#   'that',
#   'c',
#   'maps',
#   'an',
#   'input',
#   'string',
#   'x',
#   'corresponding',
#   'to',
#   'vector',
#   'norm',
#   '||~x||'],
#  ['an',
#   'exhaustive',
#   'examination',
#   'of',
#   'feature',
#   'spaces',
#   'underlying',
#   'all',
#   'compression',
#   'algorithms',
#   'is',
#   'precluded',
#   'by',
#   'space',
#   'instead',
#   'feature',
#   'vectors',
#   'chooses',
#   'to',
#   'examine',
#   'three',
#   'representative',
#   'lossless',
#   'compression',
#   'methods',
#   'lzw',
#   'lz77',
#   'and',
#   'ppm.according',
#   'to',
#   'aixi',
#   'theory',
#   'connection',
#   'more',
#   'directly',
#   'explained',
#   'in',
#   'hutter',
#   'prize',
#   'best',
#   'possible',
#   'compression',
#   'of',
#   'x',
#   'is',
#   'smallest',
#   'possible',
#   'software',
#   'that',
#   'generates',
#   'x'],
#  ['for',
#   'example',
#   'in',
#   'that',
#   'model',
#   'zip',
#   'file',
#   'compressed',
#   'size',
#   'includes',
#   'both',
#   'zip',
#   'file',
#   'and',
#   'unzipping',
#   'software',
#   'since',
#   'you',
#   'can',
#   'not',
#   'unzip',
#   'it',
#   'without',
#   'both',
#   'but',
#   'there',
#   'may',
#   'be',
#   'an',
#   'even',
#   'smaller',
#   'combined',
#   'form.examples',
#   'of',
#   'ai-powered',
#   'audio/video',
#   'compression',
#   'software',
#   'include',
#   'nvidia',
#   'maxine',
#   'aivc'],
#  ['examples',
#   'of',
#   'software',
#   'that',
#   'can',
#   'perform',
#   'ai-powered',
#   'image',
#   'compression',
#   'include',
#   'opencv',
#   'tensorflow',
#   'matlab',
#   'image',
#   'processing',
#   'toolbox',
#   'and',
#   'high-fidelity',
#   'generative',
#   'image',
#   'compression.in',
#   'unsupervised',
#   'machine',
#   'learning',
#   'k-means',
#   'clustering',
#   'can',
#   'be',
#   'utilized',
#   'to',
#   'compress',
#   'data',
#   'by',
#   'grouping',
#   'similar',
#   'data',
#   'points',
#   'into',
#   'clusters'],
#  ['this',
#   'technique',
#   'simplifies',
#   'handling',
#   'extensive',
#   'datasets',
#   'that',
#   'lack',
#   'predefined',
#   'labels',
#   'and',
#   'finds',
#   'widespread',
#   'use',
#   'in',
#   'fields',
#   'such',
#   'as',
#   'image',
#   'compression.data',
#   'compression',
#   'aims',
#   'to',
#   'reduce',
#   'size',
#   'of',
#   'data',
#   'files',
#   'enhancing',
#   'storage',
#   'efficiency',
#   'and',
#   'speeding',
#   'up',
#   'data',
#   'transmission'],
#  ['k-means',
#   'clustering',
#   'an',
#   'unsupervised',
#   'machine',
#   'learning',
#   'algorithm',
#   'is',
#   'employed',
#   'to',
#   'partition',
#   'dataset',
#   'into',
#   'specified',
#   'number',
#   'of',
#   'clusters',
#   'k',
#   'each',
#   'represented',
#   'by',
#   'centroid',
#   'of',
#   'its',
#   'points'],
#  ['this',
#   'process',
#   'condenses',
#   'extensive',
#   'datasets',
#   'into',
#   'more',
#   'compact',
#   'set',
#   'of',
#   'representative',
#   'points'],
#  ['particularly',
#   'beneficial',
#   'in',
#   'image',
#   'and',
#   'signal',
#   'processing',
#   'k-means',
#   'clustering',
#   'aids',
#   'in',
#   'data',
#   'reduction',
#   'by',
#   'replacing',
#   'groups',
#   'of',
#   'data',
#   'points',
#   'with',
#   'their',
#   'centroids',
#   'thereby',
#   'preserving',
#   'core',
#   'information',
#   'of',
#   'original',
#   'data',
#   'while',
#   'significantly',
#   'decreasing',
#   'required',
#   'storage',
#   'space.machine',
#   'learning',
#   'and',
#   'data',
#   'mining',
#   'often',
#   'employ',
#   'same',
#   'methods',
#   'and',
#   'overlap',
#   'significantly',
#   'but',
#   'while',
#   'machine',
#   'learning',
#   'focuses',
#   'on',
#   'prediction',
#   'based',
#   'on',
#   'known',
#   'properties',
#   'learned',
#   'from',
#   'training',
#   'data',
#   'data',
#   'mining',
#   'focuses',
#   'on',
#   'discovery',
#   'of',
#   'unknown',
#   'properties',
#   'in',
#   'data'],
#  ['data',
#   'mining',
#   'uses',
#   'many',
#   'machine',
#   'learning',
#   'methods',
#   'but',
#   'with',
#   'different',
#   'goals',
#   'on',
#   'other',
#   'hand',
#   'machine',
#   'learning',
#   'also',
#   'employs',
#   'data',
#   'mining',
#   'methods',
#   'as',
#   '``',
#   'unsupervised',
#   'learning',
#   "''",
#   'or',
#   'as',
#   'preprocessing',
#   'step',
#   'to',
#   'improve',
#   'learner',
#   'accuracy'],
#  ['much',
#   'of',
#   'confusion',
#   'between',
#   'these',
#   'two',
#   'research',
#   'communities',
#   'comes',
#   'from',
#   'basic',
#   'assumptions',
#   'they',
#   'work',
#   'with',
#   'in',
#   'machine',
#   'learning',
#   'performance',
#   'is',
#   'usually',
#   'evaluated',
#   'with',
#   'respect',
#   'to',
#   'ability',
#   'to',
#   'reproduce',
#   'known',
#   'knowledge',
#   'while',
#   'in',
#   'knowledge',
#   'discovery',
#   'and',
#   'data',
#   'mining',
#   'key',
#   'task',
#   'is',
#   'discovery',
#   'of',
#   'previously',
#   'unknown',
#   'knowledge'],
#  ['evaluated',
#   'with',
#   'respect',
#   'to',
#   'known',
#   'knowledge',
#   'an',
#   'uninformed',
#   'method',
#   'will',
#   'easily',
#   'be',
#   'outperformed',
#   'by',
#   'other',
#   'supervised',
#   'methods',
#   'while',
#   'in',
#   'typical',
#   'kdd',
#   'task',
#   'supervised',
#   'methods',
#   'can',
#   'not',
#   'be',
#   'used',
#   'due',
#   'to',
#   'unavailability',
#   'of',
#   'training',
#   'data.machine',
#   'learning',
#   'also',
#   'has',
#   'intimate',
#   'ties',
#   'to',
#   'optimization',
#   'many',
#   'learning',
#   'problems',
#   'are',
#   'formulated',
#   'as',
#   'minimization',
#   'of',
#   'some',
#   'loss',
#   'function',
#   'on',
#   'training',
#   'set',
#   'of',
#   'examples'],
#  ['loss',
#   'functions',
#   'express',
#   'discrepancy',
#   'between',
#   'predictions',
#   'of',
#   'model',
#   'being',
#   'trained',
#   'and',
#   'actual',
#   'problem',
#   'instances',
#   '.characterizing',
#   'generalization',
#   'of',
#   'various',
#   'learning',
#   'algorithms',
#   'is',
#   'an',
#   'active',
#   'topic',
#   'of',
#   'current',
#   'research',
#   'especially',
#   'for',
#   'deep',
#   'learning',
#   'algorithms.machine',
#   'learning',
#   'and',
#   'statistics',
#   'are',
#   'closely',
#   'related',
#   'fields',
#   'in',
#   'terms',
#   'of',
#   'methods',
#   'but',
#   'distinct',
#   'in',
#   'their',
#   'principal',
#   'goal',
#   'statistics',
#   'draws',
#   'population',
#   'inferences',
#   'from',
#   'sample',
#   'while',
#   'machine',
#   'learning',
#   'finds',
#   'generalizable',
#   'predictive',
#   'patterns'],
#  ['according',
#   'to',
#   'michael',
#   'i.',
#   'jordan',
#   'ideas',
#   'of',
#   'machine',
#   'learning',
#   'from',
#   'methodological',
#   'principles',
#   'to',
#   'theoretical',
#   'tools',
#   'have',
#   'had',
#   'long',
#   'pre-history',
#   'in',
#   'statistics'],
#  ['he',
#   'also',
#   'suggested',
#   'term',
#   'data',
#   'science',
#   'as',
#   'placeholder',
#   'to',
#   'call',
#   'overall',
#   'field.conventional',
#   'statistical',
#   'analyses',
#   'require',
#   'priori',
#   'selection',
#   'of',
#   'model',
#   'most',
#   'suitable',
#   'for',
#   'study',
#   'data',
#   'set'],
#  ['in',
#   'addition',
#   'only',
#   'significant',
#   'or',
#   'theoretically',
#   'relevant',
#   'variables',
#   'based',
#   'on',
#   'previous',
#   'experience',
#   'are',
#   'included',
#   'for',
#   'analysis'],
#  ['in',
#   'contrast',
#   'machine',
#   'learning',
#   'is',
#   'not',
#   'built',
#   'on',
#   'pre-structured',
#   'model',
#   'rather',
#   'data',
#   'shape',
#   'model',
#   'by',
#   'detecting',
#   'underlying',
#   'patterns'],
#  ['more',
#   'variables',
#   'used',
#   'to',
#   'train',
#   'model',
#   'more',
#   'accurate',
#   'ultimate',
#   'model',
#   'will',
#   'be.leo',
#   'breiman',
#   'distinguished',
#   'two',
#   'statistical',
#   'modeling',
#   'paradigms',
#   'data',
#   'model',
#   'and',
#   'algorithmic',
#   'wherein',
#   '``',
#   'algorithmic',
#   'model',
#   "''",
#   'means',
#   'more',
#   'or',
#   'less',
#   'machine',
#   'learning',
#   'algorithms',
#   'like',
#   'random',
#   'forest.some',
#   'statisticians',
#   'have',
#   'adopted',
#   'methods',
#   'from',
#   'machine',
#   'learning',
#   'leading',
#   'to',
#   'combined',
#   'field',
#   'that',
#   'they',
#   'call',
#   'statistical',
#   'learning.analytical',
#   'and',
#   'computational',
#   'techniques',
#   'derived',
#   'from',
#   'deep-rooted',
#   'physics',
#   'of',
#   'disordered',
#   'systems',
#   'can',
#   'be',
#   'extended',
#   'to',
#   'large-scale',
#   'problems',
#   'including',
#   'machine',
#   'learning',
#   'e.g.',
#   'to',
#   'analyse',
#   'weight',
#   'space',
#   'of',
#   'deep',
#   'neural',
#   'networks'],
#  ['statistical',
#   'physics',
#   'is',
#   'thus',
#   'finding',
#   'applications',
#   'in',
#   'area',
#   'of',
#   'medical',
#   'diagnostics.a',
#   'core',
#   'objective',
#   'of',
#   'learner',
#   'is',
#   'to',
#   'generalize',
#   'from',
#   'its',
#   'experience'],
#  ['generalization',
#   'in',
#   'this',
#   'context',
#   'is',
#   'ability',
#   'of',
#   'learning',
#   'machine',
#   'to',
#   'perform',
#   'accurately',
#   'on',
#   'new',
#   'unseen',
#   'examples/tasks',
#   'after',
#   'having',
#   'experienced',
#   'learning',
#   'data',
#   'set'],
#  ['training',
#   'examples',
#   'come',
#   'from',
#   'some',
#   'generally',
#   'unknown',
#   'probability',
#   'distribution',
#   'and',
#   'learner',
#   'has',
#   'to',
#   'build',
#   'general',
#   'model',
#   'about',
#   'this',
#   'space',
#   'that',
#   'enables',
#   'it',
#   'to',
#   'produce',
#   'sufficiently',
#   'accurate',
#   'predictions',
#   'in',
#   'new',
#   'cases.the',
#   'computational',
#   'analysis',
#   'of',
#   'machine',
#   'learning',
#   'algorithms',
#   'and',
#   'their',
#   'performance',
#   'is',
#   'branch',
#   'of',
#   'theoretical',
#   'computer',
#   'science',
#   'known',
#   'as',
#   'computational',
#   'learning',
#   'theory',
#   'via',
#   'probably',
#   'approximately',
#   'correct',
#   'learning',
#   'model'],
#  ['because',
#   'training',
#   'sets',
#   'are',
#   'finite',
#   'and',
#   'future',
#   'is',
#   'uncertain',
#   'learning',
#   'theory',
#   'usually',
#   'does',
#   'not',
#   'yield',
#   'guarantees',
#   'of',
#   'performance',
#   'of',
#   'algorithms'],
#  ['instead',
#   'probabilistic',
#   'bounds',
#   'on',
#   'performance',
#   'are',
#   'quite',
#   'common'],
#  ['bias–variance',
#   'decomposition',
#   'is',
#   'one',
#   'way',
#   'to',
#   'quantify',
#   'generalization',
#   'error.for',
#   'best',
#   'performance',
#   'in',
#   'context',
#   'of',
#   'generalization',
#   'complexity',
#   'of',
#   'hypothesis',
#   'should',
#   'match',
#   'complexity',
#   'of',
#   'function',
#   'underlying',
#   'data'],
#  ['if',
#   'hypothesis',
#   'is',
#   'less',
#   'complex',
#   'than',
#   'function',
#   'then',
#   'model',
#   'has',
#   'under',
#   'fitted',
#   'data'],
#  ['if',
#   'complexity',
#   'of',
#   'model',
#   'is',
#   'increased',
#   'in',
#   'response',
#   'then',
#   'training',
#   'error',
#   'decreases'],
#  ['but',
#   'if',
#   'hypothesis',
#   'is',
#   'too',
#   'complex',
#   'then',
#   'model',
#   'is',
#   'subject',
#   'to',
#   'overfitting',
#   'and',
#   'generalization',
#   'will',
#   'be',
#   'poorer.in',
#   'addition',
#   'to',
#   'performance',
#   'bounds',
#   'learning',
#   'theorists',
#   'study',
#   'time',
#   'complexity',
#   'and',
#   'feasibility',
#   'of',
#   'learning'],
#  ['in',
#   'computational',
#   'learning',
#   'theory',
#   'computation',
#   'is',
#   'considered',
#   'feasible',
#   'if',
#   'it',
#   'can',
#   'be',
#   'done',
#   'in',
#   'polynomial',
#   'time'],
#  ['there',
#   'are',
#   'two',
#   'kinds',
#   'of',
#   'time',
#   'complexity',
#   'results',
#   'positive',
#   'results',
#   'show',
#   'that',
#   'certain',
#   'class',
#   'of',
#   'functions',
#   'can',
#   'be',
#   'learned',
#   'in',
#   'polynomial',
#   'time'],
#  ['negative',
#   'results',
#   'show',
#   'that',
#   'certain',
#   'classes',
#   'can',
#   'not',
#   'be',
#   'learned',
#   'in',
#   'polynomial',
#   'time.machine',
#   'learning',
#   'approaches',
#   'are',
#   'traditionally',
#   'divided',
#   'into',
#   'three',
#   'broad',
#   'categories',
#   'which',
#   'correspond',
#   'to',
#   'learning',
#   'paradigms',
#   'depending',
#   'on',
#   'nature',
#   'of',
#   '``',
#   'signal',
#   "''",
#   'or',
#   '``',
#   'feedback',
#   "''",
#   'available',
#   'to',
#   'learning',
#   'system',
#   'although',
#   'each',
#   'algorithm',
#   'has',
#   'advantages',
#   'and',
#   'limitations',
#   'no',
#   'single',
#   'algorithm',
#   'works',
#   'for',
#   'all',
#   'problems.supervised',
#   'learning',
#   'algorithms',
#   'build',
#   'mathematical',
#   'model',
#   'of',
#   'set',
#   'of',
#   'data',
#   'that',
#   'contains',
#   'both',
#   'inputs',
#   'and',
#   'desired',
#   'outputs'],
#  ['data',
#   'known',
#   'as',
#   'training',
#   'data',
#   'consists',
#   'of',
#   'set',
#   'of',
#   'training',
#   'examples'],
#  ['each',
#   'training',
#   'example',
#   'has',
#   'one',
#   'or',
#   'more',
#   'inputs',
#   'and',
#   'desired',
#   'output',
#   'also',
#   'known',
#   'as',
#   'supervisory',
#   'signal'],
#  ['in',
#   'mathematical',
#   'model',
#   'each',
#   'training',
#   'example',
#   'is',
#   'represented',
#   'by',
#   'an',
#   'array',
#   'or',
#   'vector',
#   'sometimes',
#   'called',
#   'feature',
#   'vector',
#   'and',
#   'training',
#   'data',
#   'is',
#   'represented',
#   'by',
#   'matrix'],
#  ['through',
#   'iterative',
#   'optimization',
#   'of',
#   'an',
#   'objective',
#   'function',
#   'supervised',
#   'learning',
#   'algorithms',
#   'learn',
#   'function',
#   'that',
#   'can',
#   'be',
#   'used',
#   'to',
#   'predict',
#   'output',
#   'associated',
#   'with',
#   'new',
#   'inputs'],
#  ['an',
#   'optimal',
#   'function',
#   'allows',
#   'algorithm',
#   'to',
#   'correctly',
#   'determine',
#   'output',
#   'for',
#   'inputs',
#   'that',
#   'were',
#   'not',
#   'part',
#   'of',
#   'training',
#   'data'],
#  ['an',
#   'algorithm',
#   'that',
#   'improves',
#   'accuracy',
#   'of',
#   'its',
#   'outputs',
#   'or',
#   'predictions',
#   'over',
#   'time',
#   'is',
#   'said',
#   'to',
#   'have',
#   'learned',
#   'to',
#   'perform',
#   'that',
#   'task.types',
#   'of',
#   'supervised-learning',
#   'algorithms',
#   'include',
#   'active',
#   'learning',
#   'classification',
#   'and',
#   'regression'],
#  ['classification',
#   'algorithms',
#   'are',
#   'used',
#   'when',
#   'outputs',
#   'are',
#   'restricted',
#   'to',
#   'limited',
#   'set',
#   'of',
#   'values',
#   'while',
#   'regression',
#   'algorithms',
#   'are',
#   'used',
#   'when',
#   'outputs',
#   'can',
#   'take',
#   'any',
#   'numerical',
#   'value',
#   'within',
#   'range'],
#  ['for',
#   'example',
#   'in',
#   'classification',
#   'algorithm',
#   'that',
#   'filters',
#   'emails',
#   'input',
#   'is',
#   'an',
#   'incoming',
#   'email',
#   'and',
#   'output',
#   'is',
#   'folder',
#   'in',
#   'which',
#   'to',
#   'file',
#   'email'],
#  ['in',
#   'contrast',
#   'regression',
#   'is',
#   'used',
#   'for',
#   'tasks',
#   'such',
#   'as',
#   'predicting',
#   'person',
#   'height',
#   'based',
#   'on',
#   'factors',
#   'like',
#   'age',
#   'and',
#   'genetics',
#   'or',
#   'forecasting',
#   'future',
#   'temperatures',
#   'based',
#   'on',
#   'historical',
#   'data.similarity',
#   'learning',
#   'is',
#   'an',
#   'area',
#   'of',
#   'supervised',
#   'machine',
#   'learning',
#   'closely',
#   'related',
#   'to',
#   'regression',
#   'and',
#   'classification',
#   'but',
#   'goal',
#   'is',
#   'to',
#   'learn',
#   'from',
#   'examples',
#   'using',
#   'similarity',
#   'function',
#   'that',
#   'measures',
#   'how',
#   'similar',
#   'or',
#   'related',
#   'two',
#   'objects',
#   'are'],
#  ['it',
#   'has',
#   'applications',
#   'in',
#   'ranking',
#   'recommendation',
#   'systems',
#   'visual',
#   'identity',
#   'tracking',
#   'face',
#   'verification',
#   'and',
#   'speaker',
#   'verification.unsupervised',
#   'learning',
#   'algorithms',
#   'find',
#   'structures',
#   'in',
#   'data',
#   'that',
#   'has',
#   'not',
#   'been',
#   'labeled',
#   'classified',
#   'or',
#   'categorized'],
#  ['instead',
#   'of',
#   'responding',
#   'to',
#   'feedback',
#   'unsupervised',
#   'learning',
#   'algorithms',
#   'identify',
#   'commonalities',
#   'in',
#   'data',
#   'and',
#   'react',
#   'based',
#   'on',
#   'presence',
#   'or',
#   'absence',
#   'of',
#   'such',
#   'commonalities',
#   'in',
#   'each',
#   'new',
#   'piece',
#   'of',
#   'data'],
#  ['central',
#   'applications',
#   'of',
#   'unsupervised',
#   'machine',
#   'learning',
#   'include',
#   'clustering',
#   'dimensionality',
#   'and',
#   'density',
#   'estimation.cluster',
#   'analysis',
#   'is',
#   'assignment',
#   'of',
#   'set',
#   'of',
#   'observations',
#   'into',
#   'subsets',
#   'so',
#   'that',
#   'observations',
#   'within',
#   'same',
#   'cluster',
#   'are',
#   'similar',
#   'according',
#   'to',
#   'one',
#   'or',
#   'more',
#   'predesignated',
#   'criteria',
#   'while',
#   'observations',
#   'drawn',
#   'from',
#   'different',
#   'clusters',
#   'are',
#   'dissimilar'],
#  ['different',
#   'clustering',
#   'techniques',
#   'make',
#   'different',
#   'assumptions',
#   'on',
#   'structure',
#   'of',
#   'data',
#   'often',
#   'defined',
#   'by',
#   'some',
#   'similarity',
#   'metric',
#   'and',
#   'evaluated',
#   'for',
#   'example',
#   'by',
#   'internal',
#   'compactness',
#   'or',
#   'similarity',
#   'between',
#   'members',
#   'of',
#   'same',
#   'cluster',
#   'and',
#   'separation',
#   'difference',
#   'between',
#   'clusters'],
#  ['other',
#   'methods',
#   'are',
#   'based',
#   'on',
#   'estimated',
#   'density',
#   'and',
#   'graph',
#   'connectivity.a',
#   'special',
#   'type',
#   'of',
#   'unsupervised',
#   'learning',
#   'called',
#   'self-supervised',
#   'learning',
#   'involves',
#   'training',
#   'model',
#   'by',
#   'generating',
#   'supervisory',
#   'signal',
#   'from',
#   'data',
#   'itself.semi-supervised',
#   'learning',
#   'falls',
#   'between',
#   'unsupervised',
#   'learning',
#   'and',
#   'supervised',
#   'learning'],
#  ['some',
#   'of',
#   'training',
#   'examples',
#   'are',
#   'missing',
#   'training',
#   'labels',
#   'yet',
#   'many',
#   'machine-learning',
#   'researchers',
#   'have',
#   'found',
#   'that',
#   'unlabeled',
#   'data',
#   'when',
#   'used',
#   'in',
#   'conjunction',
#   'with',
#   'small',
#   'amount',
#   'of',
#   'labeled',
#   'data',
#   'can',
#   'produce',
#   'considerable',
#   'improvement',
#   'in',
#   'learning',
#   'accuracy.in',
#   'weakly',
#   'supervised',
#   'learning',
#   'training',
#   'labels',
#   'are',
#   'noisy',
#   'limited',
#   'or',
#   'imprecise',
#   'however',
#   'these',
#   'labels',
#   'are',
#   'often',
#   'cheaper',
#   'to',
#   'obtain',
#   'resulting',
#   'in',
#   'larger',
#   'effective',
#   'training',
#   'sets.reinforcement',
#   'learning',
#   'is',
#   'an',
#   'area',
#   'of',
#   'machine',
#   'learning',
#   'concerned',
#   'with',
#   'how',
#   'software',
#   'agents',
#   'ought',
#   'to',
#   'take',
#   'actions',
#   'in',
#   'an',
#   'environment',
#   'so',
#   'as',
#   'to',
#   'maximize',
#   'some',
#   'notion',
#   'of',
#   'cumulative',
#   'reward'],
#  ['due',
#   'to',
#   'its',
#   'generality',
#   'field',
#   'is',
#   'studied',
#   'in',
#   'many',
#   'other',
#   'disciplines',
#   'such',
#   'as',
#   'game',
#   'theory',
#   'control',
#   'theory',
#   'operations',
#   'research',
#   'information',
#   'theory',
#   'simulation-based',
#   'optimization',
#   'multi-agent',
#   'systems',
#   'swarm',
#   'intelligence',
#   'statistics',
#   'and',
#   'genetic',
#   'algorithms'],
#  ['in',
#   'reinforcement',
#   'learning',
#   'environment',
#   'is',
#   'typically',
#   'represented',
#   'as',
#   'markov',
#   'decision',
#   'process'],
#  ['many',
#   'reinforcement',
#   'learning',
#   'algorithms',
#   'use',
#   'dynamic',
#   'programming',
#   'techniques'],
#  ['reinforcement',
#   'learning',
#   'algorithms',
#   'do',
#   'not',
#   'assume',
#   'knowledge',
#   'of',
#   'an',
#   'exact',
#   'mathematical',
#   'model',
#   'of',
#   'mdp',
#   'and',
#   'are',
#   'used',
#   'when',
#   'exact',
#   'models',
#   'are',
#   'infeasible'],
#  ['reinforcement',
#   'learning',
#   'algorithms',
#   'are',
#   'used',
#   'in',
#   'autonomous',
#   'vehicles',
#   'or',
#   'in',
#   'learning',
#   'to',
#   'play',
#   'game',
#   'against',
#   'human',
#   'opponent.dimensionality',
#   'reduction',
#   'is',
#   'process',
#   'of',
#   'reducing',
#   'number',
#   'of',
#   'random',
#   'variables',
#   'under',
#   'consideration',
#   'by',
#   'obtaining',
#   'set',
#   'of',
#   'principal',
#   'variables'],
#  ['in',
#   'other',
#   'words',
#   'it',
#   'is',
#   'process',
#   'of',
#   'reducing',
#   'dimension',
#   'of',
#   'feature',
#   'set',
#   'also',
#   'called',
#   '``',
#   'number',
#   'of',
#   'features',
#   "''"],
#  ['most',
#   'of',
#   'dimensionality',
#   'reduction',
#   'techniques',
#   'can',
#   'be',
#   'considered',
#   'as',
#   'either',
#   'feature',
#   'elimination',
#   'or',
#   'extraction'],
#  ['one',
#   'of',
#   'popular',
#   'methods',
#   'of',
#   'dimensionality',
#   'reduction',
#   'is',
#   'principal',
#   'component',
#   'analysis'],
#  ['pca',
#   'involves',
#   'changing',
#   'higher-dimensional',
#   'data',
#   'to',
#   'smaller',
#   'space',
#   '.other',
#   'approaches',
#   'have',
#   'been',
#   'developed',
#   'which',
#   'do',
#   'not',
#   'fit',
#   'neatly',
#   'into',
#   'this',
#   'three-fold',
#   'categorization',
#   'and',
#   'sometimes',
#   'more',
#   'than',
#   'one',
#   'is',
#   'used',
#   'by',
#   'same',
#   'machine',
#   'learning',
#   'system'],
#  ['for',
#   'example',
#   'topic',
#   'modeling',
#   'meta-learning.self-learning',
#   'as',
#   'machine',
#   'learning',
#   'paradigm',
#   'was',
#   'introduced',
#   'in',
#   '1982',
#   'along',
#   'with',
#   'neural',
#   'network',
#   'capable',
#   'of',
#   'self-learning',
#   'named',
#   'crossbar',
#   'adaptive',
#   'array'],
#  ['it',
#   'gives',
#   'solution',
#   'to',
#   'problem',
#   'learning',
#   'without',
#   'any',
#   'external',
#   'reward',
#   'by',
#   'introducing',
#   'emotion',
#   'as',
#   'an',
#   'internal',
#   'reward'],
#  ['emotion',
#   'is',
#   'used',
#   'as',
#   'state',
#   'evaluation',
#   'of',
#   'self-learning',
#   'agent'],
#  ['caa',
#   'self-learning',
#   'algorithm',
#   'computes',
#   'in',
#   'crossbar',
#   'fashion',
#   'both',
#   'decisions',
#   'about',
#   'actions',
#   'and',
#   'emotions',
#   'about',
#   'consequence',
#   'situations'],
#  ['system',
#   'is',
#   'driven',
#   'by',
#   'interaction',
#   'between',
#   'cognition',
#   'and',
#   'emotion.it',
#   'is',
#   'system',
#   'with',
#   'only',
#   'one',
#   'input',
#   'situation',
#   'and',
#   'only',
#   'one',
#   'output',
#   'action'],
#  ['there',
#   'is',
#   'neither',
#   'separate',
#   'reinforcement',
#   'input',
#   'nor',
#   'an',
#   'advice',
#   'input',
#   'from',
#   'environment'],
#  ['backpropagated',
#   'value',
#   'is',
#   'emotion',
#   'toward',
#   'consequence',
#   'situation'],
#  ['caa',
#   'exists',
#   'in',
#   'two',
#   'environments',
#   'one',
#   'is',
#   'behavioral',
#   'environment',
#   'where',
#   'it',
#   'behaves',
#   'and',
#   'other',
#   'is',
#   'genetic',
#   'environment',
#   'wherefrom',
#   'it',
#   'initially',
#   'and',
#   'only',
#   'once',
#   'receives',
#   'initial',
#   'emotions',
#   'about',
#   'situations',
#   'to',
#   'be',
#   'encountered',
#   'in',
#   'behavioral',
#   'environment'],
#  ['after',
#   'receiving',
#   'genome',
#   'vector',
#   'from',
#   'genetic',
#   'environment',
#   'caa',
#   'learns',
#   'goal-seeking',
#   'behavior',
#   'in',
#   'an',
#   'environment',
#   'that',
#   'contains',
#   'both',
#   'desirable',
#   'and',
#   'undesirable',
#   'situations.several',
#   'learning',
#   'algorithms',
#   'aim',
#   'at',
#   'discovering',
#   'better',
#   'representations',
#   'of',
#   'inputs',
#   'provided',
#   'during',
#   'training'],
#  ['classic',
#   'examples',
#   'include',
#   'principal',
#   'component',
#   'analysis',
#   'and',
#   'cluster',
#   'analysis'],
#  ['feature',
#   'learning',
#   'algorithms',
#   'also',
#   'called',
#   'representation',
#   'learning',
#   'algorithms',
#   'often',
#   'attempt',
#   'to',
#   'preserve',
#   'information',
#   'in',
#   'their',
#   'input',
#   'but',
#   'also',
#   'transform',
#   'it',
#   'in',
#   'way',
#   'that',
#   'makes',
#   'it',
#   'useful',
#   'often',
#   'as',
#   'pre-processing',
#   'step',
#   'before',
#   'performing',
#   'classification',
#   'or',
#   'predictions'],
#  ['this',
#   'technique',
#   'allows',
#   'reconstruction',
#   'of',
#   'inputs',
#   'coming',
#   'from',
#   'unknown',
#   'data-generating',
#   'distribution',
#   'while',
#   'not',
#   'being',
#   'necessarily',
#   'faithful',
#   'to',
#   'configurations',
#   'that',
#   'are',
#   'implausible',
#   'under',
#   'that',
#   'distribution'],
#  ['this',
#   'replaces',
#   'manual',
#   'feature',
#   'engineering',
#   'and',
#   'allows',
#   'machine',
#   'to',
#   'both',
#   'learn',
#   'features',
#   'and',
#   'use',
#   'them',
#   'to',
#   'perform',
#   'specific',
#   'task.feature',
#   'learning',
#   'can',
#   'be',
#   'either',
#   'supervised',
#   'or',
#   'unsupervised'],
#  ['in',
#   'supervised',
#   'feature',
#   'learning',
#   'features',
#   'are',
#   'learned',
#   'using',
#   'labeled',
#   'input',
#   'data'],
#  ['examples',
#   'include',
#   'artificial',
#   'neural',
#   'networks',
#   'multilayer',
#   'perceptrons',
#   'and',
#   'supervised',
#   'dictionary',
#   'learning'],
#  ['in',
#   'unsupervised',
#   'feature',
#   'learning',
#   'features',
#   'are',
#   'learned',
#   'with',
#   'unlabeled',
#   'input',
#   'data'],
#  ['examples',
#   'include',
#   'dictionary',
#   'learning',
#   'independent',
#   'component',
#   'analysis',
#   'autoencoders',
#   'matrix',
#   'and',
#   'various',
#   'forms',
#   'of',
#   'clustering.manifold',
#   'learning',
#   'algorithms',
#   'attempt',
#   'to',
#   'do',
#   'so',
#   'under',
#   'constraint',
#   'that',
#   'learned',
#   'representation',
#   'is',
#   'low-dimensional'],
#  ['sparse',
#   'coding',
#   'algorithms',
#   'attempt',
#   'to',
#   'do',
#   'so',
#   'under',
#   'constraint',
#   'that',
#   'learned',
#   'representation',
#   'is',
#   'sparse',
#   'meaning',
#   'that',
#   'mathematical',
#   'model',
#   'has',
#   'many',
#   'zeros'],
#  ['multilinear',
#   'subspace',
#   'learning',
#   'algorithms',
#   'aim',
#   'to',
#   'learn',
#   'low-dimensional',
#   'representations',
#   'directly',
#   'from',
#   'tensor',
#   'representations',
#   'for',
#   'multidimensional',
#   'data',
#   'without',
#   'reshaping',
#   'them',
#   'into',
#   'higher-dimensional',
#   'vectors'],
#  ['deep',
#   'learning',
#   'algorithms',
#   'discover',
#   'multiple',
#   'levels',
#   'of',
#   'representation',
#   'or',
#   'hierarchy',
#   'of',
#   'features',
#   'with',
#   'higher-level',
#   'more',
#   'abstract',
#   'features',
#   'defined',
#   'in',
#   'terms',
#   'of',
#   'lower-level',
#   'features'],
#  ['it',
#   'has',
#   'been',
#   'argued',
#   'that',
#   'an',
#   'intelligent',
#   'machine',
#   'is',
#   'one',
#   'that',
#   'learns',
#   'representation',
#   'that',
#   'disentangles',
#   'underlying',
#   'factors',
#   'of',
#   'variation',
#   'that',
#   'explain',
#   'observed',
#   'data.feature',
#   'learning',
#   'is',
#   'motivated',
#   'by',
#   'fact',
#   'that',
#   'machine',
#   'learning',
#   'tasks',
#   'such',
#   'as',
#   'classification',
#   'often',
#   'require',
#   'input',
#   'that',
#   'is',
#   'mathematically',
#   'and',
#   'computationally',
#   'convenient',
#   'to',
#   'process'],
#  ['however',
#   'real-world',
#   'data',
#   'such',
#   'as',
#   'images',
#   'video',
#   'and',
#   'sensory',
#   'data',
#   'has',
#   'not',
#   'yielded',
#   'attempts',
#   'to',
#   'algorithmically',
#   'define',
#   'specific',
#   'features'],
#  ['an',
#   'alternative',
#   'is',
#   'to',
#   'discover',
#   'such',
#   'features',
#   'or',
#   'representations',
#   'through',
#   'examination',
#   'without',
#   'relying',
#   'on',
#   'explicit',
#   'algorithms.sparse',
#   'dictionary',
#   'learning',
#   'is',
#   'feature',
#   'learning',
#   'method',
#   'where',
#   'training',
#   'example',
#   'is',
#   'represented',
#   'as',
#   'linear',
#   'combination',
#   'of',
#   'basis',
#   'functions',
#   'and',
#   'assumed',
#   'to',
#   'be',
#   'sparse',
#   'matrix'],
#  ['method',
#   'is',
#   'strongly',
#   'np-hard',
#   'and',
#   'difficult',
#   'to',
#   'solve',
#   'approximately'],
#  ['popular',
#   'heuristic',
#   'method',
#   'for',
#   'sparse',
#   'dictionary',
#   'learning',
#   'is',
#   'k-svd',
#   'algorithm'],
#  ['sparse',
#   'dictionary',
#   'learning',
#   'has',
#   'been',
#   'applied',
#   'in',
#   'several',
#   'contexts'],
#  ['in',
#   'classification',
#   'problem',
#   'is',
#   'to',
#   'determine',
#   'class',
#   'to',
#   'which',
#   'previously',
#   'unseen',
#   'training',
#   'example',
#   'belongs'],
#  ['for',
#   'dictionary',
#   'where',
#   'each',
#   'class',
#   'has',
#   'already',
#   'been',
#   'built',
#   'new',
#   'training',
#   'example',
#   'is',
#   'associated',
#   'with',
#   'class',
#   'that',
#   'is',
#   'best',
#   'sparsely',
#   'represented',
#   'by',
#   'corresponding',
#   'dictionary'],
#  ['sparse',
#   'dictionary',
#   'learning',
#   'has',
#   'also',
#   'been',
#   'applied',
#   'in',
#   'image',
#   'de-noising'],
#  ['key',
#   'idea',
#   'is',
#   'that',
#   'clean',
#   'image',
#   'patch',
#   'can',
#   'be',
#   'sparsely',
#   'represented',
#   'by',
#   'an',
#   'image',
#   'dictionary',
#   'but',
#   'noise',
#   'can',
#   'not',
#   '.in',
#   'data',
#   'mining',
#   'anomaly',
#   'detection',
#   'also',
#   'known',
#   'as',
#   'outlier',
#   'detection',
#   'is',
#   'identification',
#   'of',
#   'rare',
#   'items',
#   'events',
#   'or',
#   'observations',
#   'which',
#   'raise',
#   'suspicions',
#   'by',
#   'differing',
#   'significantly',
#   'from',
#   'majority',
#   'of',
#   'data'],
#  ['typically',
#   'anomalous',
#   'items',
#   'represent',
#   'an',
#   'issue',
#   'such',
#   'as',
#   'bank',
#   'fraud',
#   'structural',
#   'defect',
#   'medical',
#   'problems',
#   'or',
#   'errors',
#   'in',
#   'text'],
#  ['anomalies',
#   'are',
#   'referred',
#   'to',
#   'as',
#   'outliers',
#   'novelties',
#   'noise',
#   'deviations',
#   'and',
#   'exceptions.in',
#   'particular',
#   'in',
#   'context',
#   'of',
#   'abuse',
#   'and',
#   'network',
#   'intrusion',
#   'detection',
#   'interesting',
#   'objects',
#   'are',
#   'often',
#   'not',
#   'rare',
#   'objects',
#   'but',
#   'unexpected',
#   'bursts',
#   'of',
#   'inactivity'],
#  ['this',
#   'pattern',
#   'does',
#   'not',
#   'adhere',
#   'to',
#   'common',
#   'statistical',
#   'definition',
#   'of',
#   'an',
#   'outlier',
#   'as',
#   'rare',
#   'object'],
#  ['many',
#   'outlier',
#   'detection',
#   'methods',
#   'will',
#   'fail',
#   'on',
#   'such',
#   'data',
#   'unless',
#   'aggregated',
#   'appropriately'],
#  ['instead',
#   'cluster',
#   'analysis',
#   'algorithm',
#   'may',
#   'be',
#   'able',
#   'to',
#   'detect',
#   'micro-clusters',
#   'formed',
#   'by',
#   'these',
#   'patterns.three',
#   'broad',
#   'categories',
#   'of',
#   'anomaly',
#   'detection',
#   'techniques',
#   'exist'],
#  ['unsupervised',
#   'anomaly',
#   'detection',
#   'techniques',
#   'detect',
#   'anomalies',
#   'in',
#   'an',
#   'unlabeled',
#   'test',
#   'data',
#   'set',
#   'under',
#   'assumption',
#   'that',
#   'majority',
#   'of',
#   'instances',
#   'in',
#   'data',
#   'set',
#   'are',
#   'normal',
#   'by',
#   'looking',
#   'for',
#   'instances',
#   'that',
#   'seem',
#   'to',
#   'fit',
#   'least',
#   'to',
#   'remainder',
#   'of',
#   'data',
#   'set'],
#  ['supervised',
#   'anomaly',
#   'detection',
#   'techniques',
#   'require',
#   'data',
#   'set',
#   'that',
#   'has',
#   'been',
#   'labeled',
#   'as',
#   '``',
#   'normal',
#   "''",
#   'and',
#   '``',
#   'abnormal',
#   "''",
#   'and',
#   'involves',
#   'training',
#   'classifier'],
#  ['semi-supervised',
#   'anomaly',
#   'detection',
#   'techniques',
#   'construct',
#   'model',
#   'representing',
#   'normal',
#   'behavior',
#   'from',
#   'given',
#   'normal',
#   'training',
#   'data',
#   'set',
#   'and',
#   'then',
#   'test',
#   'likelihood',
#   'of',
#   'test',
#   'instance',
#   'to',
#   'be',
#   'generated',
#   'by',
#   'model.robot',
#   'learning',
#   'is',
#   'inspired',
#   'by',
#   'multitude',
#   'of',
#   'machine',
#   'learning',
#   'methods',
#   'starting',
#   'from',
#   'supervised',
#   'learning',
#   'reinforcement',
#   'and',
#   'finally',
#   'meta-learning',
#   '.association',
#   'rule',
#   'learning',
#   'is',
#   'rule-based',
#   'machine',
#   'learning',
#   'method',
#   'for',
#   'discovering',
#   'relationships',
#   'between',
#   'variables',
#   'in',
#   'large',
#   'databases'],
#  ['it',
#   'is',
#   'intended',
#   'to',
#   'identify',
#   'strong',
#   'rules',
#   'discovered',
#   'in',
#   'databases',
#   'using',
#   'some',
#   'measure',
#   'of',
#   '``',
#   'interestingness',
#   "''",
#   '.rule-based',
#   'machine',
#   'learning',
#   'is',
#   'general',
#   'term',
#   'for',
#   'any',
#   'machine',
#   'learning',
#   'method',
#   'that',
#   'identifies',
#   'learns',
#   'or',
#   'evolves',
#   '``',
#   'rules',
#   "''",
#   'to',
#   'store',
#   'manipulate',
#   'or',
#   'apply',
#   'knowledge'],
#  ['defining',
#   'characteristic',
#   'of',
#   'rule-based',
#   'machine',
#   'learning',
#   'algorithm',
#   'is',
#   'identification',
#   'and',
#   'utilization',
#   'of',
#   'set',
#   'of',
#   'relational',
#   'rules',
#   'that',
#   'collectively',
#   'represent',
#   'knowledge',
#   'captured',
#   'by',
#   'system'],
#  ['this',
#   'is',
#   'in',
#   'contrast',
#   'to',
#   'other',
#   'machine',
#   'learning',
#   'algorithms',
#   'that',
#   'commonly',
#   'identify',
#   'singular',
#   'model',
#   'that',
#   'can',
#   'be',
#   'universally',
#   'applied',
#   'to',
#   'any',
#   'instance',
#   'in',
#   'order',
#   'to',
#   'make',
#   'prediction'],
#  ['rule-based',
#   'machine',
#   'learning',
#   'approaches',
#   'include',
#   'learning',
#   'classifier',
#   'systems',
#   'association',
#   'rule',
#   'learning',
#   'and',
#   'artificial',
#   'immune',
#   'systems.based',
#   'on',
#   'concept',
#   'of',
#   'strong',
#   'rules',
#   'rakesh',
#   'agrawal',
#   'tomasz',
#   'imieliński',
#   'and',
#   'arun',
#   'swami',
#   'introduced',
#   'association',
#   'rules',
#   'for',
#   'discovering',
#   'regularities',
#   'between',
#   'products',
#   'in',
#   'large-scale',
#   'transaction',
#   'data',
#   'recorded',
#   'by',
#   'point-of-sale',
#   'systems',
#   'in',
#   'supermarkets'],
#  ['learning',
#   'classifier',
#   'systems',
#   'are',
#   'family',
#   'of',
#   'rule-based',
#   'machine',
#   'learning',
#   'algorithms',
#   'that',
#   'combine',
#   'discovery',
#   'component',
#   'typically',
#   'genetic',
#   'algorithm',
#   'with',
#   'learning',
#   'component',
#   'performing',
#   'either',
#   'supervised',
#   'learning',
#   'reinforcement',
#   'learning',
#   'or',
#   'unsupervised',
#   'learning'],
#  ['they',
#   'seek',
#   'to',
#   'identify',
#   'set',
#   'of',
#   'context-dependent',
#   'rules',
#   'that',
#   'collectively',
#   'store',
#   'and',
#   'apply',
#   'knowledge',
#   'in',
#   'piecewise',
#   'manner',
#   'in',
#   'order',
#   'to',
#   'make',
#   'predictions.inductive',
#   'logic',
#   'programming',
#   'is',
#   'an',
#   'approach',
#   'to',
#   'rule',
#   'learning',
#   'using',
#   'logic',
#   'programming',
#   'as',
#   'uniform',
#   'representation',
#   'for',
#   'input',
#   'examples',
#   'background',
#   'knowledge',
#   'and',
#   'hypotheses'],
#  ['given',
#   'an',
#   'encoding',
#   'of',
#   'known',
#   'background',
#   'knowledge',
#   'and',
#   'set',
#   'of',
#   'examples',
#   'represented',
#   'as',
#   'logical',
#   'database',
#   'of',
#   'facts',
#   'an',
#   'ilp',
#   'system',
#   'will',
#   'derive',
#   'hypothesized',
#   'logic',
#   'program',
#   'that',
#   'entails',
#   'all',
#   'positive',
#   'and',
#   'no',
#   'negative',
#   'examples'],
#  ['inductive',
#   'programming',
#   'is',
#   'related',
#   'field',
#   'that',
#   'considers',
#   'any',
#   'kind',
#   'of',
#   'programming',
#   'language',
#   'for',
#   'representing',
#   'hypotheses',
#   'such',
#   'as',
#   'functional',
#   'programs.inductive',
#   'logic',
#   'programming',
#   'is',
#   'particularly',
#   'useful',
#   'in',
#   'bioinformatics',
#   'and',
#   'natural',
#   'language',
#   'processing'],
#  ['gordon',
#   'plotkin',
#   'and',
#   'ehud',
#   'shapiro',
#   'laid',
#   'initial',
#   'theoretical',
#   'foundation',
#   'for',
#   'inductive',
#   'machine',
#   'learning',
#   'in',
#   'logical',
#   'setting'],
#  ['shapiro',
#   'built',
#   'their',
#   'first',
#   'implementation',
#   'in',
#   '1981',
#   'prolog',
#   'program',
#   'that',
#   'inductively',
#   'inferred',
#   'logic',
#   'programs',
#   'from',
#   'positive',
#   'and',
#   'negative',
#   'examples'],
#  ['term',
#   'inductive',
#   'here',
#   'refers',
#   'to',
#   'philosophical',
#   'induction',
#   'suggesting',
#   'theory',
#   'to',
#   'explain',
#   'observed',
#   'facts',
#   'rather',
#   'than',
#   'mathematical',
#   'induction',
#   'proving',
#   'property',
#   'for',
#   'all',
#   'members',
#   'of',
#   'well-ordered',
#   'set'],
#  ['machine',
#   'learning',
#   'model',
#   'is',
#   'type',
#   'of',
#   'mathematical',
#   'model',
#   'that',
#   'once',
#   '``',
#   'trained',
#   "''",
#   'on',
#   'given',
#   'dataset',
#   'can',
#   'be',
#   'used',
#   'to',
#   'make',
#   'predictions',
#   'or',
#   'classifications',
#   'on',
#   'new',
#   'data'],
#  ['during',
#   'training',
#   'learning',
#   'algorithm',
#   'iteratively',
#   'adjusts',
#   'model',
#   'internal',
#   'parameters',
#   'to',
#   'minimize',
#   'errors',
#   'in',
#   'its',
#   'predictions'],
#  ['by',
#   'extension',
#   'term',
#   '``',
#   'model',
#   "''",
#   'can',
#   'refer',
#   'to',
#   'several',
#   'levels',
#   'of',
#   'specificity',
#   'from',
#   'general',
#   'class',
#   'of',
#   'models',
#   'and',
#   'their',
#   'associated',
#   'learning',
#   'algorithms',
#   'to',
#   'fully',
#   'trained',
#   'model',
#   'with',
#   'all',
#   'its',
#   'internal',
#   'parameters',
#   'tuned.various',
#   'types',
#   'of',
#   'models',
#   'have',
#   'been',
#   'used',
#   'and',
#   'researched',
#   'for',
#   'machine',
#   'learning',
#   'systems',
#   'picking',
#   'best',
#   'model',
#   'for',
#   'task',
#   'is',
#   'called',
#   'model',
#   'selection.artificial',
#   'neural',
#   'networks',
#   'or',
#   'connectionist',
#   'systems',
#   'are',
#   'computing',
#   'systems',
#   'vaguely',
#   'inspired',
#   'by',
#   'biological',
#   'neural',
#   'networks',
#   'that',
#   'constitute',
#   'animal',
#   'brains'],
#  ['such',
#   'systems',
#   '``',
#   'learn',
#   "''",
#   'to',
#   'perform',
#   'tasks',
#   'by',
#   'considering',
#   'examples',
#   'generally',
#   'without',
#   'being',
#   'programmed',
#   'with',
#   'any',
#   'task-specific',
#   'rules.an',
#   'ann',
#   'is',
#   'model',
#   'based',
#   'on',
#   'collection',
#   'of',
#   'connected',
#   'units',
#   'or',
#   'nodes',
#   'called',
#   '``',
#   'artificial',
#   'neurons',
#   "''",
#   'which',
#   'loosely',
#   'model',
#   'neurons',
#   'in',
#   'biological',
#   'brain'],
#  ['each',
#   'connection',
#   'like',
#   'synapses',
#   'in',
#   'biological',
#   'brain',
#   'can',
#   'transmit',
#   'information',
#   '``',
#   'signal',
#   "''",
#   'from',
#   'one',
#   'artificial',
#   'neuron',
#   'to',
#   'another'],
#  ['an',
#   'artificial',
#   'neuron',
#   'that',
#   'receives',
#   'signal',
#   'can',
#   'process',
#   'it',
#   'and',
#   'then',
#   'signal',
#   'additional',
#   'artificial',
#   'neurons',
#   'connected',
#   'to',
#   'it'],
#  ['in',
#   'common',
#   'ann',
#   'implementations',
#   'signal',
#   'at',
#   'connection',
#   'between',
#   'artificial',
#   'neurons',
#   'is',
#   'real',
#   'number',
#   'and',
#   'output',
#   'of',
#   'each',
#   'artificial',
#   'neuron',
#   'is',
#   'computed',
#   'by',
#   'some',
#   'non-linear',
#   'function',
#   'of',
#   'sum',
#   'of',
#   'its',
#   'inputs'],
# ...
#   'do',
#   'not',
#   'primarily',
#   'make',
#   'judgments',
#   'from',
#   'spatial',
#   'relationship',
#   'between',
#   'components',
#   'of',
#   'picture',
#   'and',
#   'they',
#   'learn',
#   'relationships',
#   'between',
#   'pixels',
#   'that',
#   'humans',
#   'are',
#   'oblivious',
#   'to',
#   'but',
#   'that',
#   'still',
#   'correlate',
#   'with',
#   'images',
#   'of',
#   'certain',
#   'types',
#   'of',
#   'real',
#   'objects'],
#  ['modifying',
#   'these',
#   'patterns',
#   'on',
#   'legitimate',
#   'image',
#   'can',
#   'result',
#   'in',
#   '``',
#   'adversarial',
#   "''",
#   'images',
#   'that',
#   'system',
#   'misclassifies.adversarial',
#   'vulnerabilities',
#   'can',
#   'also',
#   'result',
#   'in',
#   'nonlinear',
#   'systems',
#   'or',
#   'from',
#   'non-pattern',
#   'perturbations'],
#  ['for',
#   'some',
#   'systems',
#   'it',
#   'is',
#   'possible',
#   'to',
#   'change',
#   'output',
#   'by',
#   'only',
#   'changing',
#   'single',
#   'adversarially',
#   'chosen',
#   'pixel'],
#  ['machine',
#   'learning',
#   'models',
#   'are',
#   'often',
#   'vulnerable',
#   'to',
#   'manipulation',
#   'or',
#   'evasion',
#   'via',
#   'adversarial',
#   'machine',
#   'learning.researchers',
#   'have',
#   'demonstrated',
#   'how',
#   'backdoors',
#   'can',
#   'be',
#   'placed',
#   'undetectably',
#   'into',
#   'classifying',
#   'machine',
#   'learning',
#   'models',
#   'that',
#   'are',
#   'often',
#   'developed',
#   'or',
#   'trained',
#   'by',
#   'third',
#   'parties'],
#  ['parties',
#   'can',
#   'change',
#   'classification',
#   'of',
#   'any',
#   'input',
#   'including',
#   'in',
#   'cases',
#   'for',
#   'which',
#   'type',
#   'of',
#   'data/software',
#   'transparency',
#   'is',
#   'provided',
#   'possibly',
#   'including',
#   'white-box',
#   'access.classification',
#   'of',
#   'machine',
#   'learning',
#   'models',
#   'can',
#   'be',
#   'validated',
#   'by',
#   'accuracy',
#   'estimation',
#   'techniques',
#   'like',
#   'holdout',
#   'method',
#   'which',
#   'splits',
#   'data',
#   'in',
#   'training',
#   'and',
#   'test',
#   'set',
#   'and',
#   'evaluates',
#   'performance',
#   'of',
#   'training',
#   'model',
#   'on',
#   'test',
#   'set'],
#  ['in',
#   'comparison',
#   'k-fold-cross-validation',
#   'method',
#   'randomly',
#   'partitions',
#   'data',
#   'into',
#   'k',
#   'subsets',
#   'and',
#   'then',
#   'k',
#   'experiments',
#   'are',
#   'performed',
#   'each',
#   'respectively',
#   'considering',
#   '1',
#   'subset',
#   'for',
#   'evaluation',
#   'and',
#   'remaining',
#   'k-1',
#   'subsets',
#   'for',
#   'training',
#   'model'],
#  ['in',
#   'addition',
#   'to',
#   'holdout',
#   'and',
#   'cross-validation',
#   'methods',
#   'bootstrap',
#   'which',
#   'samples',
#   'n',
#   'instances',
#   'with',
#   'replacement',
#   'from',
#   'dataset',
#   'can',
#   'be',
#   'used',
#   'to',
#   'assess',
#   'model',
#   'accuracy.in',
#   'addition',
#   'to',
#   'overall',
#   'accuracy',
#   'investigators',
#   'frequently',
#   'report',
#   'sensitivity',
#   'and',
#   'specificity',
#   'meaning',
#   'true',
#   'positive',
#   'rate',
#   'and',
#   'true',
#   'negative',
#   'rate',
#   'respectively'],
#  ['similarly',
#   'investigators',
#   'sometimes',
#   'report',
#   'false',
#   'positive',
#   'rate',
#   'as',
#   'well',
#   'as',
#   'false',
#   'negative',
#   'rate'],
#  ['however',
#   'these',
#   'rates',
#   'are',
#   'ratios',
#   'that',
#   'fail',
#   'to',
#   'reveal',
#   'their',
#   'numerators',
#   'and',
#   'denominators'],
#  ['receiver',
#   'operating',
#   'characteristic',
#   'along',
#   'with',
#   'accompanying',
#   'area',
#   'under',
#   'roc',
#   'curve',
#   'offer',
#   'additional',
#   'tools',
#   'for',
#   'classification',
#   'model',
#   'assessment'],
#  ['higher',
#   'auc',
#   'is',
#   'associated',
#   'with',
#   'better',
#   'performing',
#   'model.the',
#   'ethics',
#   'of',
#   'artificial',
#   'intelligence',
#   'covers',
#   'broad',
#   'range',
#   'of',
#   'topics',
#   'within',
#   'field',
#   'that',
#   'are',
#   'considered',
#   'to',
#   'have',
#   'particular',
#   'ethical',
#   'stakes'],
#  ['this',
#   'includes',
#   'algorithmic',
#   'biases',
#   'automated',
#   'decision-making',
#   'accountability',
#   'privacy',
#   'and',
#   'regulation'],
#  ['it',
#   'also',
#   'covers',
#   'various',
#   'emerging',
#   'or',
#   'potential',
#   'future',
#   'challenges',
#   'such',
#   'as',
#   'machine',
#   'ethics',
#   'lethal',
#   'autonomous',
#   'weapon',
#   'systems',
#   'arms',
#   'race',
#   'dynamics',
#   'ai',
#   'safety',
#   'and',
#   'alignment',
#   'technological',
#   'unemployment',
#   'ai-enabled',
#   'misinformation',
#   'how',
#   'to',
#   'treat',
#   'certain',
#   'ai',
#   'systems',
#   'if',
#   'they',
#   'have',
#   'moral',
#   'status',
#   'artificial',
#   'superintelligence',
#   'and',
#   'existential',
#   'risks'],
#  ['different',
#   'machine',
#   'learning',
#   'approaches',
#   'can',
#   'suffer',
#   'from',
#   'different',
#   'data',
#   'biases'],
#  ['machine',
#   'learning',
#   'system',
#   'trained',
#   'specifically',
#   'on',
#   'current',
#   'customers',
#   'may',
#   'not',
#   'be',
#   'able',
#   'to',
#   'predict',
#   'needs',
#   'of',
#   'new',
#   'customer',
#   'groups',
#   'that',
#   'are',
#   'not',
#   'represented',
#   'in',
#   'training',
#   'data'],
#  ['when',
#   'trained',
#   'on',
#   'human-made',
#   'data',
#   'machine',
#   'learning',
#   'is',
#   'likely',
#   'to',
#   'pick',
#   'up',
#   'constitutional',
#   'and',
#   'unconscious',
#   'biases',
#   'already',
#   'present',
#   'in',
#   'society.systems',
#   'that',
#   'are',
#   'trained',
#   'on',
#   'datasets',
#   'collected',
#   'with',
#   'biases',
#   'may',
#   'exhibit',
#   'these',
#   'biases',
#   'upon',
#   'use',
#   'thus',
#   'digitizing',
#   'cultural',
#   'prejudices'],
#  ['for',
#   'example',
#   'in',
#   '1988',
#   'uk',
#   'commission',
#   'for',
#   'racial',
#   'equality',
#   'found',
#   'that',
#   'st.',
#   'george',
#   'medical',
#   'school',
#   'had',
#   'been',
#   'using',
#   'computer',
#   'program',
#   'trained',
#   'from',
#   'data',
#   'of',
#   'previous',
#   'admissions',
#   'staff',
#   'and',
#   'that',
#   'this',
#   'program',
#   'had',
#   'denied',
#   'nearly',
#   '60',
#   'candidates',
#   'who',
#   'were',
#   'found',
#   'to',
#   'either',
#   'be',
#   'women',
#   'or',
#   'have',
#   'non-european',
#   'sounding',
#   'names'],
#  ['using',
#   'job',
#   'hiring',
#   'data',
#   'from',
#   'firm',
#   'with',
#   'racist',
#   'hiring',
#   'policies',
#   'may',
#   'lead',
#   'to',
#   'machine',
#   'learning',
#   'system',
#   'duplicating',
#   'bias',
#   'by',
#   'scoring',
#   'job',
#   'applicants',
#   'by',
#   'similarity',
#   'to',
#   'previous',
#   'successful',
#   'applicants'],
#  ['another',
#   'example',
#   'includes',
#   'predictive',
#   'policing',
#   'company',
#   'geolitica',
#   'predictive',
#   'algorithm',
#   'that',
#   'resulted',
#   'in',
#   '``',
#   'disproportionately',
#   'high',
#   'levels',
#   'of',
#   'over-policing',
#   'in',
#   'low-income',
#   'and',
#   'minority',
#   'communities',
#   "''",
#   'after',
#   'being',
#   'trained',
#   'with',
#   'historical',
#   'crime',
#   'data.while',
#   'responsible',
#   'collection',
#   'of',
#   'data',
#   'and',
#   'documentation',
#   'of',
#   'algorithmic',
#   'rules',
#   'used',
#   'by',
#   'system',
#   'is',
#   'considered',
#   'critical',
#   'part',
#   'of',
#   'machine',
#   'learning',
#   'some',
#   'researchers',
#   'blame',
#   'lack',
#   'of',
#   'participation',
#   'and',
#   'representation',
#   'of',
#   'minority',
#   'population',
#   'in',
#   'field',
#   'of',
#   'ai',
#   'for',
#   'machine',
#   'learning',
#   'vulnerability',
#   'to',
#   'biases'],
#  ['in',
#   'fact',
#   'according',
#   'to',
#   'research',
#   'carried',
#   'out',
#   'by',
#   'computing',
#   'research',
#   'association',
#   'in',
#   '2021',
#   '``',
#   'female',
#   'faculty',
#   'merely',
#   'make',
#   'up',
#   '16.1',
#   "''",
#   'of',
#   'all',
#   'faculty',
#   'members',
#   'who',
#   'focus',
#   'on',
#   'ai',
#   'among',
#   'several',
#   'universities',
#   'around',
#   'world'],
#  ['furthermore',
#   'among',
#   'group',
#   'of',
#   '``',
#   'new',
#   'u.s.',
#   'resident',
#   'ai',
#   'phd',
#   'graduates',
#   "''",
#   '45',
#   'identified',
#   'as',
#   'white',
#   '22.4',
#   'as',
#   'asian',
#   '3.2',
#   'as',
#   'hispanic',
#   'and',
#   '2.4',
#   'as',
#   'african',
#   'american',
#   'which',
#   'further',
#   'demonstrates',
#   'lack',
#   'of',
#   'diversity',
#   'in',
#   'field',
#   'of',
#   'ai.language',
#   'models',
#   'learned',
#   'from',
#   'data',
#   'have',
#   'been',
#   'shown',
#   'to',
#   'contain',
#   'human-like',
#   'biases'],
#  ['because',
#   'human',
#   'languages',
#   'contain',
#   'biases',
#   'machines',
#   'trained',
#   'on',
#   'language',
#   'corpora',
#   'will',
#   'necessarily',
#   'also',
#   'learn',
#   'these',
#   'biases'],
#  ['in',
#   '2016',
#   'microsoft',
#   'tested',
#   'tay',
#   'chatbot',
#   'that',
#   'learned',
#   'from',
#   'twitter',
#   'and',
#   'it',
#   'quickly',
#   'picked',
#   'up',
#   'racist',
#   'and',
#   'sexist',
#   'language.in',
#   'an',
#   'experiment',
#   'carried',
#   'out',
#   'by',
#   'propublica',
#   'an',
#   'investigative',
#   'journalism',
#   'organization',
#   'machine',
#   'learning',
#   'algorithm',
#   'insight',
#   'into',
#   'recidivism',
#   'rates',
#   'among',
#   'prisoners',
#   'falsely',
#   'flagged',
#   '``',
#   'black',
#   'defendants',
#   'high',
#   'risk',
#   'twice',
#   'as',
#   'often',
#   'as',
#   'white',
#   'defendants',
#   "''"],
#  ['in',
#   '2015',
#   'google',
#   'photos',
#   'once',
#   'tagged',
#   'couple',
#   'of',
#   'black',
#   'people',
#   'as',
#   'gorillas',
#   'which',
#   'caused',
#   'controversy'],
#  ['gorilla',
#   'label',
#   'was',
#   'subsequently',
#   'removed',
#   'and',
#   'in',
#   '2023',
#   'it',
#   'still',
#   'can',
#   'not',
#   'recognize',
#   'gorillas'],
#  ['similar',
#   'issues',
#   'with',
#   'recognizing',
#   'non-white',
#   'people',
#   'have',
#   'been',
#   'found',
#   'in',
#   'many',
#   'other',
#   'systems.because',
#   'of',
#   'such',
#   'challenges',
#   'effective',
#   'use',
#   'of',
#   'machine',
#   'learning',
#   'may',
#   'take',
#   'longer',
#   'to',
#   'be',
#   'adopted',
#   'in',
#   'other',
#   'domains'],
#  ['concern',
#   'for',
#   'fairness',
#   'in',
#   'machine',
#   'learning',
#   'that',
#   'is',
#   'reducing',
#   'bias',
#   'in',
#   'machine',
#   'learning',
#   'and',
#   'propelling',
#   'its',
#   'use',
#   'for',
#   'human',
#   'good',
#   'is',
#   'increasingly',
#   'expressed',
#   'by',
#   'artificial',
#   'intelligence',
#   'scientists',
#   'including',
#   'fei-fei',
#   'li',
#   'who',
#   'said',
#   'that',
#   '``',
#   't',
#   'here',
#   'nothing',
#   'artificial',
#   'about',
#   'ai'],
#  ['it',
#   'inspired',
#   'by',
#   'people',
#   'it',
#   'created',
#   'by',
#   'people',
#   'and—most',
#   'importantly—it',
#   'impacts',
#   'people'],
#  ['it',
#   'is',
#   'powerful',
#   'tool',
#   'we',
#   'are',
#   'only',
#   'just',
#   'beginning',
#   'to',
#   'understand',
#   'and',
#   'that',
#   'is',
#   'profound',
#   'responsibility'],
#  ['``',
#   'there',
#   'are',
#   'concerns',
#   'among',
#   'health',
#   'care',
#   'professionals',
#   'that',
#   'these',
#   'systems',
#   'might',
#   'not',
#   'be',
#   'designed',
#   'in',
#   'public',
#   'interest',
#   'but',
#   'as',
#   'income-generating',
#   'machines'],
#  ['this',
#   'is',
#   'especially',
#   'true',
#   'in',
#   'united',
#   'states',
#   'where',
#   'there',
#   'is',
#   'long-standing',
#   'ethical',
#   'dilemma',
#   'of',
#   'improving',
#   'health',
#   'care',
#   'but',
#   'also',
#   'increasing',
#   'profits'],
#  ['for',
#   'example',
#   'algorithms',
#   'could',
#   'be',
#   'designed',
#   'to',
#   'provide',
#   'patients',
#   'with',
#   'unnecessary',
#   'tests',
#   'or',
#   'medication',
#   'in',
#   'which',
#   'algorithm',
#   'proprietary',
#   'owners',
#   'hold',
#   'stakes'],
#  ['there',
#   'is',
#   'potential',
#   'for',
#   'machine',
#   'learning',
#   'in',
#   'health',
#   'care',
#   'to',
#   'provide',
#   'professionals',
#   'an',
#   'additional',
#   'tool',
#   'to',
#   'diagnose',
#   'medicate',
#   'and',
#   'plan',
#   'recovery',
#   'paths',
#   'for',
#   'patients',
#   'but',
#   'this',
#   'requires',
#   'these',
#   'biases',
#   'to',
#   'be',
#   'mitigated.since',
#   '2010s',
#   'advances',
#   'in',
#   'both',
#   'machine',
#   'learning',
#   'algorithms',
#   'and',
#   'computer',
#   'hardware',
#   'have',
#   'led',
#   'to',
#   'more',
#   'efficient',
#   'methods',
#   'for',
#   'training',
#   'deep',
#   'neural',
#   'networks',
#   'that',
#   'contain',
#   'many',
#   'layers',
#   'of',
#   'nonlinear',
#   'hidden',
#   'units'],
#  ['by',
#   '2019',
#   'graphics',
#   'processing',
#   'units',
#   'often',
#   'with',
#   'ai-specific',
#   'enhancements',
#   'had',
#   'displaced',
#   'cpus',
#   'as',
#   'dominant',
#   'method',
#   'of',
#   'training',
#   'large-scale',
#   'commercial',
#   'cloud',
#   'ai'],
#  ['openai',
#   'estimated',
#   'hardware',
#   'compute',
#   'used',
#   'in',
#   'largest',
#   'deep',
#   'learning',
#   'projects',
#   'from',
#   'alexnet',
#   'to',
#   'alphazero',
#   'and',
#   'found',
#   '300,000-fold',
#   'increase',
#   'in',
#   'amount',
#   'of',
#   'compute',
#   'required',
#   'with',
#   'doubling-time',
#   'trendline',
#   'of',
#   '3.4',
#   'months.tensor',
#   'processing',
#   'units',
#   'are',
#   'specialized',
#   'hardware',
#   'accelerators',
#   'developed',
#   'by',
#   'google',
#   'specifically',
#   'for',
#   'machine',
#   'learning',
#   'workloads'],
#  ['unlike',
#   'general-purpose',
#   'gpus',
#   'and',
#   'fpgas',
#   'tpus',
#   'are',
#   'optimized',
#   'for',
#   'tensor',
#   'computations',
#   'making',
#   'them',
#   'particularly',
#   'efficient',
#   'for',
#   'deep',
#   'learning',
#   'tasks',
#   'such',
#   'as',
#   'training',
#   'and',
#   'inference'],
#  ['they',
#   'are',
#   'widely',
#   'used',
#   'in',
#   'google',
#   'cloud',
#   'ai',
#   'services',
#   'and',
#   'large-scale',
#   'machine',
#   'learning',
#   'models',
#   'like',
#   'google',
#   'deepmind',
#   'alphafold',
#   'and',
#   'large',
#   'language',
#   'models'],
#  ['tpus',
#   'leverage',
#   'matrix',
#   'multiplication',
#   'units',
#   'and',
#   'high-bandwidth',
#   'memory',
#   'to',
#   'accelerate',
#   'computations',
#   'while',
#   'maintaining',
#   'energy',
#   'efficiency'],
#  ['since',
#   'their',
#   'introduction',
#   'in',
#   '2016',
#   'tpus',
#   'have',
#   'become',
#   'key',
#   'component',
#   'of',
#   'ai',
#   'infrastructure',
#   'especially',
#   'in',
#   'cloud-based',
#   'environments.neuromorphic',
#   'computing',
#   'refers',
#   'to',
#   'class',
#   'of',
#   'computing',
#   'systems',
#   'designed',
#   'to',
#   'emulate',
#   'structure',
#   'and',
#   'functionality',
#   'of',
#   'biological',
#   'neural',
#   'networks'],
#  ['these',
#   'systems',
#   'may',
#   'be',
#   'implemented',
#   'through',
#   'software-based',
#   'simulations',
#   'on',
#   'conventional',
#   'hardware',
#   'or',
#   'through',
#   'specialized',
#   'hardware',
#   'architectures.a',
#   'physical',
#   'neural',
#   'network',
#   'is',
#   'specific',
#   'type',
#   'of',
#   'neuromorphic',
#   'hardware',
#   'that',
#   'relies',
#   'on',
#   'electrically',
#   'adjustable',
#   'materials',
#   'such',
#   'as',
#   'memristors',
#   'to',
#   'emulate',
#   'function',
#   'of',
#   'neural',
#   'synapses'],
#  ['term',
#   '``',
#   'physical',
#   'neural',
#   'network',
#   "''",
#   'highlights',
#   'use',
#   'of',
#   'physical',
#   'hardware',
#   'for',
#   'computation',
#   'as',
#   'opposed',
#   'to',
#   'software-based',
#   'implementations'],
#  ['it',
#   'broadly',
#   'refers',
#   'to',
#   'artificial',
#   'neural',
#   'networks',
#   'that',
#   'use',
#   'materials',
#   'with',
#   'adjustable',
#   'resistance',
#   'to',
#   'replicate',
#   'neural',
#   'synapses.embedded',
#   'machine',
#   'learning',
#   'is',
#   'sub-field',
#   'of',
#   'machine',
#   'learning',
#   'where',
#   'models',
#   'are',
#   'deployed',
#   'on',
#   'embedded',
#   'systems',
#   'with',
#   'limited',
#   'computing',
#   'resources',
#   'such',
#   'as',
#   'wearable',
#   'computers',
#   'edge',
#   'devices',
#   'and',
#   'microcontrollers'],
#  ['running',
#   'models',
#   'directly',
#   'on',
#   'these',
#   'devices',
#   'eliminates',
#   'need',
#   'to',
#   'transfer',
#   'and',
#   'store',
#   'data',
#   'on',
#   'cloud',
#   'servers',
#   'for',
#   'further',
#   'processing',
#   'thereby',
#   'reducing',
#   'risk',
#   'of',
#   'data',
#   'breaches',
#   'privacy',
#   'leaks',
#   'and',
#   'theft',
#   'of',
#   'intellectual',
#   'property',
#   'personal',
#   'data',
#   'and',
#   'business',
#   'secrets'],
#  ['embedded',
#   'machine',
#   'learning',
#   'can',
#   'be',
#   'achieved',
#   'through',
#   'various',
#   'techniques',
#   'such',
#   'as',
#   'hardware',
#   'approximate',
#   'and',
#   'model',
#   'optimization'],
#  ['common',
#   'optimization',
#   'techniques',
#   'include',
#   'pruning',
#   'quantization',
#   'knowledge',
#   'distillation',
#   'low-rank',
#   'factorization',
#   'network',
#   'architecture',
#   'search',
#   'and',
#   'parameter',
#   'sharing.software',
#   'suites',
#   'containing',
#   'variety',
#   'of',
#   'machine',
#   'learning',
#   'algorithms',
#   'include',
#   'following']]

# %%
vocab = set(word for sentence in tokenized_text for word in sentence)
word2idx = {word: idx for idx, word in enumerate(vocab)}
idx2word = {idx: word for word, idx in word2idx.items()}
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 2132

# %%
# Dataset creation
def make_sequences(tokenized_data, seq_len):
    sequences = []
    for sentence in tokenized_data:
        if len(sentence) >= seq_len + 1:
            for i in range(len(sentence) - seq_len):
                seq = sentence[i:i + seq_len]
                target = sentence[i + seq_len]
                sequences.append((seq, target))
    return sequences

# %%
sequences = make_sequences(tokenized_text, seq_len=5)
sequences
# Out:
# [(['machine', 'learning', 'is', 'field', 'of'], 'study'),
#  (['learning', 'is', 'field', 'of', 'study'], 'in'),
#  (['is', 'field', 'of', 'study', 'in'], 'artificial'),
#  (['field', 'of', 'study', 'in', 'artificial'], 'intelligence'),
#  (['of', 'study', 'in', 'artificial', 'intelligence'], 'concerned'),
#  (['study', 'in', 'artificial', 'intelligence', 'concerned'], 'with'),
#  (['in', 'artificial', 'intelligence', 'concerned', 'with'], 'development'),
#  (['artificial', 'intelligence', 'concerned', 'with', 'development'], 'and'),
#  (['intelligence', 'concerned', 'with', 'development', 'and'], 'study'),
#  (['concerned', 'with', 'development', 'and', 'study'], 'of'),
#  (['with', 'development', 'and', 'study', 'of'], 'statistical'),
#  (['development', 'and', 'study', 'of', 'statistical'], 'algorithms'),
#  (['and', 'study', 'of', 'statistical', 'algorithms'], 'that'),
#  (['study', 'of', 'statistical', 'algorithms', 'that'], 'can'),
#  (['of', 'statistical', 'algorithms', 'that', 'can'], 'learn'),
#  (['statistical', 'algorithms', 'that', 'can', 'learn'], 'from'),
#  (['algorithms', 'that', 'can', 'learn', 'from'], 'data'),
#  (['that', 'can', 'learn', 'from', 'data'], 'and'),
#  (['can', 'learn', 'from', 'data', 'and'], 'generalize'),
#  (['learn', 'from', 'data', 'and', 'generalize'], 'to'),
#  (['from', 'data', 'and', 'generalize', 'to'], 'unseen'),
#  (['data', 'and', 'generalize', 'to', 'unseen'], 'data'),
#  (['and', 'generalize', 'to', 'unseen', 'data'], 'and'),
#  (['generalize', 'to', 'unseen', 'data', 'and'], 'thus'),
#  (['to', 'unseen', 'data', 'and', 'thus'], 'perform'),
#  (['unseen', 'data', 'and', 'thus', 'perform'], 'tasks'),
#  (['data', 'and', 'thus', 'perform', 'tasks'], 'without'),
#  (['and', 'thus', 'perform', 'tasks', 'without'], 'explicit'),
#  (['thus', 'perform', 'tasks', 'without', 'explicit'], 'instructions'),
#  (['within', 'subdiscipline', 'in', 'machine', 'learning'], 'advances'),
#  (['subdiscipline', 'in', 'machine', 'learning', 'advances'], 'in'),
#  (['in', 'machine', 'learning', 'advances', 'in'], 'field'),
#  (['machine', 'learning', 'advances', 'in', 'field'], 'of'),
#  (['learning', 'advances', 'in', 'field', 'of'], 'deep'),
#  (['advances', 'in', 'field', 'of', 'deep'], 'learning'),
#  (['in', 'field', 'of', 'deep', 'learning'], 'have'),
#  (['field', 'of', 'deep', 'learning', 'have'], 'allowed'),
#  (['of', 'deep', 'learning', 'have', 'allowed'], 'neural'),
#  (['deep', 'learning', 'have', 'allowed', 'neural'], 'networks'),
#  (['learning', 'have', 'allowed', 'neural', 'networks'], 'class'),
#  (['have', 'allowed', 'neural', 'networks', 'class'], 'of'),
#  (['allowed', 'neural', 'networks', 'class', 'of'], 'statistical'),
#  (['neural', 'networks', 'class', 'of', 'statistical'], 'algorithms'),
#  (['networks', 'class', 'of', 'statistical', 'algorithms'], 'to'),
#  (['class', 'of', 'statistical', 'algorithms', 'to'], 'surpass'),
#  (['of', 'statistical', 'algorithms', 'to', 'surpass'], 'many'),
#  (['statistical', 'algorithms', 'to', 'surpass', 'many'], 'previous'),
#  (['algorithms', 'to', 'surpass', 'many', 'previous'], 'machine'),
#  (['to', 'surpass', 'many', 'previous', 'machine'], 'learning'),
#  (['surpass', 'many', 'previous', 'machine', 'learning'], 'approaches'),
#  (['many', 'previous', 'machine', 'learning', 'approaches'], 'in'),
#  (['previous', 'machine', 'learning', 'approaches', 'in'], 'performance.ml'),
#  (['machine', 'learning', 'approaches', 'in', 'performance.ml'], 'finds'),
#  (['learning', 'approaches', 'in', 'performance.ml', 'finds'], 'application'),
#  (['approaches', 'in', 'performance.ml', 'finds', 'application'], 'in'),
#  (['in', 'performance.ml', 'finds', 'application', 'in'], 'many'),
#  (['performance.ml', 'finds', 'application', 'in', 'many'], 'fields'),
#  (['finds', 'application', 'in', 'many', 'fields'], 'including'),
#  (['application', 'in', 'many', 'fields', 'including'], 'natural'),
#  (['in', 'many', 'fields', 'including', 'natural'], 'language'),
#  (['many', 'fields', 'including', 'natural', 'language'], 'processing'),
#  (['fields', 'including', 'natural', 'language', 'processing'], 'computer'),
#  (['including', 'natural', 'language', 'processing', 'computer'], 'vision'),
#  (['natural', 'language', 'processing', 'computer', 'vision'], 'speech'),
#  (['language', 'processing', 'computer', 'vision', 'speech'], 'recognition'),
#  (['processing', 'computer', 'vision', 'speech', 'recognition'], 'email'),
#  (['computer', 'vision', 'speech', 'recognition', 'email'], 'filtering'),
#  (['vision', 'speech', 'recognition', 'email', 'filtering'], 'agriculture'),
#  (['speech', 'recognition', 'email', 'filtering', 'agriculture'], 'and'),
#  (['recognition', 'email', 'filtering', 'agriculture', 'and'], 'medicine'),
#  (['application', 'of', 'ml', 'to', 'business'], 'problems'),
#  (['of', 'ml', 'to', 'business', 'problems'], 'is'),
#  (['ml', 'to', 'business', 'problems', 'is'], 'known'),
#  (['to', 'business', 'problems', 'is', 'known'], 'as'),
#  (['business', 'problems', 'is', 'known', 'as'], 'predictive'),
#  (['problems', 'is', 'known', 'as', 'predictive'], 'analytics.statistics'),
#  (['is', 'known', 'as', 'predictive', 'analytics.statistics'], 'and'),
#  (['known', 'as', 'predictive', 'analytics.statistics', 'and'],
#   'mathematical'),
#  (['as', 'predictive', 'analytics.statistics', 'and', 'mathematical'],
#   'optimization'),
#  (['predictive',
#    'analytics.statistics',
#    'and',
#    'mathematical',
#    'optimization'],
#   'methods'),
#  (['analytics.statistics', 'and', 'mathematical', 'optimization', 'methods'],
#   'comprise'),
#  (['and', 'mathematical', 'optimization', 'methods', 'comprise'],
#   'foundations'),
#  (['mathematical', 'optimization', 'methods', 'comprise', 'foundations'],
#   'of'),
#  (['optimization', 'methods', 'comprise', 'foundations', 'of'], 'machine'),
#  (['methods', 'comprise', 'foundations', 'of', 'machine'], 'learning'),
#  (['data', 'mining', 'is', 'related', 'field'], 'of'),
#  (['mining', 'is', 'related', 'field', 'of'], 'study'),
#  (['is', 'related', 'field', 'of', 'study'], 'focusing'),
#  (['related', 'field', 'of', 'study', 'focusing'], 'on'),
#  (['field', 'of', 'study', 'focusing', 'on'], 'exploratory'),
#  (['of', 'study', 'focusing', 'on', 'exploratory'], 'data'),
#  (['study', 'focusing', 'on', 'exploratory', 'data'], 'analysis'),
#  (['focusing', 'on', 'exploratory', 'data', 'analysis'], 'via'),
#  (['on', 'exploratory', 'data', 'analysis', 'via'], 'unsupervised'),
#  (['exploratory', 'data', 'analysis', 'via', 'unsupervised'], 'learning'),
#  (['from', 'theoretical', 'viewpoint', 'probably', 'approximately'],
#   'correct'),
#  (['theoretical', 'viewpoint', 'probably', 'approximately', 'correct'],
#   'learning'),
#  (['viewpoint', 'probably', 'approximately', 'correct', 'learning'],
#   'provides'),
#  (['probably', 'approximately', 'correct', 'learning', 'provides'],
#   'framework'),
#  (['approximately', 'correct', 'learning', 'provides', 'framework'], 'for'),
#  (['correct', 'learning', 'provides', 'framework', 'for'], 'describing'),
#  (['learning', 'provides', 'framework', 'for', 'describing'], 'machine'),
#  (['provides', 'framework', 'for', 'describing', 'machine'], 'learning.the'),
#  (['framework', 'for', 'describing', 'machine', 'learning.the'], 'term'),
#  (['for', 'describing', 'machine', 'learning.the', 'term'], 'machine'),
#  (['describing', 'machine', 'learning.the', 'term', 'machine'], 'learning'),
#  (['machine', 'learning.the', 'term', 'machine', 'learning'], 'was'),
#  (['learning.the', 'term', 'machine', 'learning', 'was'], 'coined'),
#  (['term', 'machine', 'learning', 'was', 'coined'], 'in'),
#  (['machine', 'learning', 'was', 'coined', 'in'], '1959'),
#  (['learning', 'was', 'coined', 'in', '1959'], 'by'),
#  (['was', 'coined', 'in', '1959', 'by'], 'arthur'),
#  (['coined', 'in', '1959', 'by', 'arthur'], 'samuel'),
#  (['in', '1959', 'by', 'arthur', 'samuel'], 'an'),
#  (['1959', 'by', 'arthur', 'samuel', 'an'], 'ibm'),
#  (['by', 'arthur', 'samuel', 'an', 'ibm'], 'employee'),
#  (['arthur', 'samuel', 'an', 'ibm', 'employee'], 'and'),
#  (['samuel', 'an', 'ibm', 'employee', 'and'], 'pioneer'),
#  (['an', 'ibm', 'employee', 'and', 'pioneer'], 'in'),
#  (['ibm', 'employee', 'and', 'pioneer', 'in'], 'field'),
#  (['employee', 'and', 'pioneer', 'in', 'field'], 'of'),
#  (['and', 'pioneer', 'in', 'field', 'of'], 'computer'),
#  (['pioneer', 'in', 'field', 'of', 'computer'], 'gaming'),
#  (['in', 'field', 'of', 'computer', 'gaming'], 'and'),
#  (['field', 'of', 'computer', 'gaming', 'and'], 'artificial'),
#  (['of', 'computer', 'gaming', 'and', 'artificial'], 'intelligence'),
#  (['synonym', 'self-teaching', 'computers', 'was', 'also'], 'used'),
#  (['self-teaching', 'computers', 'was', 'also', 'used'], 'in'),
#  (['computers', 'was', 'also', 'used', 'in'], 'this'),
#  (['was', 'also', 'used', 'in', 'this'], 'time'),
#  (['also', 'used', 'in', 'this', 'time'], 'period.although'),
#  (['used', 'in', 'this', 'time', 'period.although'], 'earliest'),
#  (['in', 'this', 'time', 'period.although', 'earliest'], 'machine'),
#  (['this', 'time', 'period.although', 'earliest', 'machine'], 'learning'),
#  (['time', 'period.although', 'earliest', 'machine', 'learning'], 'model'),
#  (['period.although', 'earliest', 'machine', 'learning', 'model'], 'was'),
#  (['earliest', 'machine', 'learning', 'model', 'was'], 'introduced'),
#  (['machine', 'learning', 'model', 'was', 'introduced'], 'in'),
#  (['learning', 'model', 'was', 'introduced', 'in'], '1950s'),
#  (['model', 'was', 'introduced', 'in', '1950s'], 'when'),
#  (['was', 'introduced', 'in', '1950s', 'when'], 'arthur'),
#  (['introduced', 'in', '1950s', 'when', 'arthur'], 'samuel'),
#  (['in', '1950s', 'when', 'arthur', 'samuel'], 'invented'),
#  (['1950s', 'when', 'arthur', 'samuel', 'invented'], 'program'),
#  (['when', 'arthur', 'samuel', 'invented', 'program'], 'that'),
#  (['arthur', 'samuel', 'invented', 'program', 'that'], 'calculated'),
#  (['samuel', 'invented', 'program', 'that', 'calculated'], 'winning'),
#  (['invented', 'program', 'that', 'calculated', 'winning'], 'chance'),
#  (['program', 'that', 'calculated', 'winning', 'chance'], 'in'),
#  (['that', 'calculated', 'winning', 'chance', 'in'], 'checkers'),
#  (['calculated', 'winning', 'chance', 'in', 'checkers'], 'for'),
#  (['winning', 'chance', 'in', 'checkers', 'for'], 'each'),
#  (['chance', 'in', 'checkers', 'for', 'each'], 'side'),
#  (['in', 'checkers', 'for', 'each', 'side'], 'history'),
#  (['checkers', 'for', 'each', 'side', 'history'], 'of'),
#  (['for', 'each', 'side', 'history', 'of'], 'machine'),
#  (['each', 'side', 'history', 'of', 'machine'], 'learning'),
#  (['side', 'history', 'of', 'machine', 'learning'], 'roots'),
#  (['history', 'of', 'machine', 'learning', 'roots'], 'back'),
#  (['of', 'machine', 'learning', 'roots', 'back'], 'to'),
#  (['machine', 'learning', 'roots', 'back', 'to'], 'decades'),
#  (['learning', 'roots', 'back', 'to', 'decades'], 'of'),
#  (['roots', 'back', 'to', 'decades', 'of'], 'human'),
#  (['back', 'to', 'decades', 'of', 'human'], 'desire'),
#  (['to', 'decades', 'of', 'human', 'desire'], 'and'),
#  (['decades', 'of', 'human', 'desire', 'and'], 'effort'),
#  (['of', 'human', 'desire', 'and', 'effort'], 'to'),
#  (['human', 'desire', 'and', 'effort', 'to'], 'study'),
#  (['desire', 'and', 'effort', 'to', 'study'], 'human'),
#  (['and', 'effort', 'to', 'study', 'human'], 'cognitive'),
#  (['effort', 'to', 'study', 'human', 'cognitive'], 'processes'),
#  (['in', '1949', 'canadian', 'psychologist', 'donald'], 'hebb'),
#  (['1949', 'canadian', 'psychologist', 'donald', 'hebb'], 'published'),
#  (['canadian', 'psychologist', 'donald', 'hebb', 'published'], 'book'),
#  (['psychologist', 'donald', 'hebb', 'published', 'book'], 'organization'),
#  (['donald', 'hebb', 'published', 'book', 'organization'], 'of'),
#  (['hebb', 'published', 'book', 'organization', 'of'], 'behavior'),
#  (['published', 'book', 'organization', 'of', 'behavior'], 'in'),
#  (['book', 'organization', 'of', 'behavior', 'in'], 'which'),
#  (['organization', 'of', 'behavior', 'in', 'which'], 'he'),
#  (['of', 'behavior', 'in', 'which', 'he'], 'introduced'),
#  (['behavior', 'in', 'which', 'he', 'introduced'], 'theoretical'),
#  (['in', 'which', 'he', 'introduced', 'theoretical'], 'neural'),
#  (['which', 'he', 'introduced', 'theoretical', 'neural'], 'structure'),
#  (['he', 'introduced', 'theoretical', 'neural', 'structure'], 'formed'),
#  (['introduced', 'theoretical', 'neural', 'structure', 'formed'], 'by'),
#  (['theoretical', 'neural', 'structure', 'formed', 'by'], 'certain'),
#  (['neural', 'structure', 'formed', 'by', 'certain'], 'interactions'),
#  (['structure', 'formed', 'by', 'certain', 'interactions'], 'among'),
#  (['formed', 'by', 'certain', 'interactions', 'among'], 'nerve'),
#  (['by', 'certain', 'interactions', 'among', 'nerve'], 'cells'),
#  (['hebb', 'model', 'of', 'neurons', 'interacting'], 'with'),
#  (['model', 'of', 'neurons', 'interacting', 'with'], 'one'),
#  (['of', 'neurons', 'interacting', 'with', 'one'], 'another'),
#  (['neurons', 'interacting', 'with', 'one', 'another'], 'set'),
#  (['interacting', 'with', 'one', 'another', 'set'], 'groundwork'),
#  (['with', 'one', 'another', 'set', 'groundwork'], 'for'),
#  (['one', 'another', 'set', 'groundwork', 'for'], 'how'),
#  (['another', 'set', 'groundwork', 'for', 'how'], 'ais'),
#  (['set', 'groundwork', 'for', 'how', 'ais'], 'and'),
#  (['groundwork', 'for', 'how', 'ais', 'and'], 'machine'),
#  (['for', 'how', 'ais', 'and', 'machine'], 'learning'),
#  (['how', 'ais', 'and', 'machine', 'learning'], 'algorithms'),
#  (['ais', 'and', 'machine', 'learning', 'algorithms'], 'work'),
#  (['and', 'machine', 'learning', 'algorithms', 'work'], 'under'),
#  (['machine', 'learning', 'algorithms', 'work', 'under'], 'nodes'),
#  (['learning', 'algorithms', 'work', 'under', 'nodes'], 'or'),
#  (['algorithms', 'work', 'under', 'nodes', 'or'], 'artificial'),
#  (['work', 'under', 'nodes', 'or', 'artificial'], 'neurons'),
#  (['under', 'nodes', 'or', 'artificial', 'neurons'], 'used'),
#  (['nodes', 'or', 'artificial', 'neurons', 'used'], 'by'),
#  (['or', 'artificial', 'neurons', 'used', 'by'], 'computers'),
#  (['artificial', 'neurons', 'used', 'by', 'computers'], 'to'),
#  (['neurons', 'used', 'by', 'computers', 'to'], 'communicate'),
#  (['used', 'by', 'computers', 'to', 'communicate'], 'data'),
#  (['other', 'researchers', 'who', 'have', 'studied'], 'human'),
#  (['researchers', 'who', 'have', 'studied', 'human'], 'cognitive'),
#  (['who', 'have', 'studied', 'human', 'cognitive'], 'systems'),
#  (['have', 'studied', 'human', 'cognitive', 'systems'], 'contributed'),
#  (['studied', 'human', 'cognitive', 'systems', 'contributed'], 'to'),
#  (['human', 'cognitive', 'systems', 'contributed', 'to'], 'modern'),
#  (['cognitive', 'systems', 'contributed', 'to', 'modern'], 'machine'),
#  (['systems', 'contributed', 'to', 'modern', 'machine'], 'learning'),
#  (['contributed', 'to', 'modern', 'machine', 'learning'], 'technologies'),
#  (['to', 'modern', 'machine', 'learning', 'technologies'], 'as'),
#  (['modern', 'machine', 'learning', 'technologies', 'as'], 'well'),
#  (['machine', 'learning', 'technologies', 'as', 'well'], 'including'),
#  (['learning', 'technologies', 'as', 'well', 'including'], 'logician'),
#  (['technologies', 'as', 'well', 'including', 'logician'], 'walter'),
#  (['as', 'well', 'including', 'logician', 'walter'], 'pitts'),
#  (['well', 'including', 'logician', 'walter', 'pitts'], 'and'),
#  (['including', 'logician', 'walter', 'pitts', 'and'], 'warren'),
#  (['logician', 'walter', 'pitts', 'and', 'warren'], 'mcculloch'),
#  (['walter', 'pitts', 'and', 'warren', 'mcculloch'], 'who'),
#  (['pitts', 'and', 'warren', 'mcculloch', 'who'], 'proposed'),
#  (['and', 'warren', 'mcculloch', 'who', 'proposed'], 'early'),
#  (['warren', 'mcculloch', 'who', 'proposed', 'early'], 'mathematical'),
#  (['mcculloch', 'who', 'proposed', 'early', 'mathematical'], 'models'),
#  (['who', 'proposed', 'early', 'mathematical', 'models'], 'of'),
#  (['proposed', 'early', 'mathematical', 'models', 'of'], 'neural'),
#  (['early', 'mathematical', 'models', 'of', 'neural'], 'networks'),
#  (['mathematical', 'models', 'of', 'neural', 'networks'], 'to'),
#  (['models', 'of', 'neural', 'networks', 'to'], 'come'),
#  (['of', 'neural', 'networks', 'to', 'come'], 'up'),
#  (['neural', 'networks', 'to', 'come', 'up'], 'with'),
#  (['networks', 'to', 'come', 'up', 'with'], 'algorithms'),
#  (['to', 'come', 'up', 'with', 'algorithms'], 'that'),
#  (['come', 'up', 'with', 'algorithms', 'that'], 'mirror'),
#  (['up', 'with', 'algorithms', 'that', 'mirror'], 'human'),
#  (['with', 'algorithms', 'that', 'mirror', 'human'], 'thought'),
#  (['algorithms', 'that', 'mirror', 'human', 'thought'], 'processes.by'),
#  (['that', 'mirror', 'human', 'thought', 'processes.by'], 'early'),
#  (['mirror', 'human', 'thought', 'processes.by', 'early'], '1960s'),
#  (['human', 'thought', 'processes.by', 'early', '1960s'], 'an'),
#  (['thought', 'processes.by', 'early', '1960s', 'an'], 'experimental'),
#  (['processes.by', 'early', '1960s', 'an', 'experimental'], '``'),
#  (['early', '1960s', 'an', 'experimental', '``'], 'learning'),
#  (['1960s', 'an', 'experimental', '``', 'learning'], 'machine'),
#  (['an', 'experimental', '``', 'learning', 'machine'], "''"),
#  (['experimental', '``', 'learning', 'machine', "''"], 'with'),
#  (['``', 'learning', 'machine', "''", 'with'], 'punched'),
#  (['learning', 'machine', "''", 'with', 'punched'], 'tape'),
#  (['machine', "''", 'with', 'punched', 'tape'], 'memory'),
#  (["''", 'with', 'punched', 'tape', 'memory'], 'called'),
#  (['with', 'punched', 'tape', 'memory', 'called'], 'cybertron'),
#  (['punched', 'tape', 'memory', 'called', 'cybertron'], 'had'),
#  (['tape', 'memory', 'called', 'cybertron', 'had'], 'been'),
#  (['memory', 'called', 'cybertron', 'had', 'been'], 'developed'),
#  (['called', 'cybertron', 'had', 'been', 'developed'], 'by'),
#  (['cybertron', 'had', 'been', 'developed', 'by'], 'raytheon'),
#  (['had', 'been', 'developed', 'by', 'raytheon'], 'company'),
#  (['been', 'developed', 'by', 'raytheon', 'company'], 'to'),
#  (['developed', 'by', 'raytheon', 'company', 'to'], 'analyse'),
#  (['by', 'raytheon', 'company', 'to', 'analyse'], 'sonar'),
#  (['raytheon', 'company', 'to', 'analyse', 'sonar'], 'signals'),
#  (['company', 'to', 'analyse', 'sonar', 'signals'], 'electrocardiograms'),
#  (['to', 'analyse', 'sonar', 'signals', 'electrocardiograms'], 'and'),
#  (['analyse', 'sonar', 'signals', 'electrocardiograms', 'and'], 'speech'),
#  (['sonar', 'signals', 'electrocardiograms', 'and', 'speech'], 'patterns'),
#  (['signals', 'electrocardiograms', 'and', 'speech', 'patterns'], 'using'),
#  (['electrocardiograms', 'and', 'speech', 'patterns', 'using'], 'rudimentary'),
#  (['and', 'speech', 'patterns', 'using', 'rudimentary'], 'reinforcement'),
#  (['speech', 'patterns', 'using', 'rudimentary', 'reinforcement'], 'learning'),
#  (['it', 'was', 'repetitively', '``', 'trained'], "''"),
#  (['was', 'repetitively', '``', 'trained', "''"], 'by'),
#  (['repetitively', '``', 'trained', "''", 'by'], 'human'),
#  (['``', 'trained', "''", 'by', 'human'], 'operator/teacher'),
#  (['trained', "''", 'by', 'human', 'operator/teacher'], 'to'),
#  (["''", 'by', 'human', 'operator/teacher', 'to'], 'recognize'),
#  (['by', 'human', 'operator/teacher', 'to', 'recognize'], 'patterns'),
#  (['human', 'operator/teacher', 'to', 'recognize', 'patterns'], 'and'),
#  (['operator/teacher', 'to', 'recognize', 'patterns', 'and'], 'equipped'),
#  (['to', 'recognize', 'patterns', 'and', 'equipped'], 'with'),
#  (['recognize', 'patterns', 'and', 'equipped', 'with'], '``'),
#  (['patterns', 'and', 'equipped', 'with', '``'], 'goof'),
#  (['and', 'equipped', 'with', '``', 'goof'], "''"),
#  (['equipped', 'with', '``', 'goof', "''"], 'button'),
#  (['with', '``', 'goof', "''", 'button'], 'to'),
#  (['``', 'goof', "''", 'button', 'to'], 'cause'),
#  (['goof', "''", 'button', 'to', 'cause'], 'it'),
#  (["''", 'button', 'to', 'cause', 'it'], 'to'),
#  (['button', 'to', 'cause', 'it', 'to'], 'reevaluate'),
#  (['to', 'cause', 'it', 'to', 'reevaluate'], 'incorrect'),
#  (['cause', 'it', 'to', 'reevaluate', 'incorrect'], 'decisions'),
#  (['representative', 'book', 'on', 'research', 'into'], 'machine'),
#  (['book', 'on', 'research', 'into', 'machine'], 'learning'),
#  (['on', 'research', 'into', 'machine', 'learning'], 'during'),
#  (['research', 'into', 'machine', 'learning', 'during'], '1960s'),
#  (['into', 'machine', 'learning', 'during', '1960s'], 'was'),
#  (['machine', 'learning', 'during', '1960s', 'was'], 'nilsson'),
#  (['learning', 'during', '1960s', 'was', 'nilsson'], 'book'),
#  (['during', '1960s', 'was', 'nilsson', 'book'], 'on'),
#  (['1960s', 'was', 'nilsson', 'book', 'on'], 'learning'),
#  (['was', 'nilsson', 'book', 'on', 'learning'], 'machines'),
#  (['nilsson', 'book', 'on', 'learning', 'machines'], 'dealing'),
#  (['book', 'on', 'learning', 'machines', 'dealing'], 'mostly'),
#  (['on', 'learning', 'machines', 'dealing', 'mostly'], 'with'),
#  (['learning', 'machines', 'dealing', 'mostly', 'with'], 'machine'),
#  (['machines', 'dealing', 'mostly', 'with', 'machine'], 'learning'),
#  (['dealing', 'mostly', 'with', 'machine', 'learning'], 'for'),
#  (['mostly', 'with', 'machine', 'learning', 'for'], 'pattern'),
#  (['with', 'machine', 'learning', 'for', 'pattern'], 'classification'),
#  (['interest', 'related', 'to', 'pattern', 'recognition'], 'continued'),
#  (['related', 'to', 'pattern', 'recognition', 'continued'], 'into'),
#  (['to', 'pattern', 'recognition', 'continued', 'into'], '1970s'),
#  (['pattern', 'recognition', 'continued', 'into', '1970s'], 'as'),
#  (['recognition', 'continued', 'into', '1970s', 'as'], 'described'),
#  (['continued', 'into', '1970s', 'as', 'described'], 'by'),
#  (['into', '1970s', 'as', 'described', 'by'], 'duda'),
#  (['1970s', 'as', 'described', 'by', 'duda'], 'and'),
#  (['as', 'described', 'by', 'duda', 'and'], 'hart'),
#  (['described', 'by', 'duda', 'and', 'hart'], 'in'),
#  (['by', 'duda', 'and', 'hart', 'in'], '1973'),
#  (['in', '1981', 'report', 'was', 'given'], 'on'),
#  (['1981', 'report', 'was', 'given', 'on'], 'using'),
#  (['report', 'was', 'given', 'on', 'using'], 'teaching'),
#  (['was', 'given', 'on', 'using', 'teaching'], 'strategies'),
#  (['given', 'on', 'using', 'teaching', 'strategies'], 'so'),
#  (['on', 'using', 'teaching', 'strategies', 'so'], 'that'),
#  (['using', 'teaching', 'strategies', 'so', 'that'], 'an'),
#  (['teaching', 'strategies', 'so', 'that', 'an'], 'artificial'),
#  (['strategies', 'so', 'that', 'an', 'artificial'], 'neural'),
#  (['so', 'that', 'an', 'artificial', 'neural'], 'network'),
#  (['that', 'an', 'artificial', 'neural', 'network'], 'learns'),
#  (['an', 'artificial', 'neural', 'network', 'learns'], 'to'),
#  (['artificial', 'neural', 'network', 'learns', 'to'], 'recognize'),
#  (['neural', 'network', 'learns', 'to', 'recognize'], '40'),
#  (['network', 'learns', 'to', 'recognize', '40'], 'characters'),
#  (['learns', 'to', 'recognize', '40', 'characters'], 'from'),
#  (['to', 'recognize', '40', 'characters', 'from'], 'computer'),
#  (['recognize', '40', 'characters', 'from', 'computer'], 'terminal.tom'),
#  (['40', 'characters', 'from', 'computer', 'terminal.tom'], 'm.'),
#  (['characters', 'from', 'computer', 'terminal.tom', 'm.'], 'mitchell'),
#  (['from', 'computer', 'terminal.tom', 'm.', 'mitchell'], 'provided'),
#  (['computer', 'terminal.tom', 'm.', 'mitchell', 'provided'], 'widely'),
#  (['terminal.tom', 'm.', 'mitchell', 'provided', 'widely'], 'quoted'),
#  (['m.', 'mitchell', 'provided', 'widely', 'quoted'], 'more'),
#  (['mitchell', 'provided', 'widely', 'quoted', 'more'], 'formal'),
#  (['provided', 'widely', 'quoted', 'more', 'formal'], 'definition'),
#  (['widely', 'quoted', 'more', 'formal', 'definition'], 'of'),
#  (['quoted', 'more', 'formal', 'definition', 'of'], 'algorithms'),
#  (['more', 'formal', 'definition', 'of', 'algorithms'], 'studied'),
#  (['formal', 'definition', 'of', 'algorithms', 'studied'], 'in'),
#  (['definition', 'of', 'algorithms', 'studied', 'in'], 'machine'),
#  (['of', 'algorithms', 'studied', 'in', 'machine'], 'learning'),
#  (['algorithms', 'studied', 'in', 'machine', 'learning'], 'field'),
#  (['studied', 'in', 'machine', 'learning', 'field'], '``'),
#  (['in', 'machine', 'learning', 'field', '``'], 'computer'),
#  (['machine', 'learning', 'field', '``', 'computer'], 'program'),
#  (['learning', 'field', '``', 'computer', 'program'], 'is'),
#  (['field', '``', 'computer', 'program', 'is'], 'said'),
#  (['``', 'computer', 'program', 'is', 'said'], 'to'),
#  (['computer', 'program', 'is', 'said', 'to'], 'learn'),
#  (['program', 'is', 'said', 'to', 'learn'], 'from'),
#  (['is', 'said', 'to', 'learn', 'from'], 'experience'),
#  (['said', 'to', 'learn', 'from', 'experience'], 'e'),
#  (['to', 'learn', 'from', 'experience', 'e'], 'with'),
#  (['learn', 'from', 'experience', 'e', 'with'], 'respect'),
#  (['from', 'experience', 'e', 'with', 'respect'], 'to'),
#  (['experience', 'e', 'with', 'respect', 'to'], 'some'),
#  (['e', 'with', 'respect', 'to', 'some'], 'class'),
#  (['with', 'respect', 'to', 'some', 'class'], 'of'),
#  (['respect', 'to', 'some', 'class', 'of'], 'tasks'),
#  (['to', 'some', 'class', 'of', 'tasks'], 't'),
#  (['some', 'class', 'of', 'tasks', 't'], 'and'),
#  (['class', 'of', 'tasks', 't', 'and'], 'performance'),
#  (['of', 'tasks', 't', 'and', 'performance'], 'measure'),
#  (['tasks', 't', 'and', 'performance', 'measure'], 'p'),
#  (['t', 'and', 'performance', 'measure', 'p'], 'if'),
#  (['and', 'performance', 'measure', 'p', 'if'], 'its'),
#  (['performance', 'measure', 'p', 'if', 'its'], 'performance'),
#  (['measure', 'p', 'if', 'its', 'performance'], 'at'),
#  (['p', 'if', 'its', 'performance', 'at'], 'tasks'),
#  (['if', 'its', 'performance', 'at', 'tasks'], 'in'),
#  (['its', 'performance', 'at', 'tasks', 'in'], 't'),
#  (['performance', 'at', 'tasks', 'in', 't'], 'as'),
#  (['at', 'tasks', 'in', 't', 'as'], 'measured'),
#  (['tasks', 'in', 't', 'as', 'measured'], 'by'),
#  (['in', 't', 'as', 'measured', 'by'], 'p'),
#  (['t', 'as', 'measured', 'by', 'p'], 'improves'),
#  (['as', 'measured', 'by', 'p', 'improves'], 'with'),
#  (['measured', 'by', 'p', 'improves', 'with'], 'experience'),
#  (['by', 'p', 'improves', 'with', 'experience'], 'e.'),
#  (['p', 'improves', 'with', 'experience', 'e.'], "''"),
#  (['improves', 'with', 'experience', 'e.', "''"], 'this'),
#  (['with', 'experience', 'e.', "''", 'this'], 'definition'),
#  (['experience', 'e.', "''", 'this', 'definition'], 'of'),
#  (['e.', "''", 'this', 'definition', 'of'], 'tasks'),
#  (["''", 'this', 'definition', 'of', 'tasks'], 'in'),
#  (['this', 'definition', 'of', 'tasks', 'in'], 'which'),
#  (['definition', 'of', 'tasks', 'in', 'which'], 'machine'),
#  (['of', 'tasks', 'in', 'which', 'machine'], 'learning'),
#  (['tasks', 'in', 'which', 'machine', 'learning'], 'is'),
#  (['in', 'which', 'machine', 'learning', 'is'], 'concerned'),
#  (['which', 'machine', 'learning', 'is', 'concerned'], 'offers'),
#  (['machine', 'learning', 'is', 'concerned', 'offers'], 'fundamentally'),
#  (['learning', 'is', 'concerned', 'offers', 'fundamentally'], 'operational'),
#  (['is', 'concerned', 'offers', 'fundamentally', 'operational'], 'definition'),
#  (['concerned', 'offers', 'fundamentally', 'operational', 'definition'],
#   'rather'),
#  (['offers', 'fundamentally', 'operational', 'definition', 'rather'], 'than'),
#  (['fundamentally', 'operational', 'definition', 'rather', 'than'],
#   'defining'),
#  (['operational', 'definition', 'rather', 'than', 'defining'], 'field'),
#  (['definition', 'rather', 'than', 'defining', 'field'], 'in'),
#  (['rather', 'than', 'defining', 'field', 'in'], 'cognitive'),
#  (['than', 'defining', 'field', 'in', 'cognitive'], 'terms'),
#  (['this', 'follows', 'alan', 'turing', 'proposal'], 'in'),
#  (['follows', 'alan', 'turing', 'proposal', 'in'], 'his'),
#  (['alan', 'turing', 'proposal', 'in', 'his'], 'paper'),
#  (['turing', 'proposal', 'in', 'his', 'paper'], '``'),
#  (['proposal', 'in', 'his', 'paper', '``'], 'computing'),
#  (['in', 'his', 'paper', '``', 'computing'], 'machinery'),
#  (['his', 'paper', '``', 'computing', 'machinery'], 'and'),
#  (['paper', '``', 'computing', 'machinery', 'and'], 'intelligence'),
#  (['``', 'computing', 'machinery', 'and', 'intelligence'], "''"),
#  (['computing', 'machinery', 'and', 'intelligence', "''"], 'in'),
#  (['machinery', 'and', 'intelligence', "''", 'in'], 'which'),
#  (['and', 'intelligence', "''", 'in', 'which'], 'question'),
#  (['intelligence', "''", 'in', 'which', 'question'], '``'),
#  (["''", 'in', 'which', 'question', '``'], 'can'),
#  (['in', 'which', 'question', '``', 'can'], 'machines'),
#  (['which', 'question', '``', 'can', 'machines'], 'think'),
#  (['question', '``', 'can', 'machines', 'think'], "''"),
#  (['is', 'replaced', 'with', 'question', '``'], 'can'),
#  (['replaced', 'with', 'question', '``', 'can'], 'machines'),
#  (['with', 'question', '``', 'can', 'machines'], 'do'),
#  (['question', '``', 'can', 'machines', 'do'], 'what'),
#  (['``', 'can', 'machines', 'do', 'what'], 'we'),
#  (['can', 'machines', 'do', 'what', 'we'], 'can'),
#  (['machines', 'do', 'what', 'we', 'can'], 'do'),
#  (['``', '.modern-day', 'machine', 'learning', 'has'], 'two'),
#  (['.modern-day', 'machine', 'learning', 'has', 'two'], 'objectives'),
#  (['one', 'is', 'to', 'classify', 'data'], 'based'),
#  (['is', 'to', 'classify', 'data', 'based'], 'on'),
#  (['to', 'classify', 'data', 'based', 'on'], 'models'),
#  (['classify', 'data', 'based', 'on', 'models'], 'which'),
#  (['data', 'based', 'on', 'models', 'which'], 'have'),
#  (['based', 'on', 'models', 'which', 'have'], 'been'),
#  (['on', 'models', 'which', 'have', 'been'], 'developed'),
#  (['models', 'which', 'have', 'been', 'developed'], 'other'),
#  (['which', 'have', 'been', 'developed', 'other'], 'purpose'),
#  (['have', 'been', 'developed', 'other', 'purpose'], 'is'),
#  (['been', 'developed', 'other', 'purpose', 'is'], 'to'),
#  (['developed', 'other', 'purpose', 'is', 'to'], 'make'),
#  (['other', 'purpose', 'is', 'to', 'make'], 'predictions'),
#  (['purpose', 'is', 'to', 'make', 'predictions'], 'for'),
#  (['is', 'to', 'make', 'predictions', 'for'], 'future'),
#  (['to', 'make', 'predictions', 'for', 'future'], 'outcomes'),
#  (['make', 'predictions', 'for', 'future', 'outcomes'], 'based'),
#  (['predictions', 'for', 'future', 'outcomes', 'based'], 'on'),
#  (['for', 'future', 'outcomes', 'based', 'on'], 'these'),
#  (['future', 'outcomes', 'based', 'on', 'these'], 'models'),
#  (['hypothetical', 'algorithm', 'specific', 'to', 'classifying'], 'data'),
#  (['algorithm', 'specific', 'to', 'classifying', 'data'], 'may'),
#  (['specific', 'to', 'classifying', 'data', 'may'], 'use'),
#  (['to', 'classifying', 'data', 'may', 'use'], 'computer'),
#  (['classifying', 'data', 'may', 'use', 'computer'], 'vision'),
#  (['data', 'may', 'use', 'computer', 'vision'], 'of'),
#  (['may', 'use', 'computer', 'vision', 'of'], 'moles'),
#  (['use', 'computer', 'vision', 'of', 'moles'], 'coupled'),
#  (['computer', 'vision', 'of', 'moles', 'coupled'], 'with'),
#  (['vision', 'of', 'moles', 'coupled', 'with'], 'supervised'),
#  (['of', 'moles', 'coupled', 'with', 'supervised'], 'learning'),
#  (['moles', 'coupled', 'with', 'supervised', 'learning'], 'in'),
#  (['coupled', 'with', 'supervised', 'learning', 'in'], 'order'),
#  (['with', 'supervised', 'learning', 'in', 'order'], 'to'),
#  (['supervised', 'learning', 'in', 'order', 'to'], 'train'),
#  (['learning', 'in', 'order', 'to', 'train'], 'it'),
#  (['in', 'order', 'to', 'train', 'it'], 'to'),
#  (['order', 'to', 'train', 'it', 'to'], 'classify'),
#  (['to', 'train', 'it', 'to', 'classify'], 'cancerous'),
#  (['train', 'it', 'to', 'classify', 'cancerous'], 'moles'),
#  (['machine', 'learning', 'algorithm', 'for', 'stock'], 'trading'),
#  (['learning', 'algorithm', 'for', 'stock', 'trading'], 'may'),
#  (['algorithm', 'for', 'stock', 'trading', 'may'], 'inform'),
#  (['for', 'stock', 'trading', 'may', 'inform'], 'trader'),
#  (['stock', 'trading', 'may', 'inform', 'trader'], 'of'),
#  (['trading', 'may', 'inform', 'trader', 'of'], 'future'),
#  (['may', 'inform', 'trader', 'of', 'future'], 'potential'),
#  (['inform', 'trader', 'of', 'future', 'potential'], 'predictions.as'),
#  (['trader', 'of', 'future', 'potential', 'predictions.as'], 'scientific'),
#  (['of', 'future', 'potential', 'predictions.as', 'scientific'], 'endeavor'),
#  (['future', 'potential', 'predictions.as', 'scientific', 'endeavor'],
#   'machine'),
#  (['potential', 'predictions.as', 'scientific', 'endeavor', 'machine'],
#   'learning'),
#  (['predictions.as', 'scientific', 'endeavor', 'machine', 'learning'], 'grew'),
#  (['scientific', 'endeavor', 'machine', 'learning', 'grew'], 'out'),
#  (['endeavor', 'machine', 'learning', 'grew', 'out'], 'of'),
#  (['machine', 'learning', 'grew', 'out', 'of'], 'quest'),
#  (['learning', 'grew', 'out', 'of', 'quest'], 'for'),
#  (['grew', 'out', 'of', 'quest', 'for'], 'artificial'),
#  (['out', 'of', 'quest', 'for', 'artificial'], 'intelligence'),
#  (['in', 'early', 'days', 'of', 'ai'], 'as'),
#  (['early', 'days', 'of', 'ai', 'as'], 'an'),
#  (['days', 'of', 'ai', 'as', 'an'], 'academic'),
#  (['of', 'ai', 'as', 'an', 'academic'], 'discipline'),
#  (['ai', 'as', 'an', 'academic', 'discipline'], 'some'),
#  (['as', 'an', 'academic', 'discipline', 'some'], 'researchers'),
#  (['an', 'academic', 'discipline', 'some', 'researchers'], 'were'),
#  (['academic', 'discipline', 'some', 'researchers', 'were'], 'interested'),
#  (['discipline', 'some', 'researchers', 'were', 'interested'], 'in'),
#  (['some', 'researchers', 'were', 'interested', 'in'], 'having'),
#  (['researchers', 'were', 'interested', 'in', 'having'], 'machines'),
#  (['were', 'interested', 'in', 'having', 'machines'], 'learn'),
#  (['interested', 'in', 'having', 'machines', 'learn'], 'from'),
#  (['in', 'having', 'machines', 'learn', 'from'], 'data'),
#  (['they', 'attempted', 'to', 'approach', 'problem'], 'with'),
#  (['attempted', 'to', 'approach', 'problem', 'with'], 'various'),
#  (['to', 'approach', 'problem', 'with', 'various'], 'symbolic'),
#  (['approach', 'problem', 'with', 'various', 'symbolic'], 'methods'),
#  (['problem', 'with', 'various', 'symbolic', 'methods'], 'as'),
#  (['with', 'various', 'symbolic', 'methods', 'as'], 'well'),
#  (['various', 'symbolic', 'methods', 'as', 'well'], 'as'),
#  (['symbolic', 'methods', 'as', 'well', 'as'], 'what'),
#  (['methods', 'as', 'well', 'as', 'what'], 'were'),
#  (['as', 'well', 'as', 'what', 'were'], 'then'),
#  (['well', 'as', 'what', 'were', 'then'], 'termed'),
#  (['as', 'what', 'were', 'then', 'termed'], '``'),
#  (['what', 'were', 'then', 'termed', '``'], 'neural'),
#  (['were', 'then', 'termed', '``', 'neural'], 'networks'),
#  (['then', 'termed', '``', 'neural', 'networks'], "''"),
#  (['termed', '``', 'neural', 'networks', "''"], 'these'),
#  (['``', 'neural', 'networks', "''", 'these'], 'were'),
#  (['neural', 'networks', "''", 'these', 'were'], 'mostly'),
#  (['networks', "''", 'these', 'were', 'mostly'], 'perceptrons'),
#  (["''", 'these', 'were', 'mostly', 'perceptrons'], 'and'),
#  (['these', 'were', 'mostly', 'perceptrons', 'and'], 'other'),
#  (['were', 'mostly', 'perceptrons', 'and', 'other'], 'models'),
#  (['mostly', 'perceptrons', 'and', 'other', 'models'], 'that'),
#  (['perceptrons', 'and', 'other', 'models', 'that'], 'were'),
#  (['and', 'other', 'models', 'that', 'were'], 'later'),
#  (['other', 'models', 'that', 'were', 'later'], 'found'),
#  (['models', 'that', 'were', 'later', 'found'], 'to'),
#  (['that', 'were', 'later', 'found', 'to'], 'be'),
#  (['were', 'later', 'found', 'to', 'be'], 'reinventions'),
#  (['later', 'found', 'to', 'be', 'reinventions'], 'of'),
#  (['found', 'to', 'be', 'reinventions', 'of'], 'generalized'),
#  (['to', 'be', 'reinventions', 'of', 'generalized'], 'linear'),
#  (['be', 'reinventions', 'of', 'generalized', 'linear'], 'models'),
#  (['reinventions', 'of', 'generalized', 'linear', 'models'], 'of'),
#  (['of', 'generalized', 'linear', 'models', 'of'], 'statistics'),
#  (['probabilistic', 'reasoning', 'was', 'also', 'employed'], 'especially'),
#  (['reasoning', 'was', 'also', 'employed', 'especially'], 'in'),
#  (['was', 'also', 'employed', 'especially', 'in'], 'automated'),
#  (['also', 'employed', 'especially', 'in', 'automated'], 'medical'),
#  (['employed', 'especially', 'in', 'automated', 'medical'],
#   'diagnosis.however'),
#  (['especially', 'in', 'automated', 'medical', 'diagnosis.however'], 'an'),
#  (['in', 'automated', 'medical', 'diagnosis.however', 'an'], 'increasing'),
#  (['automated', 'medical', 'diagnosis.however', 'an', 'increasing'],
#   'emphasis'),
#  (['medical', 'diagnosis.however', 'an', 'increasing', 'emphasis'], 'on'),
#  (['diagnosis.however', 'an', 'increasing', 'emphasis', 'on'], 'logical'),
#  (['an', 'increasing', 'emphasis', 'on', 'logical'], 'knowledge-based'),
#  (['increasing', 'emphasis', 'on', 'logical', 'knowledge-based'], 'approach'),
#  (['emphasis', 'on', 'logical', 'knowledge-based', 'approach'], 'caused'),
#  (['on', 'logical', 'knowledge-based', 'approach', 'caused'], 'rift'),
#  (['logical', 'knowledge-based', 'approach', 'caused', 'rift'], 'between'),
#  (['knowledge-based', 'approach', 'caused', 'rift', 'between'], 'ai'),
#  (['approach', 'caused', 'rift', 'between', 'ai'], 'and'),
#  (['caused', 'rift', 'between', 'ai', 'and'], 'machine'),
#  (['rift', 'between', 'ai', 'and', 'machine'], 'learning'),
#  (['probabilistic', 'systems', 'were', 'plagued', 'by'], 'theoretical'),
#  (['systems', 'were', 'plagued', 'by', 'theoretical'], 'and'),
#  (['were', 'plagued', 'by', 'theoretical', 'and'], 'practical'),
#  (['plagued', 'by', 'theoretical', 'and', 'practical'], 'problems'),
#  (['by', 'theoretical', 'and', 'practical', 'problems'], 'of'),
#  (['theoretical', 'and', 'practical', 'problems', 'of'], 'data'),
#  (['and', 'practical', 'problems', 'of', 'data'], 'acquisition'),
#  (['practical', 'problems', 'of', 'data', 'acquisition'], 'and'),
#  (['problems', 'of', 'data', 'acquisition', 'and'], 'representation'),
#  (['by', '1980', 'expert', 'systems', 'had'], 'come'),
#  (['1980', 'expert', 'systems', 'had', 'come'], 'to'),
#  (['expert', 'systems', 'had', 'come', 'to'], 'dominate'),
#  (['systems', 'had', 'come', 'to', 'dominate'], 'ai'),
#  (['had', 'come', 'to', 'dominate', 'ai'], 'and'),
#  (['come', 'to', 'dominate', 'ai', 'and'], 'statistics'),
#  (['to', 'dominate', 'ai', 'and', 'statistics'], 'was'),
#  (['dominate', 'ai', 'and', 'statistics', 'was'], 'out'),
#  (['ai', 'and', 'statistics', 'was', 'out'], 'of'),
#  (['and', 'statistics', 'was', 'out', 'of'], 'favor'),
#  (['work', 'on', 'symbolic/knowledge-based', 'learning', 'did'], 'continue'),
#  (['on', 'symbolic/knowledge-based', 'learning', 'did', 'continue'], 'within'),
#  (['symbolic/knowledge-based', 'learning', 'did', 'continue', 'within'], 'ai'),
#  (['learning', 'did', 'continue', 'within', 'ai'], 'leading'),
#  (['did', 'continue', 'within', 'ai', 'leading'], 'to'),
#  (['continue', 'within', 'ai', 'leading', 'to'], 'inductive'),
#  (['within', 'ai', 'leading', 'to', 'inductive'], 'logic'),
#  (['ai', 'leading', 'to', 'inductive', 'logic'], 'programming'),
#  (['leading', 'to', 'inductive', 'logic', 'programming'], 'but'),
#  (['to', 'inductive', 'logic', 'programming', 'but'], 'more'),
#  (['inductive', 'logic', 'programming', 'but', 'more'], 'statistical'),
#  (['logic', 'programming', 'but', 'more', 'statistical'], 'line'),
#  (['programming', 'but', 'more', 'statistical', 'line'], 'of'),
#  (['but', 'more', 'statistical', 'line', 'of'], 'research'),
#  (['more', 'statistical', 'line', 'of', 'research'], 'was'),
#  (['statistical', 'line', 'of', 'research', 'was'], 'now'),
#  (['line', 'of', 'research', 'was', 'now'], 'outside'),
#  (['of', 'research', 'was', 'now', 'outside'], 'field'),
#  (['research', 'was', 'now', 'outside', 'field'], 'of'),
#  (['was', 'now', 'outside', 'field', 'of'], 'ai'),
#  (['now', 'outside', 'field', 'of', 'ai'], 'proper'),
#  (['outside', 'field', 'of', 'ai', 'proper'], 'in'),
#  (['field', 'of', 'ai', 'proper', 'in'], 'pattern'),
#  (['of', 'ai', 'proper', 'in', 'pattern'], 'recognition'),
#  (['ai', 'proper', 'in', 'pattern', 'recognition'], 'and'),
#  (['proper', 'in', 'pattern', 'recognition', 'and'], 'information'),
#  (['in', 'pattern', 'recognition', 'and', 'information'], 'retrieval'),
#  (['neural', 'networks', 'research', 'had', 'been'], 'abandoned'),
#  (['networks', 'research', 'had', 'been', 'abandoned'], 'by'),
#  (['research', 'had', 'been', 'abandoned', 'by'], 'ai'),
#  (['had', 'been', 'abandoned', 'by', 'ai'], 'and'),
#  (['been', 'abandoned', 'by', 'ai', 'and'], 'computer'),
#  (['abandoned', 'by', 'ai', 'and', 'computer'], 'science'),
#  (['by', 'ai', 'and', 'computer', 'science'], 'around'),
#  (['ai', 'and', 'computer', 'science', 'around'], 'same'),
#  (['and', 'computer', 'science', 'around', 'same'], 'time'),
#  (['this', 'line', 'too', 'was', 'continued'], 'outside'),
#  (['line', 'too', 'was', 'continued', 'outside'], 'ai/cs'),
#  (['too', 'was', 'continued', 'outside', 'ai/cs'], 'field'),
#  (['was', 'continued', 'outside', 'ai/cs', 'field'], 'as'),
#  (['continued', 'outside', 'ai/cs', 'field', 'as'], '``'),
#  (['outside', 'ai/cs', 'field', 'as', '``'], 'connectionism'),
#  (['ai/cs', 'field', 'as', '``', 'connectionism'], "''"),
#  (['field', 'as', '``', 'connectionism', "''"], 'by'),
#  (['as', '``', 'connectionism', "''", 'by'], 'researchers'),
#  (['``', 'connectionism', "''", 'by', 'researchers'], 'from'),
#  (['connectionism', "''", 'by', 'researchers', 'from'], 'other'),
#  (["''", 'by', 'researchers', 'from', 'other'], 'disciplines'),
#  (['by', 'researchers', 'from', 'other', 'disciplines'], 'including'),
#  (['researchers', 'from', 'other', 'disciplines', 'including'], 'john'),
#  (['from', 'other', 'disciplines', 'including', 'john'], 'hopfield'),
#  (['other', 'disciplines', 'including', 'john', 'hopfield'], 'david'),
#  (['disciplines', 'including', 'john', 'hopfield', 'david'], 'rumelhart'),
#  (['including', 'john', 'hopfield', 'david', 'rumelhart'], 'and'),
#  (['john', 'hopfield', 'david', 'rumelhart', 'and'], 'geoffrey'),
#  (['hopfield', 'david', 'rumelhart', 'and', 'geoffrey'], 'hinton'),
#  (['their', 'main', 'success', 'came', 'in'], 'mid-1980s'),
#  (['main', 'success', 'came', 'in', 'mid-1980s'], 'with'),
#  (['success', 'came', 'in', 'mid-1980s', 'with'], 'reinvention'),
#  (['came', 'in', 'mid-1980s', 'with', 'reinvention'], 'of'),
#  (['in', 'mid-1980s', 'with', 'reinvention', 'of'], 'backpropagation.machine'),
#  (['mid-1980s', 'with', 'reinvention', 'of', 'backpropagation.machine'],
#   'learning'),
#  (['with', 'reinvention', 'of', 'backpropagation.machine', 'learning'],
#   'reorganized'),
#  (['reinvention', 'of', 'backpropagation.machine', 'learning', 'reorganized'],
#   'and'),
#  (['of', 'backpropagation.machine', 'learning', 'reorganized', 'and'],
#   'recognized'),
#  (['backpropagation.machine', 'learning', 'reorganized', 'and', 'recognized'],
#   'as'),
#  (['learning', 'reorganized', 'and', 'recognized', 'as'], 'its'),
#  (['reorganized', 'and', 'recognized', 'as', 'its'], 'own'),
#  (['and', 'recognized', 'as', 'its', 'own'], 'field'),
#  (['recognized', 'as', 'its', 'own', 'field'], 'started'),
#  (['as', 'its', 'own', 'field', 'started'], 'to'),
#  (['its', 'own', 'field', 'started', 'to'], 'flourish'),
#  (['own', 'field', 'started', 'to', 'flourish'], 'in'),
#  (['field', 'started', 'to', 'flourish', 'in'], '1990s'),
#  (['field', 'changed', 'its', 'goal', 'from'], 'achieving'),
#  (['changed', 'its', 'goal', 'from', 'achieving'], 'artificial'),
#  (['its', 'goal', 'from', 'achieving', 'artificial'], 'intelligence'),
#  (['goal', 'from', 'achieving', 'artificial', 'intelligence'], 'to'),
#  (['from', 'achieving', 'artificial', 'intelligence', 'to'], 'tackling'),
#  (['achieving', 'artificial', 'intelligence', 'to', 'tackling'], 'solvable'),
#  (['artificial', 'intelligence', 'to', 'tackling', 'solvable'], 'problems'),
#  (['intelligence', 'to', 'tackling', 'solvable', 'problems'], 'of'),
#  (['to', 'tackling', 'solvable', 'problems', 'of'], 'practical'),
#  (['tackling', 'solvable', 'problems', 'of', 'practical'], 'nature'),
#  (['it', 'shifted', 'focus', 'away', 'from'], 'symbolic'),
#  (['shifted', 'focus', 'away', 'from', 'symbolic'], 'approaches'),
#  (['focus', 'away', 'from', 'symbolic', 'approaches'], 'it'),
#  (['away', 'from', 'symbolic', 'approaches', 'it'], 'had'),
#  (['from', 'symbolic', 'approaches', 'it', 'had'], 'inherited'),
#  (['symbolic', 'approaches', 'it', 'had', 'inherited'], 'from'),
#  (['approaches', 'it', 'had', 'inherited', 'from'], 'ai'),
#  (['it', 'had', 'inherited', 'from', 'ai'], 'and'),
#  (['had', 'inherited', 'from', 'ai', 'and'], 'toward'),
#  (['inherited', 'from', 'ai', 'and', 'toward'], 'methods'),
#  (['from', 'ai', 'and', 'toward', 'methods'], 'and'),
#  (['ai', 'and', 'toward', 'methods', 'and'], 'models'),
#  (['and', 'toward', 'methods', 'and', 'models'], 'borrowed'),
#  (['toward', 'methods', 'and', 'models', 'borrowed'], 'from'),
#  (['methods', 'and', 'models', 'borrowed', 'from'], 'statistics'),
#  (['and', 'models', 'borrowed', 'from', 'statistics'], 'fuzzy'),
#  (['models', 'borrowed', 'from', 'statistics', 'fuzzy'], 'logic'),
#  (['borrowed', 'from', 'statistics', 'fuzzy', 'logic'], 'and'),
#  (['from', 'statistics', 'fuzzy', 'logic', 'and'], 'probability'),
#  (['statistics', 'fuzzy', 'logic', 'and', 'probability'], 'theory.there'),
#  (['fuzzy', 'logic', 'and', 'probability', 'theory.there'], 'is'),
#  (['logic', 'and', 'probability', 'theory.there', 'is'], 'close'),
#  (['and', 'probability', 'theory.there', 'is', 'close'], 'connection'),
#  (['probability', 'theory.there', 'is', 'close', 'connection'], 'between'),
#  (['theory.there', 'is', 'close', 'connection', 'between'], 'machine'),
#  (['is', 'close', 'connection', 'between', 'machine'], 'learning'),
#  (['close', 'connection', 'between', 'machine', 'learning'], 'and'),
#  (['connection', 'between', 'machine', 'learning', 'and'], 'compression'),
#  (['system', 'that', 'predicts', 'posterior', 'probabilities'], 'of'),
#  (['that', 'predicts', 'posterior', 'probabilities', 'of'], 'sequence'),
#  (['predicts', 'posterior', 'probabilities', 'of', 'sequence'], 'given'),
#  (['posterior', 'probabilities', 'of', 'sequence', 'given'], 'its'),
#  (['probabilities', 'of', 'sequence', 'given', 'its'], 'entire'),
#  (['of', 'sequence', 'given', 'its', 'entire'], 'history'),
#  (['sequence', 'given', 'its', 'entire', 'history'], 'can'),
#  (['given', 'its', 'entire', 'history', 'can'], 'be'),
#  (['its', 'entire', 'history', 'can', 'be'], 'used'),
#  (['entire', 'history', 'can', 'be', 'used'], 'for'),
#  (['history', 'can', 'be', 'used', 'for'], 'optimal'),
#  (['can', 'be', 'used', 'for', 'optimal'], 'data'),
#  (['be', 'used', 'for', 'optimal', 'data'], 'compression'),
#  (['conversely', 'an', 'optimal', 'compressor', 'can'], 'be'),
#  (['an', 'optimal', 'compressor', 'can', 'be'], 'used'),
#  (['optimal', 'compressor', 'can', 'be', 'used'], 'for'),
#  (['compressor', 'can', 'be', 'used', 'for'], 'prediction'),
#  (['this', 'equivalence', 'has', 'been', 'used'], 'as'),
#  (['equivalence', 'has', 'been', 'used', 'as'], 'justification'),
#  (['has', 'been', 'used', 'as', 'justification'], 'for'),
#  (['been', 'used', 'as', 'justification', 'for'], 'using'),
#  (['used', 'as', 'justification', 'for', 'using'], 'data'),
#  (['as', 'justification', 'for', 'using', 'data'], 'compression'),
#  (['justification', 'for', 'using', 'data', 'compression'], 'as'),
#  (['for', 'using', 'data', 'compression', 'as'], 'benchmark'),
#  (['using', 'data', 'compression', 'as', 'benchmark'], 'for'),
#  (['data', 'compression', 'as', 'benchmark', 'for'], '``'),
#  (['compression', 'as', 'benchmark', 'for', '``'], 'general'),
#  (['as', 'benchmark', 'for', '``', 'general'], 'intelligence'),
#  (['benchmark', 'for', '``', 'general', 'intelligence'], "''"),
#  (['for', '``', 'general', 'intelligence', "''"], '.an'),
#  (['``', 'general', 'intelligence', "''", '.an'], 'alternative'),
#  (['general', 'intelligence', "''", '.an', 'alternative'], 'view'),
#  (['intelligence', "''", '.an', 'alternative', 'view'], 'can'),
#  (["''", '.an', 'alternative', 'view', 'can'], 'show'),
#  (['.an', 'alternative', 'view', 'can', 'show'], 'compression'),
#  (['alternative', 'view', 'can', 'show', 'compression'], 'algorithms'),
#  (['view', 'can', 'show', 'compression', 'algorithms'], 'implicitly'),
#  (['can', 'show', 'compression', 'algorithms', 'implicitly'], 'map'),
#  (['show', 'compression', 'algorithms', 'implicitly', 'map'], 'strings'),
#  (['compression', 'algorithms', 'implicitly', 'map', 'strings'], 'into'),
#  (['algorithms', 'implicitly', 'map', 'strings', 'into'], 'implicit'),
#  (['implicitly', 'map', 'strings', 'into', 'implicit'], 'feature'),
#  (['map', 'strings', 'into', 'implicit', 'feature'], 'space'),
# ...
#  (['space', 'vectors', 'and', 'compression-based', 'similarity'], 'measures'),
#  (['vectors', 'and', 'compression-based', 'similarity', 'measures'],
#   'compute'),
#  (['and', 'compression-based', 'similarity', 'measures', 'compute'],
#   'similarity'),
#  (['compression-based', 'similarity', 'measures', 'compute', 'similarity'],
#   'within'),
#  (['similarity', 'measures', 'compute', 'similarity', 'within'], 'these'),
#  (['measures', 'compute', 'similarity', 'within', 'these'], 'feature'),
#  (['compute', 'similarity', 'within', 'these', 'feature'], 'spaces'),
#  (['for', 'each', 'compressor', 'c', 'we'], 'define'),
#  (['each', 'compressor', 'c', 'we', 'define'], 'an'),
#  (['compressor', 'c', 'we', 'define', 'an'], 'associated'),
#  (['c', 'we', 'define', 'an', 'associated'], 'vector'),
#  (['we', 'define', 'an', 'associated', 'vector'], 'space'),
#  (['define', 'an', 'associated', 'vector', 'space'], 'ℵ'),
#  (['an', 'associated', 'vector', 'space', 'ℵ'], 'such'),
#  (['associated', 'vector', 'space', 'ℵ', 'such'], 'that'),
#  (['vector', 'space', 'ℵ', 'such', 'that'], 'c'),
#  (['space', 'ℵ', 'such', 'that', 'c'], 'maps'),
#  (['ℵ', 'such', 'that', 'c', 'maps'], 'an'),
#  (['such', 'that', 'c', 'maps', 'an'], 'input'),
#  (['that', 'c', 'maps', 'an', 'input'], 'string'),
#  (['c', 'maps', 'an', 'input', 'string'], 'x'),
#  (['maps', 'an', 'input', 'string', 'x'], 'corresponding'),
#  (['an', 'input', 'string', 'x', 'corresponding'], 'to'),
#  (['input', 'string', 'x', 'corresponding', 'to'], 'vector'),
#  (['string', 'x', 'corresponding', 'to', 'vector'], 'norm'),
#  (['x', 'corresponding', 'to', 'vector', 'norm'], '||~x||'),
#  (['an', 'exhaustive', 'examination', 'of', 'feature'], 'spaces'),
#  (['exhaustive', 'examination', 'of', 'feature', 'spaces'], 'underlying'),
#  (['examination', 'of', 'feature', 'spaces', 'underlying'], 'all'),
#  (['of', 'feature', 'spaces', 'underlying', 'all'], 'compression'),
#  (['feature', 'spaces', 'underlying', 'all', 'compression'], 'algorithms'),
#  (['spaces', 'underlying', 'all', 'compression', 'algorithms'], 'is'),
#  (['underlying', 'all', 'compression', 'algorithms', 'is'], 'precluded'),
#  (['all', 'compression', 'algorithms', 'is', 'precluded'], 'by'),
#  (['compression', 'algorithms', 'is', 'precluded', 'by'], 'space'),
#  (['algorithms', 'is', 'precluded', 'by', 'space'], 'instead'),
#  (['is', 'precluded', 'by', 'space', 'instead'], 'feature'),
#  (['precluded', 'by', 'space', 'instead', 'feature'], 'vectors'),
#  (['by', 'space', 'instead', 'feature', 'vectors'], 'chooses'),
#  (['space', 'instead', 'feature', 'vectors', 'chooses'], 'to'),
#  (['instead', 'feature', 'vectors', 'chooses', 'to'], 'examine'),
#  (['feature', 'vectors', 'chooses', 'to', 'examine'], 'three'),
#  (['vectors', 'chooses', 'to', 'examine', 'three'], 'representative'),
#  (['chooses', 'to', 'examine', 'three', 'representative'], 'lossless'),
#  (['to', 'examine', 'three', 'representative', 'lossless'], 'compression'),
#  (['examine', 'three', 'representative', 'lossless', 'compression'],
#   'methods'),
#  (['three', 'representative', 'lossless', 'compression', 'methods'], 'lzw'),
#  (['representative', 'lossless', 'compression', 'methods', 'lzw'], 'lz77'),
#  (['lossless', 'compression', 'methods', 'lzw', 'lz77'], 'and'),
#  (['compression', 'methods', 'lzw', 'lz77', 'and'], 'ppm.according'),
#  (['methods', 'lzw', 'lz77', 'and', 'ppm.according'], 'to'),
#  (['lzw', 'lz77', 'and', 'ppm.according', 'to'], 'aixi'),
#  (['lz77', 'and', 'ppm.according', 'to', 'aixi'], 'theory'),
#  (['and', 'ppm.according', 'to', 'aixi', 'theory'], 'connection'),
#  (['ppm.according', 'to', 'aixi', 'theory', 'connection'], 'more'),
#  (['to', 'aixi', 'theory', 'connection', 'more'], 'directly'),
#  (['aixi', 'theory', 'connection', 'more', 'directly'], 'explained'),
#  (['theory', 'connection', 'more', 'directly', 'explained'], 'in'),
#  (['connection', 'more', 'directly', 'explained', 'in'], 'hutter'),
#  (['more', 'directly', 'explained', 'in', 'hutter'], 'prize'),
#  (['directly', 'explained', 'in', 'hutter', 'prize'], 'best'),
#  (['explained', 'in', 'hutter', 'prize', 'best'], 'possible'),
#  (['in', 'hutter', 'prize', 'best', 'possible'], 'compression'),
#  (['hutter', 'prize', 'best', 'possible', 'compression'], 'of'),
#  (['prize', 'best', 'possible', 'compression', 'of'], 'x'),
#  (['best', 'possible', 'compression', 'of', 'x'], 'is'),
#  (['possible', 'compression', 'of', 'x', 'is'], 'smallest'),
#  (['compression', 'of', 'x', 'is', 'smallest'], 'possible'),
#  (['of', 'x', 'is', 'smallest', 'possible'], 'software'),
#  (['x', 'is', 'smallest', 'possible', 'software'], 'that'),
#  (['is', 'smallest', 'possible', 'software', 'that'], 'generates'),
#  (['smallest', 'possible', 'software', 'that', 'generates'], 'x'),
#  (['for', 'example', 'in', 'that', 'model'], 'zip'),
#  (['example', 'in', 'that', 'model', 'zip'], 'file'),
#  (['in', 'that', 'model', 'zip', 'file'], 'compressed'),
#  (['that', 'model', 'zip', 'file', 'compressed'], 'size'),
#  (['model', 'zip', 'file', 'compressed', 'size'], 'includes'),
#  (['zip', 'file', 'compressed', 'size', 'includes'], 'both'),
#  (['file', 'compressed', 'size', 'includes', 'both'], 'zip'),
#  (['compressed', 'size', 'includes', 'both', 'zip'], 'file'),
#  (['size', 'includes', 'both', 'zip', 'file'], 'and'),
#  (['includes', 'both', 'zip', 'file', 'and'], 'unzipping'),
#  (['both', 'zip', 'file', 'and', 'unzipping'], 'software'),
#  (['zip', 'file', 'and', 'unzipping', 'software'], 'since'),
#  (['file', 'and', 'unzipping', 'software', 'since'], 'you'),
#  (['and', 'unzipping', 'software', 'since', 'you'], 'can'),
#  (['unzipping', 'software', 'since', 'you', 'can'], 'not'),
#  (['software', 'since', 'you', 'can', 'not'], 'unzip'),
#  (['since', 'you', 'can', 'not', 'unzip'], 'it'),
#  (['you', 'can', 'not', 'unzip', 'it'], 'without'),
#  (['can', 'not', 'unzip', 'it', 'without'], 'both'),
#  (['not', 'unzip', 'it', 'without', 'both'], 'but'),
#  (['unzip', 'it', 'without', 'both', 'but'], 'there'),
#  (['it', 'without', 'both', 'but', 'there'], 'may'),
#  (['without', 'both', 'but', 'there', 'may'], 'be'),
#  (['both', 'but', 'there', 'may', 'be'], 'an'),
#  (['but', 'there', 'may', 'be', 'an'], 'even'),
#  (['there', 'may', 'be', 'an', 'even'], 'smaller'),
#  (['may', 'be', 'an', 'even', 'smaller'], 'combined'),
#  (['be', 'an', 'even', 'smaller', 'combined'], 'form.examples'),
#  (['an', 'even', 'smaller', 'combined', 'form.examples'], 'of'),
#  (['even', 'smaller', 'combined', 'form.examples', 'of'], 'ai-powered'),
#  (['smaller', 'combined', 'form.examples', 'of', 'ai-powered'], 'audio/video'),
#  (['combined', 'form.examples', 'of', 'ai-powered', 'audio/video'],
#   'compression'),
#  (['form.examples', 'of', 'ai-powered', 'audio/video', 'compression'],
#   'software'),
#  (['of', 'ai-powered', 'audio/video', 'compression', 'software'], 'include'),
#  (['ai-powered', 'audio/video', 'compression', 'software', 'include'],
#   'nvidia'),
#  (['audio/video', 'compression', 'software', 'include', 'nvidia'], 'maxine'),
#  (['compression', 'software', 'include', 'nvidia', 'maxine'], 'aivc'),
#  (['examples', 'of', 'software', 'that', 'can'], 'perform'),
#  (['of', 'software', 'that', 'can', 'perform'], 'ai-powered'),
#  (['software', 'that', 'can', 'perform', 'ai-powered'], 'image'),
#  (['that', 'can', 'perform', 'ai-powered', 'image'], 'compression'),
#  (['can', 'perform', 'ai-powered', 'image', 'compression'], 'include'),
#  (['perform', 'ai-powered', 'image', 'compression', 'include'], 'opencv'),
#  (['ai-powered', 'image', 'compression', 'include', 'opencv'], 'tensorflow'),
#  (['image', 'compression', 'include', 'opencv', 'tensorflow'], 'matlab'),
#  (['compression', 'include', 'opencv', 'tensorflow', 'matlab'], 'image'),
#  (['include', 'opencv', 'tensorflow', 'matlab', 'image'], 'processing'),
#  (['opencv', 'tensorflow', 'matlab', 'image', 'processing'], 'toolbox'),
#  (['tensorflow', 'matlab', 'image', 'processing', 'toolbox'], 'and'),
#  (['matlab', 'image', 'processing', 'toolbox', 'and'], 'high-fidelity'),
#  (['image', 'processing', 'toolbox', 'and', 'high-fidelity'], 'generative'),
#  (['processing', 'toolbox', 'and', 'high-fidelity', 'generative'], 'image'),
#  (['toolbox', 'and', 'high-fidelity', 'generative', 'image'],
#   'compression.in'),
#  (['and', 'high-fidelity', 'generative', 'image', 'compression.in'],
#   'unsupervised'),
#  (['high-fidelity', 'generative', 'image', 'compression.in', 'unsupervised'],
#   'machine'),
#  (['generative', 'image', 'compression.in', 'unsupervised', 'machine'],
#   'learning'),
#  (['image', 'compression.in', 'unsupervised', 'machine', 'learning'],
#   'k-means'),
#  (['compression.in', 'unsupervised', 'machine', 'learning', 'k-means'],
#   'clustering'),
#  (['unsupervised', 'machine', 'learning', 'k-means', 'clustering'], 'can'),
#  (['machine', 'learning', 'k-means', 'clustering', 'can'], 'be'),
#  (['learning', 'k-means', 'clustering', 'can', 'be'], 'utilized'),
#  (['k-means', 'clustering', 'can', 'be', 'utilized'], 'to'),
#  (['clustering', 'can', 'be', 'utilized', 'to'], 'compress'),
#  (['can', 'be', 'utilized', 'to', 'compress'], 'data'),
#  (['be', 'utilized', 'to', 'compress', 'data'], 'by'),
#  (['utilized', 'to', 'compress', 'data', 'by'], 'grouping'),
#  (['to', 'compress', 'data', 'by', 'grouping'], 'similar'),
#  (['compress', 'data', 'by', 'grouping', 'similar'], 'data'),
#  (['data', 'by', 'grouping', 'similar', 'data'], 'points'),
#  (['by', 'grouping', 'similar', 'data', 'points'], 'into'),
#  (['grouping', 'similar', 'data', 'points', 'into'], 'clusters'),
#  (['this', 'technique', 'simplifies', 'handling', 'extensive'], 'datasets'),
#  (['technique', 'simplifies', 'handling', 'extensive', 'datasets'], 'that'),
#  (['simplifies', 'handling', 'extensive', 'datasets', 'that'], 'lack'),
#  (['handling', 'extensive', 'datasets', 'that', 'lack'], 'predefined'),
#  (['extensive', 'datasets', 'that', 'lack', 'predefined'], 'labels'),
#  (['datasets', 'that', 'lack', 'predefined', 'labels'], 'and'),
#  (['that', 'lack', 'predefined', 'labels', 'and'], 'finds'),
#  (['lack', 'predefined', 'labels', 'and', 'finds'], 'widespread'),
#  (['predefined', 'labels', 'and', 'finds', 'widespread'], 'use'),
#  (['labels', 'and', 'finds', 'widespread', 'use'], 'in'),
#  (['and', 'finds', 'widespread', 'use', 'in'], 'fields'),
#  (['finds', 'widespread', 'use', 'in', 'fields'], 'such'),
#  (['widespread', 'use', 'in', 'fields', 'such'], 'as'),
#  (['use', 'in', 'fields', 'such', 'as'], 'image'),
#  (['in', 'fields', 'such', 'as', 'image'], 'compression.data'),
#  (['fields', 'such', 'as', 'image', 'compression.data'], 'compression'),
#  (['such', 'as', 'image', 'compression.data', 'compression'], 'aims'),
#  (['as', 'image', 'compression.data', 'compression', 'aims'], 'to'),
#  (['image', 'compression.data', 'compression', 'aims', 'to'], 'reduce'),
#  (['compression.data', 'compression', 'aims', 'to', 'reduce'], 'size'),
#  (['compression', 'aims', 'to', 'reduce', 'size'], 'of'),
#  (['aims', 'to', 'reduce', 'size', 'of'], 'data'),
#  (['to', 'reduce', 'size', 'of', 'data'], 'files'),
#  (['reduce', 'size', 'of', 'data', 'files'], 'enhancing'),
#  (['size', 'of', 'data', 'files', 'enhancing'], 'storage'),
#  (['of', 'data', 'files', 'enhancing', 'storage'], 'efficiency'),
#  (['data', 'files', 'enhancing', 'storage', 'efficiency'], 'and'),
#  (['files', 'enhancing', 'storage', 'efficiency', 'and'], 'speeding'),
#  (['enhancing', 'storage', 'efficiency', 'and', 'speeding'], 'up'),
#  (['storage', 'efficiency', 'and', 'speeding', 'up'], 'data'),
#  (['efficiency', 'and', 'speeding', 'up', 'data'], 'transmission'),
#  (['k-means', 'clustering', 'an', 'unsupervised', 'machine'], 'learning'),
#  (['clustering', 'an', 'unsupervised', 'machine', 'learning'], 'algorithm'),
#  (['an', 'unsupervised', 'machine', 'learning', 'algorithm'], 'is'),
#  (['unsupervised', 'machine', 'learning', 'algorithm', 'is'], 'employed'),
#  (['machine', 'learning', 'algorithm', 'is', 'employed'], 'to'),
#  (['learning', 'algorithm', 'is', 'employed', 'to'], 'partition'),
#  (['algorithm', 'is', 'employed', 'to', 'partition'], 'dataset'),
#  (['is', 'employed', 'to', 'partition', 'dataset'], 'into'),
#  (['employed', 'to', 'partition', 'dataset', 'into'], 'specified'),
#  (['to', 'partition', 'dataset', 'into', 'specified'], 'number'),
#  (['partition', 'dataset', 'into', 'specified', 'number'], 'of'),
#  (['dataset', 'into', 'specified', 'number', 'of'], 'clusters'),
#  (['into', 'specified', 'number', 'of', 'clusters'], 'k'),
#  (['specified', 'number', 'of', 'clusters', 'k'], 'each'),
#  (['number', 'of', 'clusters', 'k', 'each'], 'represented'),
#  (['of', 'clusters', 'k', 'each', 'represented'], 'by'),
#  (['clusters', 'k', 'each', 'represented', 'by'], 'centroid'),
#  (['k', 'each', 'represented', 'by', 'centroid'], 'of'),
#  (['each', 'represented', 'by', 'centroid', 'of'], 'its'),
#  (['represented', 'by', 'centroid', 'of', 'its'], 'points'),
#  (['this', 'process', 'condenses', 'extensive', 'datasets'], 'into'),
#  (['process', 'condenses', 'extensive', 'datasets', 'into'], 'more'),
#  (['condenses', 'extensive', 'datasets', 'into', 'more'], 'compact'),
#  (['extensive', 'datasets', 'into', 'more', 'compact'], 'set'),
#  (['datasets', 'into', 'more', 'compact', 'set'], 'of'),
#  (['into', 'more', 'compact', 'set', 'of'], 'representative'),
#  (['more', 'compact', 'set', 'of', 'representative'], 'points'),
#  (['particularly', 'beneficial', 'in', 'image', 'and'], 'signal'),
#  (['beneficial', 'in', 'image', 'and', 'signal'], 'processing'),
#  (['in', 'image', 'and', 'signal', 'processing'], 'k-means'),
#  (['image', 'and', 'signal', 'processing', 'k-means'], 'clustering'),
#  (['and', 'signal', 'processing', 'k-means', 'clustering'], 'aids'),
#  (['signal', 'processing', 'k-means', 'clustering', 'aids'], 'in'),
#  (['processing', 'k-means', 'clustering', 'aids', 'in'], 'data'),
#  (['k-means', 'clustering', 'aids', 'in', 'data'], 'reduction'),
#  (['clustering', 'aids', 'in', 'data', 'reduction'], 'by'),
#  (['aids', 'in', 'data', 'reduction', 'by'], 'replacing'),
#  (['in', 'data', 'reduction', 'by', 'replacing'], 'groups'),
#  (['data', 'reduction', 'by', 'replacing', 'groups'], 'of'),
#  (['reduction', 'by', 'replacing', 'groups', 'of'], 'data'),
#  (['by', 'replacing', 'groups', 'of', 'data'], 'points'),
#  (['replacing', 'groups', 'of', 'data', 'points'], 'with'),
#  (['groups', 'of', 'data', 'points', 'with'], 'their'),
#  (['of', 'data', 'points', 'with', 'their'], 'centroids'),
#  (['data', 'points', 'with', 'their', 'centroids'], 'thereby'),
#  (['points', 'with', 'their', 'centroids', 'thereby'], 'preserving'),
#  (['with', 'their', 'centroids', 'thereby', 'preserving'], 'core'),
#  (['their', 'centroids', 'thereby', 'preserving', 'core'], 'information'),
#  (['centroids', 'thereby', 'preserving', 'core', 'information'], 'of'),
#  (['thereby', 'preserving', 'core', 'information', 'of'], 'original'),
#  (['preserving', 'core', 'information', 'of', 'original'], 'data'),
#  (['core', 'information', 'of', 'original', 'data'], 'while'),
#  (['information', 'of', 'original', 'data', 'while'], 'significantly'),
#  (['of', 'original', 'data', 'while', 'significantly'], 'decreasing'),
#  (['original', 'data', 'while', 'significantly', 'decreasing'], 'required'),
#  (['data', 'while', 'significantly', 'decreasing', 'required'], 'storage'),
#  (['while', 'significantly', 'decreasing', 'required', 'storage'],
#   'space.machine'),
#  (['significantly', 'decreasing', 'required', 'storage', 'space.machine'],
#   'learning'),
#  (['decreasing', 'required', 'storage', 'space.machine', 'learning'], 'and'),
#  (['required', 'storage', 'space.machine', 'learning', 'and'], 'data'),
#  (['storage', 'space.machine', 'learning', 'and', 'data'], 'mining'),
#  (['space.machine', 'learning', 'and', 'data', 'mining'], 'often'),
#  (['learning', 'and', 'data', 'mining', 'often'], 'employ'),
#  (['and', 'data', 'mining', 'often', 'employ'], 'same'),
#  (['data', 'mining', 'often', 'employ', 'same'], 'methods'),
#  (['mining', 'often', 'employ', 'same', 'methods'], 'and'),
#  (['often', 'employ', 'same', 'methods', 'and'], 'overlap'),
#  (['employ', 'same', 'methods', 'and', 'overlap'], 'significantly'),
#  (['same', 'methods', 'and', 'overlap', 'significantly'], 'but'),
#  ...]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn.utils.rnn import pad_sequence
import random
# Out:
# /Users/olga/miniforge-pypy3/envs/itmo_course_py312/lib/python3.12/site-packages/torch/nn/modules/transformer.py:20: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),

# %%
# Model definition
class RNNPredictor(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim):
        super(RNNPredictor, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.gru = nn.GRU(embedding_dim, hidden_dim, batch_first=True)
        self.linear = nn.Linear(hidden_dim, vocab_size)

    def forward(self, x):
        embedded = self.embedding(x)
        output, hidden = self.gru(embedded)
        output = self.linear(output[:, -1, :])  # Only last time step
        return output
        #return torch.softmax(output, dim=1)

# %%
# Hyperparameters
embedding_dim = 64
hidden_dim = 128
epochs = 500
learning_rate = 0.01
seq_length = 5

model = RNNPredictor(vocab_size, embedding_dim, hidden_dim)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Training loop
for epoch in range(epochs):
    total_loss = 0
    random.shuffle(sequences)
    for seq, target in sequences:
        input_tensor = torch.tensor([[word2idx[word] for word in seq]], dtype=torch.long)
        target_tensor = torch.tensor([word2idx[target]], dtype=torch.long)

        optimizer.zero_grad()
        output = model(input_tensor)
        loss = criterion(output, target_tensor)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    if (epoch + 1) % 10 == 0 or epoch == 0:
        print(f"Epoch {epoch+1}/{epochs}, Loss: {total_loss:.4f}")
    if (epoch + 1) % 100 == 0 or epoch == 0:
        torch.save(model.state_dict(), f"./rnn_next_term.ckp{epoch}.pt")
# Out:
# Epoch 1/500, Loss: 58984.3580
# Epoch 10/500, Loss: 64499.5604
# Epoch 20/500, Loss: 53032.2912
# Epoch 30/500, Loss: 44869.4581
# Epoch 40/500, Loss: 36739.6135
# Epoch 50/500, Loss: 33439.0435
# Epoch 60/500, Loss: 29681.4797
# Epoch 70/500, Loss: 26776.0055
# Epoch 80/500, Loss: 24094.7868
# Epoch 90/500, Loss: 22210.3743
# Epoch 100/500, Loss: 21960.3857
# Epoch 110/500, Loss: 18855.4418
# Epoch 120/500, Loss: 16650.6132
# Epoch 130/500, Loss: 15352.1712
# Epoch 140/500, Loss: 15232.5866
# Epoch 150/500, Loss: 13628.3233
# Epoch 160/500, Loss: 12249.2445
# Epoch 170/500, Loss: 11529.0544
# Epoch 180/500, Loss: 10298.1867
# Epoch 190/500, Loss: 9533.1614
# Epoch 200/500, Loss: 8321.8976
# Epoch 210/500, Loss: 8775.2287
# Epoch 220/500, Loss: 7208.1676
# Epoch 230/500, Loss: 7130.7432
# Epoch 240/500, Loss: 6189.6627
# Epoch 250/500, Loss: 5999.6597
# Epoch 260/500, Loss: 5628.0044
# Epoch 270/500, Loss: 5287.4595
# Epoch 280/500, Loss: 4474.1597
# Epoch 290/500, Loss: 4187.4116
# Epoch 300/500, Loss: 4595.7424
# Epoch 310/500, Loss: 3861.8606
# Epoch 320/500, Loss: 4513.1476
# Epoch 330/500, Loss: 3932.0485
# Epoch 340/500, Loss: 3566.3863
# Epoch 350/500, Loss: 2858.7326
# Epoch 360/500, Loss: 2541.0952
# Epoch 370/500, Loss: 2861.8518
# Epoch 380/500, Loss: 3013.1446
# Epoch 390/500, Loss: 2751.5508
# Epoch 400/500, Loss: 2125.7014
# Epoch 410/500, Loss: 2474.4004
# Epoch 420/500, Loss: 2177.7858
# Epoch 430/500, Loss: 2399.1457
# Epoch 440/500, Loss: 1700.5446
# Epoch 450/500, Loss: 1702.0888
# Epoch 460/500, Loss: 1868.0303
# Epoch 470/500, Loss: 1893.4893
# Epoch 480/500, Loss: 1318.4659
# Epoch 490/500, Loss: 1502.2379
# Epoch 500/500, Loss: 1642.1065

# %%
torch.save(model.state_dict(), "./rnn_next_term.pt")

# %%
rnn = RNNPredictor(vocab_size, embedding_dim, hidden_dim)
rnn.load_state_dict(torch.load("./rnn_next_term.pt"))
rnn.eval()
# Out:
# RNNPredictor(
#   (embedding): Embedding(2132, 64)
#   (gru): GRU(64, 128, batch_first=True)
#   (linear): Linear(in_features=128, out_features=2132, bias=True)
# )

# %%
def predict_next_word(model, input_words):
    input_tensor = torch.tensor([[word2idx[word] for word in input_words]], dtype=torch.long)
    predicted_idx= model(input_tensor).softmax(dim=1).argmax(dim=1).item()
    return idx2word[predicted_idx]

# %%
test_seq = "model".split(" ")
print(test_seq)
for i in range(10):
    predicted = predict_next_word(rnn, test_seq)
    test_seq.append(predicted)
    print(test_seq)
# Out:
# ['model']
# ['model', 'and']
# ['model', 'and', 'algorithmic']
# ['model', 'and', 'algorithmic', 'wherein']
# ['model', 'and', 'algorithmic', 'wherein', '``']
# ['model', 'and', 'algorithmic', 'wherein', '``', 'algorithmic']
# ['model', 'and', 'algorithmic', 'wherein', '``', 'algorithmic', 'model']
# ['model', 'and', 'algorithmic', 'wherein', '``', 'algorithmic', 'model', 'machine']
# ['model', 'and', 'algorithmic', 'wherein', '``', 'algorithmic', 'model', 'machine', 'learning']
# ['model', 'and', 'algorithmic', 'wherein', '``', 'algorithmic', 'model', 'machine', 'learning', 'that']
# ['model', 'and', 'algorithmic', 'wherein', '``', 'algorithmic', 'model', 'machine', 'learning', 'that', 'algorithms']
